# %% [markdown]
# ## ViewCube survey analysis - Thesis
# 67 participants (2025).

# %%
import pandas as pd
import numpy as np
import math
import csv
from scipy import stats as scistats

# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from matplotlib.patches import Rectangle

import seaborn as sns
import pingouin as pg

# %%
import astropy
from astropy import stats

# %%
data = pd.read_csv("ViewCube_survey-clean.csv", delimiter=';') # No BLV
data.fillna("x-x", inplace=True)
data
# Out:
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 0            0   x-x               x-x               x-x    RES_ESP
# 1            0   x-x               x-x               x-x    RES_ENG
# 2            1   1.0  4/18/24 10:01:49  4/18/24 10:26:12  anonymous
# 3            2   2.0  4/18/24 14:48:33  4/18/24 15:19:46  anonymous
# 4            3   3.0  4/18/24 17:14:38  4/18/24 17:21:38  anonymous
# ..         ...   ...               ...               ...        ...
# 62          61  16.0  7/18/24 16:24:37  7/18/24 16:39:13  anonymous
# 63          62  17.0   7/21/24 9:56:47  7/21/24 10:55:44  anonymous
# 64          63  18.0   7/25/24 1:49:37   7/25/24 3:03:34  anonymous
# 65          64  19.0  7/29/24 10:32:28  7/29/24 10:50:09  anonymous
# 66          66   1.0  5/13/24 11:17:19  5/13/24 11:33:10  anonymous
#
#                 Q1              Q2               Q3               Q4  \
# 0   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 2
# 1   Sonification 1            Left  Sonification  2  Sonification  2
# 2   Sonificación 2  A la izquierda   Sonificación 2   Sonificación 2
# 3   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 4
# 4   Sonificación 2  A la izquierda   Sonificación 2   Sonificación 1
# ..             ...             ...              ...              ...
# 62  Sonification 1            Left   Sonification 3   Sonification 2
# 63  Sonification 2            Left   Sonification 3   Sonification 2
# 64  Sonification 1            Left   Sonification 2   Sonification 2
# 65  Sonification 2            Left   Sonification 2   Sonification 3
# 66  Sonification 2            Left   Sonification 2   Sonification 2
#
#             Q5  ...                                     Q18  \
# 0   Espectro 2  ...                                     x-x
# 1   Spectrum 2  ...                                     x-x
# 2   Espectro 1  ...         Mucha experiencia (profesional)
# 3   Espectro 1  ...  Algo de experiencia (hobby/entusiasta)
# 4   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# ..         ...  ...                                     ...
# 62  Spectrum 3  ...         Very experienced (professional)
# 63  Spectrum 2  ...     Some experienced (hobby/enthusiast)
# 64  Spectrum 2  ...                          No experienced
# 65  Spectrum 2  ...                          No experienced
# 66  Spectrum 2  ...         Very experienced (professional)
#
#                                        Q19  \
# 0                                      x-x
# 1                                      x-x
# 2                                  Ninguna
# 3   Algo de experiencia (hobby/entusiasta)
# 4                               Muy básica
# ..                                     ...
# 62         Very experienced (professional)
# 63                   Experienced (amateur)
# 64         Very experienced (professional)
# 65     Some experienced (hobby/enthusiast)
# 66                   Experienced (amateur)
#
#                                                   Q20                  Q21  \
# 0                                                 x-x                  x-x
# 1                                                 x-x                  x-x
# 2                                               Blues                31-40
# 3                                               Rock                 21-30
# 4                                             Clasica  Prefiero no decirlo
# ..                                                ...                  ...
# 62     Electronic Music, Jazz, Classical, Folk, Rock                 41-50
# 63                              Classical, jazz, rock                21-30
# 64  spatial electroacoustic music, music concrete,...    Prefer not to say
# 65                                          Pop music                21-30
# 66                                         Electronic                31-40
#
#     Q22              Q23       Q24                       Q25  \
# 0   x-x              x-x       x-x                       x-x
# 1   x-x              x-x       x-x                       x-x
# 2    No           España   Español  Sí, utilicé auriculares.
# 3    No           ESPAÑA   ESPAÑOL  Sí, utilicé auriculares.
# 4    No          España   Español            No, no lo hice.
# ..  ...              ...       ...                       ...
# 62   No            Malta   English    Yes, I used headphones
# 63   No            China  Mandarin    Yes, I used headphones
# 64   No        Australia  Elnglish    Yes, I used headphones
# 65   No            Spain   Catalan    Yes, I used headphones
# 66   No  United Kingdom    English    Yes, I used headphones
#
#                    Q26                                                Q27
# 0                  x-x                                                x-x
# 1                  x-x                                                x-x
# 2   Audio 3D / Gaming;                                      Gran trabajo!
# 3       Intra-aurales;                                                x-x
# 4           No lo sé.;                                                x-x
# ..                 ...                                                ...
# 62             Stereo;                                                x-x
# 63             Stereo;                                                x-x
# 64       Circum-aural;  discriminating between constant tone and rever...
# 65             Stereo;                                                x-x
# 66             Stereo;                                                x-x
#
# [67 rows x 32 columns]

# %%
blv_inc = pd.read_csv("ViewCube_survey-2.csv", delimiter=';') #raw data
blv_inc.fillna("x-x", inplace=True)
blv_inc
# Out:
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 0            0   x-x               x-x               x-x    RES_ESP
# 1            0   x-x               x-x               x-x    RES_ENG
# 2            1   1.0  4/18/24 10:01:49  4/18/24 10:26:12  anonymous
# 3            2   2.0  4/18/24 14:48:33  4/18/24 15:19:46  anonymous
# 4            3   3.0  4/18/24 17:14:38  4/18/24 17:21:38  anonymous
# ..         ...   ...               ...               ...        ...
# 64          63  18.0   7/25/24 1:49:37   7/25/24 3:03:34  anonymous
# 65          64  19.0  7/29/24 10:32:28  7/29/24 10:50:09  anonymous
# 66          65   3.0   4/15/24 9:17:06   4/15/24 9:51:59  anonymous
# 67          66   1.0  5/13/24 11:17:19  5/13/24 11:33:10  anonymous
# 68          67   2.0  7/23/24 15:06:15  7/23/24 15:31:47  anonymous
#
#                 Q1              Q2               Q3               Q4  \
# 0   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 2
# 1   Sonification 1            Left  Sonification  2  Sonification  2
# 2   Sonificación 2  A la izquierda   Sonificación 2   Sonificación 2
# 3   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 4
# 4   Sonificación 2  A la izquierda   Sonificación 2   Sonificación 1
# ..             ...             ...              ...              ...
# 64  Sonification 1            Left   Sonification 2   Sonification 2
# 65  Sonification 2            Left   Sonification 2   Sonification 3
# 66  Sonification 1            Left   Sonification 3   Sonification 3
# 67  Sonification 2            Left   Sonification 2   Sonification 2
# 68  Sonification 2            Left   Sonification 2   Sonification 2
#
#             Q5  ...                                     Q18  \
# 0   Espectro 2  ...                                     x-x
# 1   Spectrum 2  ...                                     x-x
# 2   Espectro 1  ...         Mucha experiencia (profesional)
# 3   Espectro 1  ...  Algo de experiencia (hobby/entusiasta)
# 4   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# ..         ...  ...                                     ...
# 64  Spectrum 2  ...                          No experienced
# 65  Spectrum 2  ...                          No experienced
# 66  Spectrum 2  ...         Very experienced (professional)
# 67  Spectrum 2  ...         Very experienced (professional)
# 68  Spectrum 2  ...         Very experienced (professional)
#
#                                        Q19  \
# 0                                      x-x
# 1                                      x-x
# 2                                  Ninguna
# 3   Algo de experiencia (hobby/entusiasta)
# 4                               Muy básica
# ..                                     ...
# 64         Very experienced (professional)
# 65     Some experienced (hobby/enthusiast)
# 66                   Very basic experience
# 67                   Experienced (amateur)
# 68                   Experienced (amateur)
#
#                                                   Q20                  Q21  \
# 0                                                 x-x                  x-x
# 1                                                 x-x                  x-x
# 2                                               Blues                31-40
# 3                                               Rock                 21-30
# 4                                             Clasica  Prefiero no decirlo
# ..                                                ...                  ...
# 64  spatial electroacoustic music, music concrete,...    Prefer not to say
# 65                                          Pop music                21-30
# 66                                       Clasic, Rock                41-50
# 67                                         Electronic                31-40
# 68                                   Alternative rock                41-50
#
#     Q22              Q23       Q24                       Q25  \
# 0   x-x              x-x       x-x                       x-x
# 1   x-x              x-x       x-x                       x-x
# 2    No           España   Español  Sí, utilicé auriculares.
# 3    No           ESPAÑA   ESPAÑOL  Sí, utilicé auriculares.
# 4    No          España   Español            No, no lo hice.
# ..  ...              ...       ...                       ...
# 64   No        Australia  Elnglish    Yes, I used headphones
# 65   No            Spain   Catalan    Yes, I used headphones
# 66  Yes            Spain   Spanish    Yes, I used headphones
# 67   No  United Kingdom    English    Yes, I used headphones
# 68  Yes   United Kingdom   English    Yes, I used headphones
#
#                    Q26                                                Q27
# 0                  x-x                                                x-x
# 1                  x-x                                                x-x
# 2   Audio 3D / Gaming;                                      Gran trabajo!
# 3       Intra-aurales;                                                x-x
# 4           No lo sé.;                                                x-x
# ..                 ...                                                ...
# 64       Circum-aural;  discriminating between constant tone and rever...
# 65             Stereo;                                                x-x
# 66                 x-x  No queda claro si lo que distingue una regi´òn...
# 67             Stereo;                                                x-x
# 68             Stereo;                                                x-x
#
# [69 rows x 32 columns]

# %%
data_total_responses = len(data)-2
print("Total responses:", data_total_responses)
# Out:
# Total responses: 65

# %%
def percentage (participants):
    y = (participants/data_total_responses)*100
    return(y)

# %%
def percentage_sub (participants, subgroup_responses):
    z = (participants/subgroup_responses)*100
    return(z)

# %% [markdown]
# # Global results

# %% [markdown]
# ### 12 Simple questions

# %%
data.Q3[0] #Correct answers in spanish => Row[0]
# Out:
# 'Sonificación 2'

# %%
data.Q3[1] #Correct answers in english => Row[1]
# Out:
# 'Sonification  2'

# %%
grades = []
for i in range(2,len(data)):
    grade = 0
    if (data.Q1[i] == (data.Q1[0]) or (data.Q1[i] == data.Q1[1])):
        grade += 1
    if (data.Q2[i] == (data.Q2[0]) or (data.Q2[i] == data.Q2[1])):
        grade += 1 
    if (data.Q3[i] == (data.Q3[0]) or (data.Q3[i] == data.Q3[1])):
        grade += 1
    if (data.Q4[i] == (data.Q4[0]) or (data.Q4[i] == data.Q4[1])):
        grade += 1    
    if (data.Q5[i] == (data.Q5[0]) or (data.Q5[i] == data.Q5[1])):
        grade += 1
    if (data.Q6[i] == (data.Q6[0]) or (data.Q6[i] == data.Q6[1])):
        grade += 1    
    if (data.Q7[i] == (data.Q7[0]) or (data.Q7[i] == data.Q7[1])):
        grade += 1
    if (data.Q8[i] == (data.Q8[0]) or (data.Q8[i] == data.Q8[1])):
        grade += 1    
    if (data.Q9[i] == (data.Q9[0]) or (data.Q9[i] == data.Q9[1])):
        grade += 1
    if (data.Q10[i] == (data.Q10[0]) or (data.Q10[i] == data.Q10[1])):
        grade += 1    
    if (data.Q11[i] == (data.Q11[0]) or (data.Q11[i] == data.Q11[1])):
        grade += 1
    if (data.Q12[i] == (data.Q12[0]) or (data.Q12[i] == data.Q12[1])):
        grade += 1    
   
    grades.append(grade)
mode = scistats.mode(grades)
print("Grades:", grades)    
print("Mean:", np.mean(grades))
print("Median:", np.median(grades))
print("Most frequent result:", mode)
# Out:
# Grades: [8, 7, 3, 4, 6, 6, 3, 4, 7, 3, 5, 5, 1, 9, 8, 7, 5, 3, 7, 9, 6, 8, 6, 5, 5, 10, 8, 7, 9, 6, 8, 8, 8, 5, 6, 8, 10, 6, 7, 6, 5, 5, 11, 5, 6, 5, 6, 4, 7, 7, 4, 8, 3, 6, 10, 6, 5, 6, 5, 4, 6, 6, 8, 5, 7]
# Mean: 6.184615384615385
# Median: 6.0
# Most frequent result: ModeResult(mode=array([6]), count=array([15]))

# %% [markdown]
# ## Outlier identification

# %%
print("Original Grades:", grades)
print("-" * 30)

grades_nump = np.array(grades)
# --- Z-score Method with a less strict threshold ---
mean_grade = np.mean(grades_nump)
std_dev_grade = np.std(grades_nump)
z_scores = (grades - mean_grade) / std_dev_grade
z_score_outliers_relaxed = grades_nump[np.abs(z_scores) > 2]
print("Potential Outliers (Z-score > |2|):", z_score_outliers_relaxed)
print("-" * 30)

# --- IQR Method with a different multiplier ---
q1 = np.percentile(grades_nump, 25)
q3 = np.percentile(grades_nump, 75)
iqr = q3 - q1
lower_fence_wide = q1 - 3 * iqr
upper_fence_wide = q3 + 3 * iqr
iqr_outliers_wide = grades_nump[(grades_nump < lower_fence_wide) | (grades_nump > upper_fence_wide)]
print("Potential Outliers (IQR with multiplier 3):", iqr_outliers_wide)
print("-" * 30)

# --- Visualizing with a Box Plot ---
plt.figure(figsize=(8, 6))
sns.boxplot(x=grades_nump)
plt.title("Box Plot of Grades")
plt.xlabel("Grades")
plt.show()
# Out:
# Original Grades: [8, 7, 3, 4, 6, 6, 3, 4, 7, 3, 5, 5, 1, 9, 8, 7, 5, 3, 7, 9, 6, 8, 6, 5, 5, 10, 8, 7, 9, 6, 8, 8, 8, 5, 6, 8, 10, 6, 7, 6, 5, 5, 11, 5, 6, 5, 6, 4, 7, 7, 4, 8, 3, 6, 10, 6, 5, 6, 5, 4, 6, 6, 8, 5, 7]
# ------------------------------
# Potential Outliers (Z-score > |2|): [ 1 11]
# ------------------------------
# Potential Outliers (IQR with multiplier 3): []
# ------------------------------

# %% [markdown]
# # BLV analysis

# %%
blv_list = []
blv_index = []
blv_counter = 0
for j in range(len(blv_inc)):
    if (blv_inc.Q22[j] == "Yes"):
        blv_counter += 1
        current_row = blv_inc.iloc[j]
        blv_list.append(current_row)
        blv_index.append(j)
        
print("Number of blv:", blv_counter)
blv_df = pd.DataFrame(blv_list)
blv_df
# Out:
# Number of blv: 2
#     Unnamed: 0   ID        Start time   Completion time        REF  \
# 66          65  3.0   4/15/24 9:17:06   4/15/24 9:51:59  anonymous
# 68          67  2.0  7/23/24 15:06:15  7/23/24 15:31:47  anonymous
#
#                 Q1    Q2              Q3              Q4          Q5  ...  \
# 66  Sonification 1  Left  Sonification 3  Sonification 3  Spectrum 2  ...
# 68  Sonification 2  Left  Sonification 2  Sonification 2  Spectrum 2  ...
#
#                                 Q18                    Q19               Q20  \
# 66  Very experienced (professional)  Very basic experience      Clasic, Rock
# 68  Very experienced (professional)  Experienced (amateur)  Alternative rock
#
#       Q21  Q22             Q23      Q24                     Q25      Q26  \
# 66  41-50  Yes           Spain  Spanish  Yes, I used headphones      x-x
# 68  41-50  Yes  United Kingdom  English  Yes, I used headphones  Stereo;
#
#                                                   Q27
# 66  No queda claro si lo que distingue una regi´òn...
# 68                                                x-x
#
# [2 rows x 32 columns]

# %%
grades_blv = []
for i in range(len(blv_df)):
    grade = 0
    if (blv_df.Q1[blv_index[i]] == (data.Q1[0]) or (blv_df.Q1[blv_index[i]] == data.Q1[1])):
        grade += 1
    if (blv_df.Q2[blv_index[i]] == (data.Q2[0]) or (blv_df.Q2[blv_index[i]] == data.Q2[1])):
        grade += 1 
    if (blv_df.Q3[blv_index[i]] == (data.Q3[0]) or (blv_df.Q3[blv_index[i]] == data.Q3[1])):
        grade += 1
    if (blv_df.Q4[blv_index[i]] == (data.Q4[0]) or (blv_df.Q4[blv_index[i]] == data.Q4[1])):
        grade += 1    
    if (blv_df.Q5[blv_index[i]] == (data.Q5[0]) or (blv_df.Q5[blv_index[i]] == data.Q5[1])):
        grade += 1
    if (blv_df.Q6[blv_index[i]] == (data.Q6[0]) or (blv_df.Q6[blv_index[i]] == data.Q6[1])):
        grade += 1    
    if (blv_df.Q7[blv_index[i]] == (data.Q7[0]) or (blv_df.Q7[blv_index[i]] == data.Q7[1])):
        grade += 1
    if (blv_df.Q8[blv_index[i]] == (data.Q8[0]) or (blv_df.Q8[blv_index[i]] == data.Q8[1])):
        grade += 1    
    if (blv_df.Q9[blv_index[i]] == (data.Q9[0]) or (blv_df.Q9[blv_index[i]] == data.Q9[1])):
        grade += 1
    if (blv_df.Q10[blv_index[i]] == (data.Q10[0]) or (blv_df.Q10[blv_index[i]] == data.Q10[1])):
        grade += 1    
    if (blv_df.Q11[blv_index[i]] == (data.Q11[0]) or (blv_df.Q11[blv_index[i]] == data.Q11[1])):
        grade += 1
    if (blv_df.Q12[blv_index[i]] == (data.Q12[0]) or (blv_df.Q12[blv_index[i]] == data.Q12[1])):
        grade += 1    
    grades_blv.append(grade)
mode_blv = scistats.mode(grades_blv)
print("Grades blv:", grades_blv)    
print("Mean:", np.mean(grades_blv))
print("Median:", np.median(grades_blv))
print("Most frequent result:", mode_blv)
# Out:
# Grades blv: [6, 7]
# Mean: 6.5
# Median: 6.5
# Most frequent result: ModeResult(mode=array([6]), count=array([1]))

# %%
Q1blv = len([i for i in range(len(blv_df)) if ((blv_df.Q1[blv_index[i]] == data.Q1[0]) or (blv_df.Q1[blv_index[i]] == data.Q1[1]))])
Q2blv = len([i for i in range(len(blv_df)) if ((blv_df.Q2[blv_index[i]] == data.Q2[0]) or (blv_df.Q2[blv_index[i]] == data.Q2[1]))])
Q3blv = len([i for i in range(len(blv_df)) if ((blv_df.Q3[blv_index[i]] == data.Q3[0]) or (blv_df.Q3[blv_index[i]] == data.Q3[1]))])
Q4blv = len([i for i in range(len(blv_df)) if ((blv_df.Q4[blv_index[i]] == data.Q4[0]) or (blv_df.Q4[blv_index[i]] == data.Q4[1]))])
Q5blv = len([i for i in range(len(blv_df)) if ((blv_df.Q5[blv_index[i]] == data.Q5[0]) or (blv_df.Q5[blv_index[i]] == data.Q5[1]))])
Q6blv = len([i for i in range(len(blv_df)) if ((blv_df.Q6[blv_index[i]] == data.Q6[0]) or (blv_df.Q6[blv_index[i]] == data.Q6[1]))])
Q7blv = len([i for i in range(len(blv_df)) if ((blv_df.Q7[blv_index[i]] == data.Q7[0]) or (blv_df.Q7[blv_index[i]] == data.Q7[1]))])
Q8blv = len([i for i in range(len(blv_df)) if ((blv_df.Q8[blv_index[i]] == data.Q8[0]) or (blv_df.Q8[blv_index[i]] == data.Q8[1]))])
Q9blv = len([i for i in range(len(blv_df)) if ((blv_df.Q9[blv_index[i]] == data.Q9[0]) or (blv_df.Q9[blv_index[i]] == data.Q9[1]))])
Q10blv = len([i for i in range(len(blv_df)) if ((blv_df.Q10[blv_index[i]] == data.Q10[0]) or (blv_df.Q10[blv_index[i]] == data.Q10[1]))])
Q11blv = len([i for i in range(len(blv_df)) if ((blv_df.Q11[blv_index[i]] == data.Q11[0]) or (blv_df.Q11[blv_index[i]] == data.Q11[1]))])
Q12blv = len([i for i in range(len(blv_df)) if ((blv_df.Q12[blv_index[i]] == data.Q12[0]) or (blv_df.Q12[blv_index[i]] == data.Q12[1]))])

blv_correct = [Q1blv,Q2blv,Q3blv,Q4blv,Q5blv,Q6blv,Q7blv,Q8blv,Q9blv,Q10blv,Q11blv,Q12blv]
blv_correct = np.array(blv_correct, int)
blv_correct #12 Single response correct results
# Out:
# array([1, 2, 0, 0, 2, 1, 1, 2, 2, 0, 1, 1])

# %%
blv_total_responses = len(blv_df)
mean_blv_correct = np.mean(blv_correct)
print("Total responses: ", blv_total_responses)
print("BLV success mean:", mean_blv_correct/blv_total_responses)

success_blv_correct = np.sum(blv_correct)
attempts_blv_correct = 12* blv_total_responses
conf_blv_correct = astropy.stats.binom_conf_interval(success_blv_correct, attempts_blv_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_blv_correct) # Correct answers interval
# Out:
# Total responses:  2
# BLV success mean: 0.5416666666666666
# Jeffreys confidence interval:  [0.44033182 0.63961517]

# %%
blv_total_responses = len(blv_df)
mean_blv_correct = np.mean(blv_correct)
print("blv answers mean in %:", mean_blv_correct/blv_total_responses)
median_blv_correct = np.median(blv_correct)
print("blv answers median in %:", median_blv_correct/blv_total_responses)
# Out:
# blv answers mean in %: 0.5416666666666666
# blv answers median in %: 0.5

# %%
blv = pd.Series(blv_correct/blv_total_responses)
blv.describe()
# Out:
# count    12.000000
# mean      0.541667
# std       0.396481
# min       0.000000
# 25%       0.375000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
# dtype: float64

# %%
check_1 = "Lejos"
check_2 = "derecha"
check_3 = "formación"
check_4 = "Far"
check_5 = "Right"
check_6 = "forming"

check_7 = "Cerca"
check_8 = "izquierda"
check_9 = "vieja"
check_10 = "Close"
check_11 = "Left"
check_12 = "Retired"

# %%
Q13blv = len([i for i in range(len(blv_df)) if ((check_1 in blv_df.Q13[blv_index[i]]) and (check_2 in blv_df.Q13[blv_index[i]]) and (check_3 in blv_df.Q13[blv_index[i]])) or ((check_4 in blv_df.Q13[blv_index[i]]) and (check_5 in blv_df.Q13[blv_index[i]]) and (check_6 in blv_df.Q13[blv_index[i]]))])
Q14blv = len([i for i in range(len(blv_df)) if ((check_7 in blv_df.Q14[blv_index[i]]) and (check_8 in blv_df.Q14[blv_index[i]]) and (check_9 in blv_df.Q14[blv_index[i]])) or ((check_10 in blv_df.Q14[blv_index[i]]) and (check_11 in blv_df.Q14[blv_index[i]]) and (check_12 in blv_df.Q14[blv_index[i]]))])

blv_combined_correct = [Q13blv,Q14blv]
blv_combined_correct = np.array(blv_combined_correct, int)

blv_combined_correct
# Out:
# array([0, 0])

# %%
mean_blv_combined_correct = np.mean(blv_combined_correct)
print("Professional astronomers success mean (Combined questions):", mean_blv_combined_correct/blv_total_responses)
success_blv_combined_correct = np.sum(blv_combined_correct)
attempts_blv_combined_correct = 2* blv_total_responses
conf_blv_combined_correct = astropy.stats.binom_conf_interval(success_blv_combined_correct, attempts_blv_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_blv_combined_correct) # Correct answers interval
# Out:
# Professional astronomers success mean (Combined questions): 0.0
# Jeffreys confidence interval:  [0.         0.20792572]

# %%
blv_combined = pd.Series(blv_combined_correct/blv_total_responses)
blv_combined.describe()
# Out:
# count    2.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# dtype: float64

# %%
# Interactivity
Q15blv_good = len([i for i in range(len(blv_df)) if (("Buena" in blv_df.Q15[blv_index[i]]) or ("Muy buena" in blv_df.Q15[blv_index[i]]) or ("Good" in blv_df.Q15[blv_index[i]]) or ("Very good" in blv_df.Q15[blv_index[i]]))])
Q15blv_acc = len([i for i in range(len(blv_df)) if (("Aceptable" in blv_df.Q15[blv_index[i]]) or ("Acceptable" in blv_df.Q15[blv_index[i]]))])
Q15blv_bad = len([i for i in range(len(blv_df)) if (("Mala" in blv_df.Q15[blv_index[i]]) or ("Muy mala" in blv_df.Q15[blv_index[i]]) or ("Bad" in blv_df.Q15[blv_index[i]]) or ("Very bad" in blv_df.Q15[blv_index[i]]))])
Q15blv_xxx = len([i for i in range(len(blv_df)) if (("XXX" in blv_df.Q15[blv_index[i]]))])
print("Interactivity 'good' or 'very good':", Q15blv_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15blv_good, blv_counter))
print("Interactivity 'acceptable':", Q15blv_acc)
print("(%)", percentage_sub(Q15blv_acc, blv_counter))
print("Interactivity 'bad' or 'very bad':", Q15blv_bad)
print("(%)", percentage_sub(Q15blv_bad, blv_counter))
print("Participants that couldn't test the application in person:", Q15blv_xxx)
print("(%)", percentage_sub(Q15blv_xxx, blv_counter))
# Out:
# Interactivity 'good' or 'very good': 0
# (%) 0.0
# Interactivity 'acceptable': 0
# (%) 0.0
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 2
# (%) 100.0

# %%
# Usefulness
Q16blv_good = len([i for i in range(len(blv_df)) if (("Útil" in blv_df.Q16[blv_index[i]]) or ("Muy útil" in blv_df.Q16[blv_index[i]]) or ("Useful" in blv_df.Q16[blv_index[i]]) or ("Very useful" in blv_df.Q16[blv_index[i]]))])
Q16blv_bad = len([i for i in range(len(blv_df)) if (("dudosa" in blv_df.Q16[blv_index[i]]) or ("Doubtedly" in blv_df.Q16[blv_index[i]]) or ("Doubtely" in blv_df.Q16[blv_index[i]]) or ("Inútil" in blv_df.Q16[blv_index[i]]) or ("Useless" in blv_df.Q16[blv_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16blv_good)
print("(%)", percentage_sub(Q16blv_good, blv_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16blv_bad)
print("(%)", percentage_sub(Q16blv_bad, blv_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 2
# (%) 100.0
# Participants finding it 'Doubtedly useful' or 'useless': 0
# (%) 0.0

# %%
# Quality of sound
Q17blv_good = len([i for i in range(len(blv_df)) if (("Buen" in blv_df.Q17[blv_index[i]]) or ("Muy buen" in blv_df.Q17[blv_index[i]]) or ("Good" in blv_df.Q17[blv_index[i]]) or ("Nice" in blv_df.Q17[blv_index[i]]))])
Q17blv_acc = len([i for i in range(len(blv_df)) if (("Aceptable" in blv_df.Q17[blv_index[i]]) or ("Acceptable" in blv_df.Q17[blv_index[i]]))])
Q17blv_bad = len([i for i in range(len(blv_df)) if (("Mal" in blv_df.Q17[blv_index[i]]) or ("Insoportable" in blv_df.Q17[blv_index[i]]) or ("Bad" in blv_df.Q17[blv_index[i]]) or ("Intolerable" in blv_df.Q17[blv_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17blv_good)
print("(%)", percentage_sub(Q17blv_good, blv_counter))
print("Sound Quality 'acceptable':", Q17blv_acc)
print("(%)", percentage(Q17blv_acc))
print("Sound Quality 'bad' or 'very bad':", Q17blv_bad)
print("(%)", percentage_sub(Q17blv_bad, blv_counter))
# Out:
# Sound Quality 'good' or 'very good': 2
# (%) 100.0
# Sound Quality 'acceptable': 0
# (%) 0.0
# Sound Quality 'bad' or 'very bad': 0
# (%) 0.0

# %% [markdown]
# # Non-BLV

# %%
nonblv_df = blv_inc.sample(frac=0.03, replace=False, random_state=55)
nonblv_df
# Out:
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 15          14  14.0  4/23/24 12:13:07  4/23/24 12:56:30  anonymous
# 58          57  12.0   7/2/24 10:56:21   7/2/24 11:13:48  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 15  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 58  Sonification 1            Left  Sonification 2  Sonification 3
#
#             Q5  ...                              Q18  \
# 15  Espectro 3  ...                          Ninguna
# 58  Spectrum 2  ...  Very experienced (professional)
#
#                                     Q19                                  Q20  \
# 15                           Muy básica            Variada (un poco de todo)
# 58  Some experienced (hobby/enthusiast)  Electronic music / alternative rock
#
#       Q21 Q22     Q23         Q24                       Q25         Q26  Q27
# 15  21-30  No  España  Castellano  Sí, utilicé auriculares.  No lo sé.;  x-x
# 58  21-30  No   Spain     Spanish    Yes, I used headphones     Stereo;  x-x
#
# [2 rows x 32 columns]

# %%
nonblv_counter = 0
nonblv_index = []
for j in range(len(nonblv_df)):
    nonblv_index.append(nonblv_df.index[j])
    nonblv_counter +=1
nonblv_index
# Out:
# [15, 58]

# %%
grades_nonblv = []
for i in range(len(nonblv_df)):
    grade = 0
    if (nonblv_df.Q1[nonblv_index[i]] == (data.Q1[0]) or (nonblv_df.Q1[nonblv_index[i]] == data.Q1[1])):
        grade += 1
    if (nonblv_df.Q2[nonblv_index[i]] == (data.Q2[0]) or (nonblv_df.Q2[nonblv_index[i]] == data.Q2[1])):
        grade += 1 
    if (nonblv_df.Q3[nonblv_index[i]] == (data.Q3[0]) or (nonblv_df.Q3[nonblv_index[i]] == data.Q3[1])):
        grade += 1
    if (nonblv_df.Q4[nonblv_index[i]] == (data.Q4[0]) or (nonblv_df.Q4[nonblv_index[i]] == data.Q4[1])):
        grade += 1    
    if (nonblv_df.Q5[nonblv_index[i]] == (data.Q5[0]) or (nonblv_df.Q5[nonblv_index[i]] == data.Q5[1])):
        grade += 1
    if (nonblv_df.Q6[nonblv_index[i]] == (data.Q6[0]) or (nonblv_df.Q6[nonblv_index[i]] == data.Q6[1])):
        grade += 1    
    if (nonblv_df.Q7[nonblv_index[i]] == (data.Q7[0]) or (nonblv_df.Q7[nonblv_index[i]] == data.Q7[1])):
        grade += 1
    if (nonblv_df.Q8[nonblv_index[i]] == (data.Q8[0]) or (nonblv_df.Q8[nonblv_index[i]] == data.Q8[1])):
        grade += 1    
    if (nonblv_df.Q9[nonblv_index[i]] == (data.Q9[0]) or (nonblv_df.Q9[nonblv_index[i]] == data.Q9[1])):
        grade += 1
    if (nonblv_df.Q10[nonblv_index[i]] == (data.Q10[0]) or (nonblv_df.Q10[nonblv_index[i]] == data.Q10[1])):
        grade += 1    
    if (nonblv_df.Q11[nonblv_index[i]] == (data.Q11[0]) or (nonblv_df.Q11[nonblv_index[i]] == data.Q11[1])):
        grade += 1
    if (nonblv_df.Q12[nonblv_index[i]] == (data.Q12[0]) or (nonblv_df.Q12[nonblv_index[i]] == data.Q12[1])):
        grade += 1    
    grades_nonblv.append(grade)
mode_nonblv = scistats.mode(grades_nonblv)
print("Grades nonblv:", grades_nonblv)    
print("Mean:", np.mean(grades_nonblv))
print("Median:", np.median(grades_nonblv))
print("Most frequent result:", mode_nonblv)
# Out:
# Grades nonblv: [9, 5]
# Mean: 7.0
# Median: 7.0
# Most frequent result: ModeResult(mode=array([5]), count=array([1]))

# %%
Q1nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q1[nonblv_index[i]] == data.Q1[0]) or (nonblv_df.Q1[nonblv_index[i]] == data.Q1[1]))])
Q2nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q2[nonblv_index[i]] == data.Q2[0]) or (nonblv_df.Q2[nonblv_index[i]] == data.Q2[1]))])
Q3nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q3[nonblv_index[i]] == data.Q3[0]) or (nonblv_df.Q3[nonblv_index[i]] == data.Q3[1]))])
Q4nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q4[nonblv_index[i]] == data.Q4[0]) or (nonblv_df.Q4[nonblv_index[i]] == data.Q4[1]))])
Q5nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q5[nonblv_index[i]] == data.Q5[0]) or (nonblv_df.Q5[nonblv_index[i]] == data.Q5[1]))])
Q6nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q6[nonblv_index[i]] == data.Q6[0]) or (nonblv_df.Q6[nonblv_index[i]] == data.Q6[1]))])
Q7nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q7[nonblv_index[i]] == data.Q7[0]) or (nonblv_df.Q7[nonblv_index[i]] == data.Q7[1]))])
Q8nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q8[nonblv_index[i]] == data.Q8[0]) or (nonblv_df.Q8[nonblv_index[i]] == data.Q8[1]))])
Q9nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q9[nonblv_index[i]] == data.Q9[0]) or (nonblv_df.Q9[nonblv_index[i]] == data.Q9[1]))])
Q10nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q10[nonblv_index[i]] == data.Q10[0]) or (nonblv_df.Q10[nonblv_index[i]] == data.Q10[1]))])
Q11nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q11[nonblv_index[i]] == data.Q11[0]) or (nonblv_df.Q11[nonblv_index[i]] == data.Q11[1]))])
Q12nonblv = len([i for i in range(len(nonblv_df)) if ((nonblv_df.Q12[nonblv_index[i]] == data.Q12[0]) or (nonblv_df.Q12[nonblv_index[i]] == data.Q12[1]))])

nonblv_correct = [Q1nonblv,Q2nonblv,Q3nonblv,Q4nonblv,Q5nonblv,Q6nonblv,Q7nonblv,Q8nonblv,Q9nonblv,Q10nonblv,Q11nonblv,Q12nonblv]
nonblv_correct = np.array(nonblv_correct, int)
nonblv_correct #12 Single response correct results
# Out:
# array([2, 2, 0, 1, 1, 1, 1, 2, 2, 1, 0, 1])

# %%
nonblv_total_responses = len(nonblv_df)
mean_nonblv_correct = np.mean(nonblv_correct)
print("Total responses: ", nonblv_total_responses)
print("nonblv success mean:", mean_nonblv_correct/nonblv_total_responses)

success_nonblv_correct = np.sum(nonblv_correct)
attempts_nonblv_correct = 12* nonblv_total_responses
conf_nonblv_correct = astropy.stats.binom_conf_interval(success_nonblv_correct, attempts_nonblv_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nonblv_correct) # Correct answers interval
# Out:
# Total responses:  2
# nonblv success mean: 0.5833333333333334
# Jeffreys confidence interval:  [0.48132622 0.67856745]

# %%
nonblv_total_responses = len(nonblv_df)
mean_nonblv_correct = np.mean(nonblv_correct)
print("nonblv answers mean in %:", mean_nonblv_correct/nonblv_total_responses)
median_nonblv_correct = np.median(nonblv_correct)
print("nonblv answers median in %:", median_nonblv_correct/nonblv_total_responses)
# Out:
# nonblv answers mean in %: 0.5833333333333334
# nonblv answers median in %: 0.5

# %%
nonblv = pd.Series(nonblv_correct/nonblv_total_responses)
nonblv.describe()
# Out:
# count    12.000000
# mean      0.583333
# std       0.358870
# min       0.000000
# 25%       0.500000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
# dtype: float64

# %%
Q13nonblv = len([i for i in range(len(nonblv_df)) if ((check_1 in nonblv_df.Q13[nonblv_index[i]]) and (check_2 in nonblv_df.Q13[nonblv_index[i]]) and (check_3 in nonblv_df.Q13[nonblv_index[i]])) or ((check_4 in nonblv_df.Q13[nonblv_index[i]]) and (check_5 in nonblv_df.Q13[nonblv_index[i]]) and (check_6 in nonblv_df.Q13[nonblv_index[i]]))])
Q14nonblv = len([i for i in range(len(nonblv_df)) if ((check_7 in nonblv_df.Q14[nonblv_index[i]]) and (check_8 in nonblv_df.Q14[nonblv_index[i]]) and (check_9 in nonblv_df.Q14[nonblv_index[i]])) or ((check_10 in nonblv_df.Q14[nonblv_index[i]]) and (check_11 in nonblv_df.Q14[nonblv_index[i]]) and (check_12 in nonblv_df.Q14[nonblv_index[i]]))])

nonblv_combined_correct = [Q13nonblv,Q14nonblv]
nonblv_combined_correct = np.array(nonblv_combined_correct, int)

nonblv_combined_correct
# Out:
# array([0, 0])

# %%
mean_nonblv_combined_correct = np.mean(nonblv_combined_correct)
print("Professional astronomers success mean (Combined questions):", mean_nonblv_combined_correct/nonblv_total_responses)
success_nonblv_combined_correct = np.sum(nonblv_combined_correct)
attempts_nonblv_combined_correct = 2* nonblv_total_responses
conf_nonblv_combined_correct = astropy.stats.binom_conf_interval(success_nonblv_combined_correct, attempts_nonblv_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nonblv_combined_correct) # Correct answers interval
# Out:
# Professional astronomers success mean (Combined questions): 0.0
# Jeffreys confidence interval:  [0.         0.20792572]

# %%
nonblv_combined = pd.Series(nonblv_combined_correct/nonblv_total_responses)
nonblv_combined.describe()
# Out:
# count    2.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# dtype: float64

# %%
# Interactivity
Q15nonblv_good = len([i for i in range(len(nonblv_df)) if (("Buena" in nonblv_df.Q15[nonblv_index[i]]) or ("Muy buena" in nonblv_df.Q15[nonblv_index[i]]) or ("Good" in nonblv_df.Q15[nonblv_index[i]]) or ("Very good" in nonblv_df.Q15[nonblv_index[i]]))])
Q15nonblv_acc = len([i for i in range(len(nonblv_df)) if (("Aceptable" in nonblv_df.Q15[nonblv_index[i]]) or ("Acceptable" in nonblv_df.Q15[nonblv_index[i]]))])
Q15nonblv_bad = len([i for i in range(len(nonblv_df)) if (("Mala" in nonblv_df.Q15[nonblv_index[i]]) or ("Muy mala" in nonblv_df.Q15[nonblv_index[i]]) or ("Bad" in nonblv_df.Q15[nonblv_index[i]]) or ("Very bad" in nonblv_df.Q15[nonblv_index[i]]))])
Q15nonblv_xxx = len([i for i in range(len(nonblv_df)) if (("XXX" in nonblv_df.Q15[nonblv_index[i]]))])
print("Interactivity 'good' or 'very good':", Q15nonblv_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15nonblv_good, nonblv_counter))
print("Interactivity 'acceptable':", Q15nonblv_acc)
print("(%)", percentage_sub(Q15nonblv_acc, nonblv_counter))
print("Interactivity 'bad' or 'very bad':", Q15nonblv_bad)
print("(%)", percentage_sub(Q15nonblv_bad, nonblv_counter))
print("Participants that couldn't test the application in person:", Q15nonblv_xxx)
print("(%)", percentage_sub(Q15nonblv_xxx, nonblv_counter))
# Out:
# Interactivity 'good' or 'very good': 2
# (%) 100.0
# Interactivity 'acceptable': 0
# (%) 0.0
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 0
# (%) 0.0

# %%
# Usefulness
Q16nonblv_good = len([i for i in range(len(nonblv_df)) if (("Útil" in nonblv_df.Q16[nonblv_index[i]]) or ("Muy útil" in nonblv_df.Q16[nonblv_index[i]]) or ("Useful" in nonblv_df.Q16[nonblv_index[i]]) or ("Very useful" in nonblv_df.Q16[nonblv_index[i]]))])
Q16nonblv_bad = len([i for i in range(len(nonblv_df)) if (("dudosa" in nonblv_df.Q16[nonblv_index[i]]) or ("Doubtedly" in nonblv_df.Q16[nonblv_index[i]]) or ("Doubtely" in nonblv_df.Q16[nonblv_index[i]]) or ("Inútil" in nonblv_df.Q16[nonblv_index[i]]) or ("Useless" in nonblv_df.Q16[nonblv_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16nonblv_good)
print("(%)", percentage_sub(Q16nonblv_good, nonblv_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16nonblv_bad)
print("(%)", percentage_sub(Q16nonblv_bad, nonblv_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 2
# (%) 100.0
# Participants finding it 'Doubtedly useful' or 'useless': 0
# (%) 0.0

# %%
# Quality of sound
Q17nonblv_good = len([i for i in range(len(nonblv_df)) if (("Buen" in nonblv_df.Q17[nonblv_index[i]]) or ("Muy buen" in nonblv_df.Q17[nonblv_index[i]]) or ("Good" in nonblv_df.Q17[nonblv_index[i]]) or ("Nice" in nonblv_df.Q17[nonblv_index[i]]))])
Q17nonblv_acc = len([i for i in range(len(nonblv_df)) if (("Aceptable" in nonblv_df.Q17[nonblv_index[i]]) or ("Acceptable" in nonblv_df.Q17[nonblv_index[i]]))])
Q17nonblv_bad = len([i for i in range(len(nonblv_df)) if (("Mal" in nonblv_df.Q17[nonblv_index[i]]) or ("Insoportable" in nonblv_df.Q17[nonblv_index[i]]) or ("Bad" in nonblv_df.Q17[nonblv_index[i]]) or ("Intolerable" in nonblv_df.Q17[nonblv_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17nonblv_good)
print("(%)", percentage_sub(Q17nonblv_good, nonblv_counter))
print("Sound Quality 'acceptable':", Q17nonblv_acc)
print("(%)", percentage(Q17nonblv_acc))
print("Sound Quality 'bad' or 'very bad':", Q17nonblv_bad)
print("(%)", percentage_sub(Q17nonblv_bad, nonblv_counter))
# Out:
# Sound Quality 'good' or 'very good': 1
# (%) 50.0
# Sound Quality 'acceptable': 1
# (%) 1.5384615384615385
# Sound Quality 'bad' or 'very bad': 0
# (%) 0.0

# %% [markdown]
# # Global results

# %%
len(data)
# Out:
# 67

# %%
data_total_responses = len(data)-2
print("Total responses after outlier and BLV identification:", data_total_responses)
# Out:
# Total responses after outlier and BLV identification: 65

# %%
data.Q1[14]
# Out:
# 'Sonificación 2'

# %%
Q1G = len([i for i in range(len(data)) if ((data.Q1[i] == data.Q1[0]) or (data.Q1[i] == data.Q1[1]))])-2
Q2G = len([i for i in range(len(data)) if ((data.Q2[i] == data.Q2[0]) or (data.Q2[i] == data.Q2[1]))])-2
Q3G = len([i for i in range(len(data)) if ((data.Q3[i] == data.Q3[0]) or (data.Q3[i] == data.Q3[1]))])-2
Q4G = len([i for i in range(len(data)) if ((data.Q4[i] == data.Q4[0]) or (data.Q4[i] == data.Q4[1]))])-2
Q5G = len([i for i in range(len(data)) if ((data.Q5[i] == data.Q5[0]) or (data.Q5[i] == data.Q5[1]))])-2
Q6G = len([i for i in range(len(data)) if ((data.Q6[i] == data.Q6[0]) or (data.Q6[i] == data.Q6[1]))])-2
Q7G = len([i for i in range(len(data)) if ((data.Q7[i] == data.Q7[0]) or (data.Q7[i] == data.Q7[1]))])-2
Q8G = len([i for i in range(len(data)) if ((data.Q8[i] == data.Q8[0]) or (data.Q8[i] == data.Q8[1]))])-2
Q9G = len([i for i in range(len(data)) if ((data.Q9[i] == data.Q9[0]) or (data.Q9[i] == data.Q9[1]))])-2
Q10G = len([i for i in range(len(data)) if ((data.Q10[i] == data.Q10[0]) or (data.Q10[i] == data.Q10[1]))])-2
Q11G = len([i for i in range(len(data)) if ((data.Q11[i] == data.Q11[0]) or (data.Q11[i] == data.Q11[1]))])-2
Q12G = len([i for i in range(len(data)) if ((data.Q12[i] == data.Q12[0]) or (data.Q12[i] == data.Q12[1]))])-2

data_correct = [Q1G,Q2G,Q3G,Q4G,Q5G,Q6G,Q7G,Q8G,Q9G,Q10G,Q11G,Q12G]
data_correct = np.array(data_correct, int)
data_correct #12 Single response correct results
# Out:
# array([30, 57, 25, 25, 39, 42, 34, 43, 31, 16, 26, 34])

# %%
mean_data_correct = np.mean(data_correct)
print("Total responses: ", data_total_responses)
print("Global success mean:", mean_data_correct/data_total_responses)

success_data_correct = np.sum(data_correct)
attempts_data_correct = 12* data_total_responses
conf_data_correct = astropy.stats.binom_conf_interval(success_data_correct, attempts_data_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_data_correct) # Correct answers interval
# Out:
# Total responses:  65
# Global success mean: 0.5153846153846153
# Jeffreys confidence interval:  [0.49748195 0.53324786]

# %%
glob = pd.Series(data_correct/data_total_responses)

# %%
glob.describe()
# Out:
# count    12.000000
# mean      0.515385
# std       0.165372
# min       0.246154
# 25%       0.396154
# 50%       0.500000
# 75%       0.611538
# max       0.876923
# dtype: float64

# %%
glob.describe()["mean"]
# Out:
# 0.5153846153846154

# %%
glob.to_frame('Global').boxplot(meanline=True, showmeans=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 2 Combined questions

# %%
check_1 = "Lejos"
check_2 = "derecha"
check_3 = "formación"
check_4 = "Far"
check_5 = "Right"
check_6 = "forming"

Q13G = len([i for i in range(len(data)) if ((check_1 in data.Q13[i]) and (check_2 in data.Q13[i]) and (check_3 in data.Q13[i])) or ((check_4 in data.Q13[i]) and (check_5 in data.Q13[i]) and (check_6 in data.Q13[i]))])-2

check_7 = "Cerca"
check_8 = "izquierda"
check_9 = "vieja"
check_10 = "Close"
check_11 = "Left"
check_12 = "Retired"

Q14G = len([i for i in range(len(data)) if ((check_7 in data.Q14[i]) and (check_8 in data.Q14[i]) and (check_9 in data.Q14[i])) or ((check_10 in data.Q14[i]) and (check_11 in data.Q14[i]) and (check_12 in data.Q14[i]))])-2

combined_correct = [Q13G,Q14G]
combined_correct = np.array(combined_correct, int)

combined_correct
# Out:
# array([11, 10])

# %%
mean_combined_correct = np.mean(combined_correct)
print("Global success mean (Combined questions):", mean_combined_correct/data_total_responses)
median_combined_correct = np.median(combined_correct)
print("Global success median (Combined questions):", median_combined_correct/data_total_responses)

success_combined_correct = np.sum(combined_correct)
attempts_combined_correct = 2* data_total_responses
conf_combined_correct = astropy.stats.binom_conf_interval(success_combined_correct, attempts_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_combined_correct) # Correct answers interval
# Out:
# Global success mean (Combined questions): 0.16153846153846155
# Global success median (Combined questions): 0.16153846153846155
# Jeffreys confidence interval:  [0.13190661 0.19635536]

# %%
glob_comb = pd.Series(combined_correct/data_total_responses)
glob_comb.describe()
# Out:
# count    2.000000
# mean     0.161538
# std      0.010879
# min      0.153846
# 25%      0.157692
# 50%      0.161538
# 75%      0.165385
# max      0.169231
# dtype: float64

# %%
glob_comb.to_frame('Combined_Global').boxplot(meanline=True, showmeans=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Qualitative questions

# %%
# Interactivity
Q15G_good = len([i for i in range(len(data)) if (("Buena" in data.Q15[i]) or ("Muy buena" in data.Q15[i]) or ("Good" in data.Q15[i]) or ("Very good" in data.Q15[i]))])
Q15G_acc = len([i for i in range(len(data)) if (("Aceptable" in data.Q15[i]) or ("Acceptable" in data.Q15[i]))])
Q15G_bad = len([i for i in range(len(data)) if (("Mala" in data.Q15[i]) or ("Muy mala" in data.Q15[i]) or ("Bad" in data.Q15[i]) or ("Very bad" in data.Q15[i]))])
Q15G_xxx = len([i for i in range(len(data)) if ("XXX" in data.Q15[i])])
print("Interactivity 'good' or 'very good':", Q15G_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15G_good, data_total_responses - Q15G_xxx))
print("Interactivity 'acceptable':", Q15G_acc)
print("(%)", percentage_sub(Q15G_acc, data_total_responses - Q15G_xxx))
print("Interactivity 'bad' or 'very bad':", Q15G_bad)
print("(%)", percentage_sub(Q15G_bad, data_total_responses - Q15G_xxx))
print("Participants that couldn't test the application in person:", Q15G_xxx)
print("(%)", percentage(Q15G_xxx))
# Out:
# Interactivity 'good' or 'very good': 34
# (%) 80.95238095238095
# Interactivity 'acceptable': 6
# (%) 14.285714285714285
# Interactivity 'bad' or 'very bad': 2
# (%) 4.761904761904762
# Participants that couldn't test the application in person: 23
# (%) 35.38461538461539

# %%
data_total_responses
# Out:
# 65

# %%
# Usefulness
Q16G_good = len([i for i in range(len(data)) if (("Útil" in data.Q16[i]) or ("Muy útil" in data.Q16[i]) or ("Useful" in data.Q16[i]) or ("Very useful" in data.Q16[i]))])
Q16G_bad = len([i for i in range(len(data)) if (("dudosa" in data.Q16[i]) or ("Doubtedly" in data.Q16[i]) or ("Doubtely" in data.Q16[i]) or ("Inútil" in data.Q16[i]) or ("Useless" in data.Q16[i]))])
print("Participants finding it 'useful' or 'very useful':", Q16G_good)
print("(%)", percentage(Q16G_good))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16G_bad)
print("(%)", percentage(Q16G_bad))
# Out:
# Participants finding it 'useful' or 'very useful': 51
# (%) 78.46153846153847
# Participants finding it 'Doubtedly useful' or 'useless': 14
# (%) 21.53846153846154

# %%
# Quality of sound
Q17G_good = len([i for i in range(len(data)) if (("Buen" in data.Q17[i]) or ("Muy buen" in data.Q17[i]) or ("Good" in data.Q17[i]) or ("Nice" in data.Q17[i]))])
Q17G_acc = len([i for i in range(len(data)) if (("Aceptable" in data.Q17[i]) or ("Acceptable" in data.Q17[i]))])
Q17G_bad = len([i for i in range(len(data)) if (("Mal" in data.Q17[i]) or ("Insoportable" in data.Q17[i]) or ("Bad" in data.Q17[i]) or ("Intolerable" in data.Q17[i]))])
print("Sound Quality 'good' or 'very good':", Q17G_good)
print("(%)", percentage(Q17G_good))
print("Sound Quality 'acceptable':", Q17G_acc)
print("(%)", percentage(Q17G_acc))
print("Sound Quality 'bad' or 'very bad':", Q17G_bad)
print("(%)", percentage(Q17G_bad))
# Out:
# Sound Quality 'good' or 'very good': 37
# (%) 56.92307692307692
# Sound Quality 'acceptable': 23
# (%) 35.38461538461539
# Sound Quality 'bad' or 'very bad': 5
# (%) 7.6923076923076925

# %% [markdown]
# ## Demographics

# %%
Astro = len([i for i in range(2,len(data)) if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])))])
Astro_mus_pro = len([i for i in range(2,len(data)) if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])) and (("profesional" in data.Q19[i]) or ("professional" in data.Q19[i])))])
Astro_mus_amt = len([i for i in range(2,len(data)) if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])) and (("experiencia" in data.Q19[i]) or ("experienced" in data.Q19[i])))])
Astro_pro = len([i for i in range(2,len(data)) if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i]))) and not ((("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("experiencia" in data.Q19[i]) or ("experienced" in data.Q19[i])))])
Astro_amt = len([i for i in range(2,len(data)) if ((("entusiasta" in data.Q18[i]) or ("enthusiast" in data.Q18[i]))) and not ((("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("experiencia" in data.Q19[i]) or ("experienced" in data.Q19[i])))])
Mus_pro = len([i for i in range(2,len(data)) if ((("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]))) and not ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i]) or ("entusiasta" in data.Q18[i]) or ("enthusiast" in data.Q18[i])))])
Mus_amt = len([i for i in range(2,len(data)) if ("amateur" in data.Q19[i]) and not (("profesional" in data.Q18[i]) or ("professional" in data.Q18[i]) or ("entusiasta" in data.Q18[i]) or ("enthusiast" in data.Q18[i]))])
Non_exp = data_total_responses - Astro_mus_pro - Astro_mus_amt - Astro_pro - Astro_amt - Mus_pro - Mus_amt
BLV = len([i for i in range(2,len(data)) if ("Yes" in data.Q22[i])]) #included within the professional astronomers group
check = Non_exp + Astro_mus_pro + Astro_mus_amt + Astro_pro + Astro_amt + Mus_pro + Mus_amt 
Astro = len([i for i in range(2,len(data)) if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])))])
Non_astro = len([i for i in range(2,len(data)) if not ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])))])

print("Total number of participants (check):", check)

print("Number of professional astronomers:", Astro)
print("(%)", percentage(Astro))
print("Number of non professional astronomers:", Non_astro)
print("(%)", percentage(Non_astro))


print("------------------SUBGROUPS----------------------")
print("Number of professional astronomers-musicians:", Astro_mus_pro)
print("(%)", percentage(Astro_mus_pro))
print("Number of professional astronomers-amateur musicians:", Astro_mus_amt)
print("(%)", percentage(Astro_mus_amt))
print("Number of professional astronomers:", Astro_pro)
print("(%)", percentage(Astro_pro))
print("Number of amateur astronomers:", Astro_amt)
print("(%)", percentage(Astro_amt))
print("Number of professional musicians non-astronomers(professional and amateur):", Mus_pro)
print("(%)", percentage(Mus_pro))
print("Number of amateur musicians non-astronomers(professional and amateur):", Mus_amt)
print("(%)", percentage(Mus_amt))
print("Number of non-experienced:", Non_exp)
print("(%)", percentage(Non_exp))
print("Number of BLV participants:", BLV)
print("(%)", percentage(BLV))
# Out:
# Total number of participants (check): 65
# Number of professional astronomers: 29
# (%) 44.61538461538462
# Number of non professional astronomers: 36
# (%) 55.38461538461539
# ------------------SUBGROUPS----------------------
# Number of professional astronomers-musicians: 1
# (%) 1.5384615384615385
# Number of professional astronomers-amateur musicians: 15
# (%) 23.076923076923077
# Number of professional astronomers: 14
# (%) 21.53846153846154
# Number of amateur astronomers: 5
# (%) 7.6923076923076925
# Number of professional musicians non-astronomers(professional and amateur): 4
# (%) 6.153846153846154
# Number of amateur musicians non-astronomers(professional and amateur): 4
# (%) 6.153846153846154
# Number of non-experienced: 22
# (%) 33.84615384615385
# Number of BLV participants: 0
# (%) 0.0

# %%
#Participants' age range
Q21G_21 = len([i for i in range(len(data)) if (("Menos" in data.Q21[i]) or ("Under" in data.Q21[i]))])
Q21G_21_30 = len([i for i in range(len(data)) if (("21-30" in data.Q21[i]))])
Q21G_31_40 = len([i for i in range(len(data)) if (("31-40" in data.Q21[i]))])
Q21G_41_50 = len([i for i in range(len(data)) if (("41-50" in data.Q21[i]))])
Q21G_51_60 = len([i for i in range(len(data)) if (("51-60" in data.Q21[i]))])
Q21G_60 = len([i for i in range(len(data)) if (("Más" in data.Q21[i]) or ("Over" in data.Q21[i]))])

print("Number of participants under 21:", Q21G_21)
print("(%)", percentage(Q21G_21))
print("Number of participants between 21 and 30 :", Q21G_21_30)
print("(%)", percentage(Q21G_21_30))
print("Number of participants between 31 and 40 :", Q21G_31_40)
print("(%)", percentage(Q21G_31_40))
print("Number of participants between 41 and 50 :", Q21G_41_50)
print("(%)", percentage(Q21G_41_50))
print("Number of participants between 51 and 60 :", Q21G_51_60)
print("(%)", percentage(Q21G_51_60))
print("Number of participants over 60 :", Q21G_60)
print("(%)", percentage(Q21G_60))
# Out:
# Number of participants under 21: 1
# (%) 1.5384615384615385
# Number of participants between 21 and 30 : 18
# (%) 27.692307692307693
# Number of participants between 31 and 40 : 9
# (%) 13.846153846153847
# Number of participants between 41 and 50 : 19
# (%) 29.230769230769234
# Number of participants between 51 and 60 : 6
# (%) 9.230769230769232
# Number of participants over 60 : 10
# (%) 15.384615384615385

# %% [markdown]
# ## Appending Global results

# %%
column_list = ["Global", "Astrónomos", "No astrónomos", "Astro y Mus", "Astro no Mus", "Mus no Astro", "Sin experiencia", "BLV", "No BLV"]
participants_list = []
success_list = []
Jeff_low_list = []
Jeff_high_list = []
std_list = []
comb_success_list = []
comb_Jeff_low_list = []
comb_Jeff_high_list = []
comb_std_list = []
interactivity_list = []
useful_list = []
sound_list = []

# %%
participants_list.append(data_total_responses)
success_list.append(glob.describe()["mean"])
Jeff_low_list.append(conf_data_correct[0])
Jeff_high_list.append(conf_data_correct[1])
std_list.append(glob.describe()["std"])
comb_success_list.append(glob_comb.describe()["mean"])
comb_Jeff_low_list.append(conf_combined_correct[0])
comb_Jeff_high_list.append(conf_combined_correct[1])
comb_std_list.append(glob_comb.describe()["std"])
interactivity_list.append(percentage_sub(Q15G_good, data_total_responses - Q15G_xxx))
useful_list.append(percentage(Q16G_good))
sound_list.append(percentage(Q17G_good))

# %% [markdown]
# # Experts: Professional astronomers

# %%
experts_list = []
experts_index = []
experts_counter = 0
for i in range(len(data)):
    if (("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])):
        experts_counter += 1
        current_row = data.iloc[i]
        experts_list.append(current_row)
        experts_index.append(i)
        
print("Number of Professional astronomers:", experts_counter)
experts_df = pd.DataFrame(experts_list)
experts_df
# Out:
# Number of Professional astronomers: 29
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 2            1   1.0  4/18/24 10:01:49  4/18/24 10:26:12  anonymous
# 5            4   4.0  4/18/24 16:09:19  4/18/24 17:34:52  anonymous
# 16          15  15.0  4/23/24 12:44:04  4/23/24 13:08:00  anonymous
# 20          19  19.0  4/25/24 11:19:03  4/25/24 11:32:28  anonymous
# 21          20  20.0  4/25/24 11:30:57  4/25/24 11:46:09  anonymous
# 22          21  21.0  4/25/24 14:36:30  4/25/24 15:03:00  anonymous
# 29          28  28.0  4/29/24 11:22:35  4/29/24 11:31:38  anonymous
# 32          31  31.0   5/2/24 18:31:56   5/2/24 18:51:31  anonymous
# 35          34  34.0   5/6/24 11:21:54   5/6/24 11:42:11  anonymous
# 37          36  36.0   5/24/24 1:59:41   5/24/24 4:34:47  anonymous
# 39          38  38.0  5/26/24 21:53:07  5/26/24 22:10:15  anonymous
# 40          39  39.0  6/14/24 12:39:07  6/14/24 19:32:03  anonymous
# 41          40  40.0  6/24/24 18:07:27  6/24/24 18:18:36  anonymous
# 42          41   1.0   4/25/24 9:19:19   4/25/24 9:23:16  anonymous
# 43          42   2.0   4/25/24 9:45:02  4/25/24 12:17:33  anonymous
# 44          43   3.0  4/25/24 11:55:21  4/25/24 12:18:21  anonymous
# 45          44   4.0  4/26/24 23:27:16   4/27/24 0:15:56  anonymous
# 46          45   5.0  4/27/24 10:16:07  4/27/24 10:37:46  anonymous
# 48          47   2.0  4/17/24 11:32:00  4/17/24 12:09:06  anonymous
# 49          48   3.0   4/26/24 4:40:27   4/26/24 5:03:39  anonymous
# 50          49   4.0   5/2/24 17:18:28   5/2/24 17:35:06  anonymous
# 51          50   5.0   5/2/24 20:11:15   5/2/24 20:28:04  anonymous
# 53          52   7.0   6/1/24 10:16:23   6/1/24 10:29:00  anonymous
# 55          54   9.0  6/24/24 16:27:17  6/24/24 16:46:13  anonymous
# 56          55  10.0   6/25/24 9:48:12  6/25/24 10:04:54  anonymous
# 58          57  12.0   7/2/24 10:56:21   7/2/24 11:13:48  anonymous
# 59          58  13.0   7/2/24 16:31:37   7/2/24 16:55:08  anonymous
# 62          61  16.0  7/18/24 16:24:37  7/18/24 16:39:13  anonymous
# 66          66   1.0  5/13/24 11:17:19  5/13/24 11:33:10  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 2   Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 5   Sonificación 2  A la izquierda  Sonificación 3  Sonificación 3
# 16  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 20  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 21  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 22  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 29  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 32  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 35  Sonificación 2    A la derecha  Sonificación 2  Sonificación 2
# 37  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 39  Sonificación 2    A la derecha  Sonificación 1  Sonificación 2
# 40  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 41  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 1
# 42  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 43  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 44  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 45  Sonificación 2  A la izquierda  Sonificación 1  Sonificación 4
# 46  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 48  Sonification 1            Left  Sonification 2  Sonification 2
# 49  Sonification 1           Right  Sonification 2  Sonification 1
# 50  Sonification 1            Left  Sonification 2  Sonification 4
# 51  Sonification 1            Left  Sonification 3  Sonification 2
# 53  Sonification 1            Left  Sonification 2  Sonification 2
# 55  Sonification 2            Left  Sonification 4  Sonification 2
# 56  Sonification 1            Left  Sonification 2  Sonification 3
# 58  Sonification 1            Left  Sonification 2  Sonification 3
# 59  Sonification 1            Left  Sonification 2  Sonification 1
# 62  Sonification 1            Left  Sonification 3  Sonification 2
# 66  Sonification 2            Left  Sonification 2  Sonification 2
#
#             Q5  ...                              Q18  \
# 2   Espectro 1  ...  Mucha experiencia (profesional)
# 5   Espectro 1  ...  Mucha experiencia (profesional)
# 16  Espectro 1  ...  Mucha experiencia (profesional)
# 20  Espectro 2  ...  Mucha experiencia (profesional)
# 21  Espectro 2  ...  Mucha experiencia (profesional)
# 22  Espectro 2  ...  Mucha experiencia (profesional)
# 29  Espectro 2  ...  Mucha experiencia (profesional)
# 32  Espectro 2  ...  Mucha experiencia (profesional)
# 35  Espectro 2  ...  Mucha experiencia (profesional)
# 37  Espectro 2  ...  Mucha experiencia (profesional)
# 39  Espectro 1  ...  Mucha experiencia (profesional)
# 40  Espectro 2  ...  Mucha experiencia (profesional)
# 41  Espectro 1  ...  Mucha experiencia (profesional)
# 42  Espectro 3  ...  Mucha experiencia (profesional)
# 43  Espectro 2  ...  Mucha experiencia (profesional)
# 44  Espectro 2  ...  Mucha experiencia (profesional)
# 45  Espectro 1  ...  Mucha experiencia (profesional)
# 46  Espectro 2  ...  Mucha experiencia (profesional)
# 48  Spectrum 1  ...  Very experienced (professional)
# 49  Spectrum 2  ...  Very experienced (professional)
# 50  Spectrum 2  ...  Very experienced (professional)
# 51  Spectrum 2  ...  Very experienced (professional)
# 53  Spectrum 2  ...  Very experienced (professional)
# 55  Spectrum 2  ...  Very experienced (professional)
# 56  Spectrum 2  ...  Very experienced (professional)
# 58  Spectrum 2  ...  Very experienced (professional)
# 59  Spectrum 2  ...  Very experienced (professional)
# 62  Spectrum 3  ...  Very experienced (professional)
# 66  Spectrum 2  ...  Very experienced (professional)
#
#                                        Q19  \
# 2                                  Ninguna
# 5                               Muy básica
# 16          Bastante experiencia (amateur)
# 20                                 Ninguna
# 21                              Muy básica
# 22  Algo de experiencia (hobby/entusiasta)
# 29  Algo de experiencia (hobby/entusiasta)
# 32          Bastante experiencia (amateur)
# 35          Bastante experiencia (amateur)
# 37  Algo de experiencia (hobby/entusiasta)
# 39          Bastante experiencia (amateur)
# 40                              Muy básica
# 41  Algo de experiencia (hobby/entusiasta)
# 42                              Muy básica
# 43  Algo de experiencia (hobby/entusiasta)
# 44                              Muy básica
# 45                                 Ninguna
# 46          Bastante experiencia (amateur)
# 48                         Not experienced
# 49                   Experienced (amateur)
# 50                   Experienced (amateur)
# 51     Some experienced (hobby/enthusiast)
# 53                   Experienced (amateur)
# 55                   Very basic experience
# 56                   Very basic experience
# 58     Some experienced (hobby/enthusiast)
# 59                         Not experienced
# 62         Very experienced (professional)
# 66                   Experienced (amateur)
#
#                                                   Q20        Q21 Q22  \
# 2                                               Blues      31-40  No
# 5                                             clásica      51-60  No
# 16                         Clasica, Jazz, Cantautores      41-50  No
# 20                                    Techno melódico      21-30  No
# 21  Pop, rock, música española/latina y francesa, ...      21-30  No
# 22                                      jazz, clásica      41-50  No
# 29                  Música clásica, latino, pop-rock.      21-30  No
# 32                                               Jazz      41-50  No
# 35                                      Clásica y pop      51-60  No
# 37        Clásica, Rock, Electrónica, un poco de todo      41-50  No
# 39                                               Rock      41-50  No
# 40                                               Rock      41-50  No
# 41                                  Rock, Blues, Jazz      21-30  No
# 42                                               Toda      41-50  No
# 43                                     Música clásica      41-50  No
# 44              Rock suave, reggae, hip-hop, flamenco      21-30  No
# 45                                               Rock      41-50  No
# 46                                           Clásica   Más de 60  No
# 48                         Rock, trash, grunge, metal      31-40  No
# 49                                   Rock, folk, jazz      31-40  No
# 50                                   classical, indie      41-50  No
# 51                                    Classical. Rock    Over 60  No
# 53                            Classical but also rock      41-50  No
# 55                                               rock      21-30  No
# 56                              Chinese Ancient Music      21-30  No
# 58                Electronic music / alternative rock      21-30  No
# 59                                                Pop      41-50  No
# 62     Electronic Music, Jazz, Classical, Folk, Rock       41-50  No
# 66                                         Electronic      31-40  No
#
#                 Q23                  Q24                       Q25  \
# 2            España              Español  Sí, utilicé auriculares.
# 5            España           Castellano  Sí, utilicé auriculares.
# 16           España             Italiano  Sí, utilicé auriculares.
# 20           España              Español  Sí, utilicé auriculares.
# 21           España             Francés   Sí, utilicé auriculares.
# 22           españa              español  Sí, utilicé auriculares.
# 29           España              Español  Sí, utilicé auriculares.
# 32           España              Español  Sí, utilicé auriculares.
# 35           España              Español  Sí, utilicé auriculares.
# 37           España              español  Sí, utilicé auriculares.
# 39           España              Español           No, no lo hice.
# 40           España             italiano  Sí, utilicé auriculares.
# 41           España              Español  Sí, utilicé auriculares.
# 42           España              Español           No, no lo hice.
# 43            Spain             Catalan   Sí, utilicé auriculares.
# 44           España  Euskara, Castellano  Sí, utilicé auriculares.
# 45           España              Español           No, no lo hice.
# 46          España               Español  Sí, utilicé auriculares.
# 48            Spain              Spanish    Yes, I used headphones
# 49            Spain                Greek    Yes, I used headphones
# 50           Canada              Swedish    Yes, I used headphones
# 51    United States              English    Yes, I used headphones
# 53          Germany              Spanish    Yes, I used headphones
# 55            China              Chinese              No, I didn't
# 56            China              Chinese    Yes, I used headphones
# 58            Spain              Spanish    Yes, I used headphones
# 59            Spain              Persian    Yes, I used headphones
# 62            Malta              English    Yes, I used headphones
# 66  United Kingdom               English    Yes, I used headphones
#
#                           Q26  \
# 2          Audio 3D / Gaming;
# 5          Audio 3D / Gaming;
# 16                   Estéreo;
# 20    Estéreo;Circum-aurales;
# 21         Audio 3D / Gaming;
# 22            Circum-aurales;
# 29             Intra-aurales;
# 32                   Estéreo;
# 35                   Estéreo;
# 37                   Estéreo;
# 39                 No lo sé.;
# 40                   Estéreo;
# 41             Intra-aurales;
# 42                 No lo sé.;
# 43    Estéreo;Circum-aurales;
# 44         Audio 3D / Gaming;
# 45                 No lo sé.;
# 46     Intra-aurales;Estéreo;
# 48                        x-x
# 49               Intra-aural;
# 50  Intra-aural;I don't know;
# 51                    Stereo;
# 53                    Stereo;
# 55              I don't know;
# 56              I don't know;
# 58                    Stereo;
# 59                    Stereo;
# 62                    Stereo;
# 66                    Stereo;
#
#                                                   Q27
# 2                                       Gran trabajo!
# 5                                                 x-x
# 16                                                x-x
# 20    Todo mi apoyo para este proyecto tan necesario!
# 21                                                x-x
# 22                                                x-x
# 29                                                x-x
# 32  La diferencia entre zona con formación estelar...
# 35  Salvo la posición de los sonidos, las demás ca...
# 37            Un trabajo muy interesante. Enhorabuena
# 39                                                x-x
# 40                                                x-x
# 41                                                x-x
# 42                                                x-x
# 43                                                x-x
# 44  Me hubiese ayudado una explicación más detalla...
# 45                                                x-x
# 46                                                x-x
# 48                                                x-x
# 49  The localization was not very easy to distinct...
# 50  It was fairly easy in the beginning, but I had...
# 51  Use the word Pitch instead of Reverberation --...
# 53                                                x-x
# 55                                                x-x
# 56                                                x-x
# 58                                                x-x
# 59                                                x-x
# 62                                                x-x
# 66                                                x-x
#
# [29 rows x 32 columns]

# %%
grades_experts = []
for i in range(len(experts_df)):
    grade = 0
    if (experts_df.Q1[experts_index[i]] == (data.Q1[0]) or (experts_df.Q1[experts_index[i]] == data.Q1[1])):
        grade += 1
    if (experts_df.Q2[experts_index[i]] == (data.Q2[0]) or (experts_df.Q2[experts_index[i]] == data.Q2[1])):
        grade += 1 
    if (experts_df.Q3[experts_index[i]] == (data.Q3[0]) or (experts_df.Q3[experts_index[i]] == data.Q3[1])):
        grade += 1
    if (experts_df.Q4[experts_index[i]] == (data.Q4[0]) or (experts_df.Q4[experts_index[i]] == data.Q4[1])):
        grade += 1    
    if (experts_df.Q5[experts_index[i]] == (data.Q5[0]) or (experts_df.Q5[experts_index[i]] == data.Q5[1])):
        grade += 1
    if (experts_df.Q6[experts_index[i]] == (data.Q6[0]) or (experts_df.Q6[experts_index[i]] == data.Q6[1])):
        grade += 1    
    if (experts_df.Q7[experts_index[i]] == (data.Q7[0]) or (experts_df.Q7[experts_index[i]] == data.Q7[1])):
        grade += 1
    if (experts_df.Q8[experts_index[i]] == (data.Q8[0]) or (experts_df.Q8[experts_index[i]] == data.Q8[1])):
        grade += 1    
    if (experts_df.Q9[experts_index[i]] == (data.Q9[0]) or (experts_df.Q9[experts_index[i]] == data.Q9[1])):
        grade += 1
    if (experts_df.Q10[experts_index[i]] == (data.Q10[0]) or (experts_df.Q10[experts_index[i]] == data.Q10[1])):
        grade += 1    
    if (experts_df.Q11[experts_index[i]] == (data.Q11[0]) or (experts_df.Q11[experts_index[i]] == data.Q11[1])):
        grade += 1
    if (experts_df.Q12[experts_index[i]] == (data.Q12[0]) or (experts_df.Q12[experts_index[i]] == data.Q12[1])):
        grade += 1      
    grades_experts.append(grade)
mode_experts = scistats.mode(grades_experts)
print("Grades experts:", grades_experts)    
print("Mean:", np.mean(grades_experts))
print("Median:", np.median(grades_experts))
print("Most frequent result:", mode_experts)
# Out:
# Grades experts: [8, 4, 8, 7, 9, 6, 7, 8, 5, 8, 6, 7, 6, 5, 5, 11, 5, 6, 6, 4, 7, 7, 8, 6, 10, 5, 6, 6, 7]
# Mean: 6.655172413793103
# Median: 6.0
# Most frequent result: ModeResult(mode=array([6]), count=array([8]))

# %%
Q1E = len([i for i in range(len(experts_df)) if ((experts_df.Q1[experts_index[i]] == data.Q1[0]) or (experts_df.Q1[experts_index[i]] == data.Q1[1]))])
Q2E = len([i for i in range(len(experts_df)) if ((experts_df.Q2[experts_index[i]] == data.Q2[0]) or (experts_df.Q2[experts_index[i]] == data.Q2[1]))])
Q3E = len([i for i in range(len(experts_df)) if ((experts_df.Q3[experts_index[i]] == data.Q3[0]) or (experts_df.Q3[experts_index[i]] == data.Q3[1]))])
Q4E = len([i for i in range(len(experts_df)) if ((experts_df.Q4[experts_index[i]] == data.Q4[0]) or (experts_df.Q4[experts_index[i]] == data.Q4[1]))])
Q5E = len([i for i in range(len(experts_df)) if ((experts_df.Q5[experts_index[i]] == data.Q5[0]) or (experts_df.Q5[experts_index[i]] == data.Q5[1]))])
Q6E = len([i for i in range(len(experts_df)) if ((experts_df.Q6[experts_index[i]] == data.Q6[0]) or (experts_df.Q6[experts_index[i]] == data.Q6[1]))])
Q7E = len([i for i in range(len(experts_df)) if ((experts_df.Q7[experts_index[i]] == data.Q7[0]) or (experts_df.Q7[experts_index[i]] == data.Q7[1]))])
Q8E = len([i for i in range(len(experts_df)) if ((experts_df.Q8[experts_index[i]] == data.Q8[0]) or (experts_df.Q8[experts_index[i]] == data.Q8[1]))])
Q9E = len([i for i in range(len(experts_df)) if ((experts_df.Q9[experts_index[i]] == data.Q9[0]) or (experts_df.Q9[experts_index[i]] == data.Q9[1]))])
Q10E = len([i for i in range(len(experts_df)) if ((experts_df.Q10[experts_index[i]] == data.Q10[0]) or (experts_df.Q10[experts_index[i]] == data.Q10[1]))])
Q11E = len([i for i in range(len(experts_df)) if ((experts_df.Q11[experts_index[i]] == data.Q11[0]) or (experts_df.Q11[experts_index[i]] == data.Q11[1]))])
Q12E = len([i for i in range(len(experts_df)) if ((experts_df.Q12[experts_index[i]] == data.Q12[0]) or (experts_df.Q12[experts_index[i]] == data.Q12[1]))])

experts_correct = [Q1E,Q2E,Q3E,Q4E,Q5E,Q6E,Q7E,Q8E,Q9E,Q10E,Q11E,Q12E]
experts_correct = np.array(experts_correct, int)
experts_correct #12 Single response correct results
# Out:
# array([15, 26, 11, 14, 20, 20, 16, 22, 15,  7, 12, 15])

# %%
experts_total_responses = len(experts_df)
mean_experts_correct = np.mean(experts_correct)
print("Total responses: ", experts_total_responses)
print("Professional astronomers success mean:", mean_experts_correct/experts_total_responses)

success_experts_correct = np.sum(experts_correct)
attempts_experts_correct = 12* experts_total_responses
conf_experts_correct = astropy.stats.binom_conf_interval(success_experts_correct, attempts_experts_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_experts_correct) # Correct answers interval
# Out:
# Total responses:  29
# Professional astronomers success mean: 0.5545977011494252
# Jeffreys confidence interval:  [0.52783643 0.58104573]

# %%
experts = pd.Series(experts_correct/experts_total_responses)
experts.describe()
# Out:
# count    12.000000
# mean      0.554598
# std       0.179153
# min       0.241379
# 25%       0.465517
# 50%       0.517241
# 75%       0.689655
# max       0.896552
# dtype: float64

# %%
Q13E = len([i for i in range(len(experts_df)) if ((check_1 in experts_df.Q13[experts_index[i]]) and (check_2 in experts_df.Q13[experts_index[i]]) and (check_3 in experts_df.Q13[experts_index[i]])) or ((check_4 in experts_df.Q13[experts_index[i]]) and (check_5 in experts_df.Q13[experts_index[i]]) and (check_6 in experts_df.Q13[experts_index[i]]))])
Q14E = len([i for i in range(len(experts_df)) if ((check_7 in experts_df.Q14[experts_index[i]]) and (check_8 in experts_df.Q14[experts_index[i]]) and (check_9 in experts_df.Q14[experts_index[i]])) or ((check_10 in experts_df.Q14[experts_index[i]]) and (check_11 in experts_df.Q14[experts_index[i]]) and (check_12 in experts_df.Q14[experts_index[i]]))])

experts_combined_correct = [Q13E,Q14E]
experts_combined_correct = np.array(experts_combined_correct, int)

experts_combined_correct
# Out:
# array([7, 2])

# %%
mean_experts_combined_correct = np.mean(experts_combined_correct)
print("Professional astronomers success mean (Combined questions):", mean_experts_combined_correct/experts_total_responses)
success_experts_combined_correct = np.sum(experts_combined_correct)
attempts_experts_combined_correct = 2* experts_total_responses
conf_experts_combined_correct = astropy.stats.binom_conf_interval(success_experts_combined_correct, attempts_experts_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_experts_combined_correct) # Correct answers interval
# Out:
# Professional astronomers success mean (Combined questions): 0.15517241379310345
# Jeffreys confidence interval:  [0.11367855 0.20844441]

# %%
experts_combined = pd.Series(experts_combined_correct/experts_total_responses)
experts_combined.describe()
# Out:
# count    2.000000
# mean     0.155172
# std      0.121915
# min      0.068966
# 25%      0.112069
# 50%      0.155172
# 75%      0.198276
# max      0.241379
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15E_good = len([i for i in range(len(experts_df)) if (("Buena" in experts_df.Q15[experts_index[i]]) or ("Muy buena" in experts_df.Q15[experts_index[i]]) or ("Good" in experts_df.Q15[experts_index[i]]) or ("Very good" in experts_df.Q15[experts_index[i]]))])
Q15E_acc = len([i for i in range(len(experts_df)) if (("Aceptable" in experts_df.Q15[experts_index[i]]) or ("Acceptable" in experts_df.Q15[experts_index[i]]))])
Q15E_bad = len([i for i in range(len(experts_df)) if (("Mala" in experts_df.Q15[experts_index[i]]) or ("Muy mala" in experts_df.Q15[experts_index[i]]) or ("Bad" in experts_df.Q15[experts_index[i]]) or ("Very bad" in experts_df.Q15[experts_index[i]]))])
Q15E_xxx = len([i for i in range(len(experts_df)) if (("XXX" in experts_df.Q15[experts_index[i]]))])
print("Interactivity 'good' or 'very good':", Q15E_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15E_good, experts_counter - Q15E_xxx))
print("Interactivity 'acceptable':", Q15E_acc)
print("(%)", percentage_sub(Q15E_acc, experts_counter - Q15E_xxx))
print("Interactivity 'bad' or 'very bad':", Q15E_bad)
print("(%)", percentage_sub(Q15E_bad, experts_counter - Q15E_xxx))
print("Participants that couldn't test the application in person:", Q15E_xxx)
print("(%)", percentage_sub(Q15E_xxx, experts_counter))
# Out:
# Interactivity 'good' or 'very good': 16
# (%) 76.19047619047619
# Interactivity 'acceptable': 3
# (%) 14.285714285714285
# Interactivity 'bad' or 'very bad': 2
# (%) 9.523809523809524
# Participants that couldn't test the application in person: 8
# (%) 27.586206896551722

# %%
# Usefulness
Q16E_good = len([i for i in range(len(experts_df)) if (("Útil" in experts_df.Q16[experts_index[i]]) or ("Muy útil" in experts_df.Q16[experts_index[i]]) or ("Useful" in experts_df.Q16[experts_index[i]]) or ("Very useful" in experts_df.Q16[experts_index[i]]))])
Q16E_bad = len([i for i in range(len(experts_df)) if (("dudosa" in experts_df.Q16[experts_index[i]]) or ("Doubtedly" in experts_df.Q16[experts_index[i]]) or ("Doubtely" in experts_df.Q16[experts_index[i]]) or ("Inútil" in experts_df.Q16[experts_index[i]]) or ("Useless" in experts_df.Q16[experts_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16E_good)
print("(%)", percentage_sub(Q16E_good, experts_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16E_bad)
print("(%)", percentage_sub(Q16E_bad, experts_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 21
# (%) 72.41379310344827
# Participants finding it 'Doubtedly useful' or 'useless': 8
# (%) 27.586206896551722

# %%
# Quality of sound
Q17E_good = len([i for i in range(len(experts_df)) if (("Buen" in experts_df.Q17[experts_index[i]]) or ("Muy buen" in experts_df.Q17[experts_index[i]]) or ("Good" in experts_df.Q17[experts_index[i]]) or ("Nice" in experts_df.Q17[experts_index[i]]))])
Q17E_acc = len([i for i in range(len(experts_df)) if (("Aceptable" in experts_df.Q17[experts_index[i]]) or ("Acceptable" in experts_df.Q17[experts_index[i]]))])
Q17E_bad = len([i for i in range(len(experts_df)) if (("Mal" in experts_df.Q17[experts_index[i]]) or ("Insoportable" in experts_df.Q17[experts_index[i]]) or ("Bad" in experts_df.Q17[experts_index[i]]) or ("Intolerable" in experts_df.Q17[experts_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17E_good)
print("(%)", percentage_sub(Q17E_good, experts_counter))
print("Sound Quality 'acceptable':", Q17E_acc)
print("(%)", percentage(Q17E_acc))
print("Sound Quality 'bad' or 'very bad':", Q17E_bad)
print("(%)", percentage_sub(Q17E_bad, experts_counter))
# Out:
# Sound Quality 'good' or 'very good': 14
# (%) 48.275862068965516
# Sound Quality 'acceptable': 12
# (%) 18.461538461538463
# Sound Quality 'bad' or 'very bad': 3
# (%) 10.344827586206897

# %% [markdown]
# ## Appending results

# %%
participants_list.append(experts_counter)
success_list.append(experts.describe()["mean"])
Jeff_low_list.append(conf_experts_correct[0])
Jeff_high_list.append(conf_experts_correct[1])
std_list.append(experts.describe()["std"])
comb_success_list.append(experts_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_experts_combined_correct[0])
comb_Jeff_high_list.append(conf_experts_combined_correct[1])
comb_std_list.append(experts_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15E_good, experts_counter - Q15E_xxx))
useful_list.append(percentage_sub(Q16E_good, experts_counter))
sound_list.append(percentage_sub(Q17E_good, experts_counter))

# %% [markdown]
# # Non experts. Non-professional astronomers

# %%
nonExperts_list = []
nonExperts_index = []
nonExperts_counter = 0
for i in range(2,len(data)):
    if not (("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])):
        nonExperts_counter += 1
        current_row = data.iloc[i]
        nonExperts_list.append(current_row)
        nonExperts_index.append(i)
        
print("Number of Non-professional astronomers:", nonExperts_counter)
nonExperts_df = pd.DataFrame(nonExperts_list)
nonExperts_df
# Out:
# Number of Non-professional astronomers: 36
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 3            2   2.0  4/18/24 14:48:33  4/18/24 15:19:46  anonymous
# 4            3   3.0  4/18/24 17:14:38  4/18/24 17:21:38  anonymous
# 6            5   5.0  4/18/24 21:15:36  4/18/24 21:19:42  anonymous
# 7            6   6.0  4/18/24 18:10:42  4/18/24 21:23:00  anonymous
# 8            7   7.0  4/18/24 21:09:34  4/18/24 21:41:59  anonymous
# 9            8   8.0  4/18/24 21:31:33  4/18/24 21:43:57  anonymous
# 10           9   9.0  4/18/24 23:02:44  4/18/24 23:17:20  anonymous
# 11          10  10.0  4/18/24 23:21:02  4/18/24 23:30:11  anonymous
# 12          11  11.0  4/19/24 10:07:08  4/19/24 10:14:43  anonymous
# 13          12  12.0  4/20/24 12:25:14  4/20/24 12:34:51  anonymous
# 14          13  13.0  4/22/24 22:03:27  4/22/24 22:09:19  anonymous
# 15          14  14.0  4/23/24 12:13:07  4/23/24 12:56:30  anonymous
# 17          16  16.0  4/24/24 13:08:29  4/24/24 13:33:33  anonymous
# 18          17  17.0  4/24/24 20:09:26  4/24/24 20:17:02  anonymous
# 19          18  18.0  4/24/24 21:49:28  4/24/24 22:03:07  anonymous
# 23          22  22.0  4/25/24 16:04:38  4/25/24 16:19:51  anonymous
# 24          23  23.0  4/26/24 12:04:50  4/26/24 12:17:55  anonymous
# 25          24  24.0  4/26/24 19:24:11  4/26/24 19:40:14  anonymous
# 26          25  25.0  4/26/24 21:38:11  4/26/24 21:55:22  anonymous
# 27          26  26.0  4/26/24 19:53:36   4/27/24 0:52:27  anonymous
# 28          27  27.0  4/27/24 23:28:51  4/27/24 23:58:21  anonymous
# 30          29  29.0  4/30/24 11:11:36  4/30/24 11:37:53  anonymous
# 31          30  30.0   5/2/24 14:19:24   5/2/24 14:47:41  anonymous
# 33          32  32.0   5/3/24 12:31:43   5/3/24 13:15:07  anonymous
# 34          33  33.0   5/5/24 23:19:51   5/5/24 23:38:24  anonymous
# 36          35  35.0   5/8/24 22:32:24   5/8/24 22:47:20  anonymous
# 38          37  37.0  5/25/24 11:00:56  5/25/24 11:10:50  anonymous
# 47          46   1.0   4/17/24 9:12:01   4/17/24 9:28:15  anonymous
# 52          51   6.0   5/27/24 2:29:28   5/27/24 2:57:48  anonymous
# 54          53   8.0  6/23/24 15:32:58  6/23/24 16:18:51  anonymous
# 57          56  11.0   6/26/24 6:39:03   6/26/24 7:09:03  anonymous
# 60          59  14.0  7/14/24 15:25:48  7/14/24 15:51:10  anonymous
# 61          60  15.0   7/17/24 2:20:03   7/17/24 3:10:00  anonymous
# 63          62  17.0   7/21/24 9:56:47  7/21/24 10:55:44  anonymous
# 64          63  18.0   7/25/24 1:49:37   7/25/24 3:03:34  anonymous
# 65          64  19.0  7/29/24 10:32:28  7/29/24 10:50:09  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 3   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 4
# 4   Sonificación 2  A la izquierda  Sonificación 2  Sonificación 1
# 6   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 7   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 4
# 8   Sonificación 2    A la derecha  Sonificación 2  Sonificación 3
# 9   Sonificación 2  A la izquierda  Sonificación 4  Sonificación 1
# 10  Sonificación 1    A la derecha  Sonificación 3  Sonificación 4
# 11  Sonificación 2  A la izquierda  Sonificación 4  Sonificación 1
# 12  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 13  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 3
# 14  Sonificación 2    A la derecha  Sonificación 1  Sonificación 3
# 15  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 17  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 18  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 3
# 19  Sonificación 1  A la izquierda  Sonificación 1  Sonificación 4
# 23  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 24  Sonificación 1    A la derecha  Sonificación 1  Sonificación 3
# 25  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 26  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 3
# 27  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 28  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 30  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 31  Sonificación 2    A la derecha  Sonificación 3  Sonificación 2
# 33  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 34  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 36  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 38  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 47  Sonification 2            Left  Sonification 3  Sonification 3
# 52  Sonification 2            Left  Sonification 3  Sonification 2
# 54  Sonification 1            Left  Sonification 2  Sonification 1
# 57  Sonification 2            Left  Sonification 2  Sonification 2
# 60  Sonification 2            Left  Sonification 3  Sonification 3
# 61  Sonification 2            Left  Sonification 3  Sonification 1
# 63  Sonification 2            Left  Sonification 3  Sonification 2
# 64  Sonification 1            Left  Sonification 2  Sonification 2
# 65  Sonification 2            Left  Sonification 2  Sonification 3
#
#             Q5  ...                                     Q18  \
# 3   Espectro 1  ...  Algo de experiencia (hobby/entusiasta)
# 4   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# 6   Espectro 2  ...                                 Ninguna
# 7   Espectro 1  ...                                 Ninguna
# 8   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# 9   Espectro 1  ...  Algo de experiencia (hobby/entusiasta)
# 10  Espectro 2  ...                                 Ninguna
# 11  Espectro 1  ...                                 Ninguna
# 12  Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# 13  Espectro 2  ...                                 Ninguna
# 14  Espectro 3  ...                                 Ninguna
# 15  Espectro 3  ...                                 Ninguna
# 17  Espectro 2  ...                                 Ninguna
# 18  Espectro 1  ...                                 Ninguna
# 19  Espectro 3  ...                                 Ninguna
# 23  Espectro 1  ...                                 Ninguna
# 24  Espectro 2  ...                                 Ninguna
# 25  Espectro 2  ...                                 Ninguna
# 26  Espectro 1  ...                                 Ninguna
# 27  Espectro 2  ...                                 Ninguna
# 28  Espectro 2  ...                                 Ninguna
# 30  Espectro 2  ...                                 Ninguna
# 31  Espectro 2  ...                                 Ninguna
# 33  Espectro 2  ...  Algo de experiencia (hobby/entusiasta)
# 34  Espectro 2  ...                                 Ninguna
# 36  Espectro 1  ...                                 Ninguna
# 38  Espectro 2  ...  Algo de experiencia (hobby/entusiasta)
# 47  Spectrum 2  ...                          No experienced
# 52  Spectrum 1  ...                          No experienced
# 54  Spectrum 3  ...     Some experienced (hobby/enthusiast)
# 57  Spectrum 2  ...     Some experienced (hobby/enthusiast)
# 60  Spectrum 2  ...                          No experienced
# 61  Spectrum 1  ...                          No experienced
# 63  Spectrum 2  ...     Some experienced (hobby/enthusiast)
# 64  Spectrum 2  ...                          No experienced
# 65  Spectrum 2  ...                          No experienced
#
#                                        Q19  \
# 3   Algo de experiencia (hobby/entusiasta)
# 4                               Muy básica
# 6                               Muy básica
# 7                               Muy básica
# 8   Algo de experiencia (hobby/entusiasta)
# 9                                  Ninguna
# 10                                 Ninguna
# 11                                 Ninguna
# 12                              Muy básica
# 13                              Muy básica
# 14  Algo de experiencia (hobby/entusiasta)
# 15                              Muy básica
# 17          Bastante experiencia (amateur)
# 18                              Muy básica
# 19                              Muy básica
# 23                                 Ninguna
# 24                                 Ninguna
# 25                                 Ninguna
# 26                                 Ninguna
# 27                              Muy básica
# 28                                 Ninguna
# 30        Mucha experiencia (professional)
# 31  Algo de experiencia (hobby/entusiasta)
# 33  Algo de experiencia (hobby/entusiasta)
# 34          Bastante experiencia (amateur)
# 36          Bastante experiencia (amateur)
# 38        Mucha experiencia (professional)
# 47         Very experienced (professional)
# 52                         Not experienced
# 54                   Very basic experience
# 57     Some experienced (hobby/enthusiast)
# 60                   Experienced (amateur)
# 61         Very experienced (professional)
# 63                   Experienced (amateur)
# 64         Very experienced (professional)
# 65     Some experienced (hobby/enthusiast)
#
#                                                   Q20                  Q21  \
# 3                                               Rock                 21-30
# 4                                             Clasica  Prefiero no decirlo
# 6                                    Música del mundo            Más de 60
# 7                                             Clásica            Más de 60
# 8                                             Clasica            Más de 60
# 9                                            Clásica                 51-60
# 10                                                Pop                51-60
# 11                                                pop          Menos de 21
# 12                                            Boleros            Más de 60
# 13                                            clasica            Más de 60
# 14                                            el Fary                31-40
# 15                          Variada (un poco de todo)                21-30
# 17  Rock, Noise, Rock-Noise, Pop-Rock, Shoegaze, E...                21-30
# 18                                          Todo tipo                41-50
# 19                                 Sobre todo clasica            Más de 60
# 23                                           Clásica             Más de 60
# 24                                            Clasica                51-60
# 25                                        Electrónica                21-30
# 26                                      Rock and roll            Más de 60
# 27                                               Jazz                41-50
# 28       Jazz, Rock, Blues, Alternativo, Lofi, Metal.                21-30
# 30        Rock psicodelico, Jazz, Reggae, Electronica                31-40
# 31                 R&B, jazz, indie, pop, electrónica                31-40
# 33                                       Experimental                31-40
# 34                         Jazz, rock, clásica, blues                41-50
# 36                                           The todo                51-60
# 38                                Todo tipo de música                41-50
# 47                                       Early music                 41-50
# 52                                      Jazz and Pops                41-50
# 54                                      popular songs                21-30
# 57                    Alternative rock & Japanese pop                31-40
# 60      edm, classical music, Airs of the States, pop                21-30
# 61                                European art music                 21-30
# 63                              Classical, jazz, rock                21-30
# 64  spatial electroacoustic music, music concrete,...    Prefer not to say
# 65                                          Pop music                21-30
#
#    Q22        Q23          Q24                       Q25  \
# 3   No     ESPAÑA      ESPAÑOL  Sí, utilicé auriculares.
# 4   No    España      Español            No, no lo hice.
# 6   No     Canada      español  Sí, utilicé auriculares.
# 7   No     España      Español  Sí, utilicé auriculares.
# 8   No     España     Española  Sí, utilicé auriculares.
# 9   No     España     Español            No, no lo hice.
# 10  No    España      Español   Sí, utilicé auriculares.
# 11  No     España      español           No, no lo hice.
# 12  No     España      Español  Sí, utilicé auriculares.
# 13  No     España      Español  Sí, utilicé auriculares.
# 14  No     España   Castellano           No, no lo hice.
# 15  No     España   Castellano  Sí, utilicé auriculares.
# 17  No     España  Castellano   Sí, utilicé auriculares.
# 18  No     España      Español  Sí, utilicé auriculares.
# 19  No     España      Español           No, no lo hice.
# 23  No     ESPAÑA    ESPAÑOLA   Sí, utilicé auriculares.
# 24  No    España   Castellano   Sí, utilicé auriculares.
# 25  No     España      Español  Sí, utilicé auriculares.
# 26  No    España       Español  Sí, utilicé auriculares.
# 27  No     España   Mallorquín  Sí, utilicé auriculares.
# 28  No     México      Español  Sí, utilicé auriculares.
# 30  No     España   Castellano  Sí, utilicé auriculares.
# 31  No     España      Español  Sí, utilicé auriculares.
# 33  No     España   Castellano  Sí, utilicé auriculares.
# 34  No     España      Español  Sí, utilicé auriculares.
# 36  No     España  Castellano   Sí, utilicé auriculares.
# 38  No     España      Español  Sí, utilicé auriculares.
# 47  No      Spain      Spanish    Yes, I used headphones
# 52  No      Japan     Japanese    Yes, I used headphones
# 54  No         中国           中文    Yes, I used headphones
# 57  No      Japan      Chinese    Yes, I used headphones
# 60  No      China      Chinese    Yes, I used headphones
# 61  No      China      Chinese    Yes, I used headphones
# 63  No      China     Mandarin    Yes, I used headphones
# 64  No  Australia     Elnglish    Yes, I used headphones
# 65  No      Spain      Catalan    Yes, I used headphones
#
#                         Q26                                                Q27
# 3            Intra-aurales;                                                x-x
# 4                No lo sé.;                                                x-x
# 6                  Estéreo;                                    muy interesante
# 7                  Estéreo;                                    Muy interesante
# 8        No lo sé.;Estéreo;                                                x-x
# 9                No lo sé.;                                                x-x
# 10          Circum-aurales;                                                x-x
# 11                 Estéreo;                                                x-x
# 12               No lo sé.;                                                x-x
# 13          Circum-aurales;                                                x-x
# 14                 Estéreo;                                                x-x
# 15               No lo sé.;                                                x-x
# 17       Estéreo;No lo sé.;                                                x-x
# 18  Estéreo;Circum-aurales;                                                x-x
# 19               No lo sé.;                                                x-x
# 23               No lo sé.;               Me parece un trabajo extraordinario
# 24                 Estéreo;                                                x-x
# 25                 Estéreo;                                                x-x
# 26               No lo sé.;                                                x-x
# 27                 Estéreo;                                                x-x
# 28       Audio 3D / Gaming;                                                x-x
# 30   Estéreo;Intra-aurales;                                                x-x
# 31                 Estéreo;                                      Buen trabajo!
# 33  Estéreo;Circum-aurales;                                                x-x
# 34          Circum-aurales;  La reverberación no se aprecia claramente cuan...
# 36                 Estéreo;                                                x-x
# 38                 Estéreo;                                                x-x
# 47                      x-x                                                x-x
# 52                  Stereo;  The age of the stellar was rather difficult fo...
# 54                  Stereo;                                                x-x
# 57            I don't know;  I am not sure the use of this tool.  It is not...
# 60            Circum-aural;                                          difficult
# 61            I don't know;                                    Fantastic work.
# 63                  Stereo;                                                x-x
# 64            Circum-aural;  discriminating between constant tone and rever...
# 65                  Stereo;                                                x-x
#
# [36 rows x 32 columns]

# %% [markdown]
# ### Random downsampling

# %%
nonExperts_down = nonExperts_df.sample(frac=0.85, replace=False, random_state=1)
nonExperts_down
# Out:
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 57          56  11.0   6/26/24 6:39:03   6/26/24 7:09:03  anonymous
# 64          63  18.0   7/25/24 1:49:37   7/25/24 3:03:34  anonymous
# 52          51   6.0   5/27/24 2:29:28   5/27/24 2:57:48  anonymous
# 7            6   6.0  4/18/24 18:10:42  4/18/24 21:23:00  anonymous
# 27          26  26.0  4/26/24 19:53:36   4/27/24 0:52:27  anonymous
# 25          24  24.0  4/26/24 19:24:11  4/26/24 19:40:14  anonymous
# 30          29  29.0  4/30/24 11:11:36  4/30/24 11:37:53  anonymous
# 33          32  32.0   5/3/24 12:31:43   5/3/24 13:15:07  anonymous
# 54          53   8.0  6/23/24 15:32:58  6/23/24 16:18:51  anonymous
# 38          37  37.0  5/25/24 11:00:56  5/25/24 11:10:50  anonymous
# 47          46   1.0   4/17/24 9:12:01   4/17/24 9:28:15  anonymous
# 63          62  17.0   7/21/24 9:56:47  7/21/24 10:55:44  anonymous
# 34          33  33.0   5/5/24 23:19:51   5/5/24 23:38:24  anonymous
# 36          35  35.0   5/8/24 22:32:24   5/8/24 22:47:20  anonymous
# 8            7   7.0  4/18/24 21:09:34  4/18/24 21:41:59  anonymous
# 6            5   5.0  4/18/24 21:15:36  4/18/24 21:19:42  anonymous
# 19          18  18.0  4/24/24 21:49:28  4/24/24 22:03:07  anonymous
# 14          13  13.0  4/22/24 22:03:27  4/22/24 22:09:19  anonymous
# 61          60  15.0   7/17/24 2:20:03   7/17/24 3:10:00  anonymous
# 31          30  30.0   5/2/24 14:19:24   5/2/24 14:47:41  anonymous
# 60          59  14.0  7/14/24 15:25:48  7/14/24 15:51:10  anonymous
# 28          27  27.0  4/27/24 23:28:51  4/27/24 23:58:21  anonymous
# 26          25  25.0  4/26/24 21:38:11  4/26/24 21:55:22  anonymous
# 10           9   9.0  4/18/24 23:02:44  4/18/24 23:17:20  anonymous
# 18          17  17.0  4/24/24 20:09:26  4/24/24 20:17:02  anonymous
# 11          10  10.0  4/18/24 23:21:02  4/18/24 23:30:11  anonymous
# 65          64  19.0  7/29/24 10:32:28  7/29/24 10:50:09  anonymous
# 4            3   3.0  4/18/24 17:14:38  4/18/24 17:21:38  anonymous
# 24          23  23.0  4/26/24 12:04:50  4/26/24 12:17:55  anonymous
# 3            2   2.0  4/18/24 14:48:33  4/18/24 15:19:46  anonymous
# 23          22  22.0  4/25/24 16:04:38  4/25/24 16:19:51  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 57  Sonification 2            Left  Sonification 2  Sonification 2
# 64  Sonification 1            Left  Sonification 2  Sonification 2
# 52  Sonification 2            Left  Sonification 3  Sonification 2
# 7   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 4
# 27  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 25  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 30  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 33  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 54  Sonification 1            Left  Sonification 2  Sonification 1
# 38  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 47  Sonification 2            Left  Sonification 3  Sonification 3
# 63  Sonification 2            Left  Sonification 3  Sonification 2
# 34  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 36  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 8   Sonificación 2    A la derecha  Sonificación 2  Sonificación 3
# 6   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 19  Sonificación 1  A la izquierda  Sonificación 1  Sonificación 4
# 14  Sonificación 2    A la derecha  Sonificación 1  Sonificación 3
# 61  Sonification 2            Left  Sonification 3  Sonification 1
# 31  Sonificación 2    A la derecha  Sonificación 3  Sonificación 2
# 60  Sonification 2            Left  Sonification 3  Sonification 3
# 28  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 26  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 3
# 10  Sonificación 1    A la derecha  Sonificación 3  Sonificación 4
# 18  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 3
# 11  Sonificación 2  A la izquierda  Sonificación 4  Sonificación 1
# 65  Sonification 2            Left  Sonification 2  Sonification 3
# 4   Sonificación 2  A la izquierda  Sonificación 2  Sonificación 1
# 24  Sonificación 1    A la derecha  Sonificación 1  Sonificación 3
# 3   Sonificación 1  A la izquierda  Sonificación 2  Sonificación 4
# 23  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
#
#             Q5  ...                                     Q18  \
# 57  Spectrum 2  ...     Some experienced (hobby/enthusiast)
# 64  Spectrum 2  ...                          No experienced
# 52  Spectrum 1  ...                          No experienced
# 7   Espectro 1  ...                                 Ninguna
# 27  Espectro 2  ...                                 Ninguna
# 25  Espectro 2  ...                                 Ninguna
# 30  Espectro 2  ...                                 Ninguna
# 33  Espectro 2  ...  Algo de experiencia (hobby/entusiasta)
# 54  Spectrum 3  ...     Some experienced (hobby/enthusiast)
# 38  Espectro 2  ...  Algo de experiencia (hobby/entusiasta)
# 47  Spectrum 2  ...                          No experienced
# 63  Spectrum 2  ...     Some experienced (hobby/enthusiast)
# 34  Espectro 2  ...                                 Ninguna
# 36  Espectro 1  ...                                 Ninguna
# 8   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# 6   Espectro 2  ...                                 Ninguna
# 19  Espectro 3  ...                                 Ninguna
# 14  Espectro 3  ...                                 Ninguna
# 61  Spectrum 1  ...                          No experienced
# 31  Espectro 2  ...                                 Ninguna
# 60  Spectrum 2  ...                          No experienced
# 28  Espectro 2  ...                                 Ninguna
# 26  Espectro 1  ...                                 Ninguna
# 10  Espectro 2  ...                                 Ninguna
# 18  Espectro 1  ...                                 Ninguna
# 11  Espectro 1  ...                                 Ninguna
# 65  Spectrum 2  ...                          No experienced
# 4   Espectro 3  ...  Algo de experiencia (hobby/entusiasta)
# 24  Espectro 2  ...                                 Ninguna
# 3   Espectro 1  ...  Algo de experiencia (hobby/entusiasta)
# 23  Espectro 1  ...                                 Ninguna
#
#                                        Q19  \
# 57     Some experienced (hobby/enthusiast)
# 64         Very experienced (professional)
# 52                         Not experienced
# 7                               Muy básica
# 27                              Muy básica
# 25                                 Ninguna
# 30        Mucha experiencia (professional)
# 33  Algo de experiencia (hobby/entusiasta)
# 54                   Very basic experience
# 38        Mucha experiencia (professional)
# 47         Very experienced (professional)
# 63                   Experienced (amateur)
# 34          Bastante experiencia (amateur)
# 36          Bastante experiencia (amateur)
# 8   Algo de experiencia (hobby/entusiasta)
# 6                               Muy básica
# 19                              Muy básica
# 14  Algo de experiencia (hobby/entusiasta)
# 61         Very experienced (professional)
# 31  Algo de experiencia (hobby/entusiasta)
# 60                   Experienced (amateur)
# 28                                 Ninguna
# 26                                 Ninguna
# 10                                 Ninguna
# 18                              Muy básica
# 11                                 Ninguna
# 65     Some experienced (hobby/enthusiast)
# 4                               Muy básica
# 24                                 Ninguna
# 3   Algo de experiencia (hobby/entusiasta)
# 23                                 Ninguna
#
#                                                   Q20                  Q21  \
# 57                    Alternative rock & Japanese pop                31-40
# 64  spatial electroacoustic music, music concrete,...    Prefer not to say
# 52                                      Jazz and Pops                41-50
# 7                                             Clásica            Más de 60
# 27                                               Jazz                41-50
# 25                                        Electrónica                21-30
# 30        Rock psicodelico, Jazz, Reggae, Electronica                31-40
# 33                                       Experimental                31-40
# 54                                      popular songs                21-30
# 38                                Todo tipo de música                41-50
# 47                                       Early music                 41-50
# 63                              Classical, jazz, rock                21-30
# 34                         Jazz, rock, clásica, blues                41-50
# 36                                           The todo                51-60
# 8                                             Clasica            Más de 60
# 6                                    Música del mundo            Más de 60
# 19                                 Sobre todo clasica            Más de 60
# 14                                            el Fary                31-40
# 61                                European art music                 21-30
# 31                 R&B, jazz, indie, pop, electrónica                31-40
# 60      edm, classical music, Airs of the States, pop                21-30
# 28       Jazz, Rock, Blues, Alternativo, Lofi, Metal.                21-30
# 26                                      Rock and roll            Más de 60
# 10                                                Pop                51-60
# 18                                          Todo tipo                41-50
# 11                                                pop          Menos de 21
# 65                                          Pop music                21-30
# 4                                             Clasica  Prefiero no decirlo
# 24                                            Clasica                51-60
# 3                                               Rock                 21-30
# 23                                           Clásica             Más de 60
#
#    Q22        Q23          Q24                       Q25  \
# 57  No      Japan      Chinese    Yes, I used headphones
# 64  No  Australia     Elnglish    Yes, I used headphones
# 52  No      Japan     Japanese    Yes, I used headphones
# 7   No     España      Español  Sí, utilicé auriculares.
# 27  No     España   Mallorquín  Sí, utilicé auriculares.
# 25  No     España      Español  Sí, utilicé auriculares.
# 30  No     España   Castellano  Sí, utilicé auriculares.
# 33  No     España   Castellano  Sí, utilicé auriculares.
# 54  No         中国           中文    Yes, I used headphones
# 38  No     España      Español  Sí, utilicé auriculares.
# 47  No      Spain      Spanish    Yes, I used headphones
# 63  No      China     Mandarin    Yes, I used headphones
# 34  No     España      Español  Sí, utilicé auriculares.
# 36  No     España  Castellano   Sí, utilicé auriculares.
# 8   No     España     Española  Sí, utilicé auriculares.
# 6   No     Canada      español  Sí, utilicé auriculares.
# 19  No     España      Español           No, no lo hice.
# 14  No     España   Castellano           No, no lo hice.
# 61  No      China      Chinese    Yes, I used headphones
# 31  No     España      Español  Sí, utilicé auriculares.
# 60  No      China      Chinese    Yes, I used headphones
# 28  No     México      Español  Sí, utilicé auriculares.
# 26  No    España       Español  Sí, utilicé auriculares.
# 10  No    España      Español   Sí, utilicé auriculares.
# 18  No     España      Español  Sí, utilicé auriculares.
# 11  No     España      español           No, no lo hice.
# 65  No      Spain      Catalan    Yes, I used headphones
# 4   No    España      Español            No, no lo hice.
# 24  No    España   Castellano   Sí, utilicé auriculares.
# 3   No     ESPAÑA      ESPAÑOL  Sí, utilicé auriculares.
# 23  No     ESPAÑA    ESPAÑOLA   Sí, utilicé auriculares.
#
#                         Q26                                                Q27
# 57            I don't know;  I am not sure the use of this tool.  It is not...
# 64            Circum-aural;  discriminating between constant tone and rever...
# 52                  Stereo;  The age of the stellar was rather difficult fo...
# 7                  Estéreo;                                    Muy interesante
# 27                 Estéreo;                                                x-x
# 25                 Estéreo;                                                x-x
# 30   Estéreo;Intra-aurales;                                                x-x
# 33  Estéreo;Circum-aurales;                                                x-x
# 54                  Stereo;                                                x-x
# 38                 Estéreo;                                                x-x
# 47                      x-x                                                x-x
# 63                  Stereo;                                                x-x
# 34          Circum-aurales;  La reverberación no se aprecia claramente cuan...
# 36                 Estéreo;                                                x-x
# 8        No lo sé.;Estéreo;                                                x-x
# 6                  Estéreo;                                    muy interesante
# 19               No lo sé.;                                                x-x
# 14                 Estéreo;                                                x-x
# 61            I don't know;                                    Fantastic work.
# 31                 Estéreo;                                      Buen trabajo!
# 60            Circum-aural;                                          difficult
# 28       Audio 3D / Gaming;                                                x-x
# 26               No lo sé.;                                                x-x
# 10          Circum-aurales;                                                x-x
# 18  Estéreo;Circum-aurales;                                                x-x
# 11                 Estéreo;                                                x-x
# 65                  Stereo;                                                x-x
# 4                No lo sé.;                                                x-x
# 24                 Estéreo;                                                x-x
# 3            Intra-aurales;                                                x-x
# 23               No lo sé.;               Me parece un trabajo extraordinario
#
# [31 rows x 32 columns]

# %%
len(nonExperts_down)
# Out:
# 31

# %%
nonExperts_index2 = []
for i in range(len(nonExperts_down)):
    nonExperts_index2.append(nonExperts_down.index[i])
nonExperts_index2
# Out:
# [57,
#  64,
#  52,
#  7,
#  27,
#  25,
#  30,
#  33,
#  54,
#  38,
#  47,
#  63,
#  34,
#  36,
#  8,
#  6,
#  19,
#  14,
#  61,
#  31,
#  60,
#  28,
#  26,
#  10,
#  18,
#  11,
#  65,
#  4,
#  24,
#  3,
#  23]

# %%
grades_nonexperts_down = []
for i in range(len(nonExperts_down)):
    grade = 0
    if (nonExperts_df.Q1[nonExperts_index[i]] == (data.Q1[0]) or (nonExperts_df.Q1[nonExperts_index[i]] == data.Q1[1])):
        grade += 1
    if (nonExperts_df.Q2[nonExperts_index[i]] == (data.Q2[0]) or (nonExperts_df.Q2[nonExperts_index[i]] == data.Q2[1])):
        grade += 1 
    if (nonExperts_df.Q3[nonExperts_index[i]] == (data.Q3[0]) or (nonExperts_df.Q3[nonExperts_index[i]] == data.Q3[1])):
        grade += 1
    if (nonExperts_df.Q4[nonExperts_index[i]] == (data.Q4[0]) or (nonExperts_df.Q4[nonExperts_index[i]] == data.Q4[1])):
        grade += 1    
    if (nonExperts_df.Q5[nonExperts_index[i]] == (data.Q5[0]) or (nonExperts_df.Q5[nonExperts_index[i]] == data.Q5[1])):
        grade += 1
    if (nonExperts_df.Q6[nonExperts_index[i]] == (data.Q6[0]) or (nonExperts_df.Q6[nonExperts_index[i]] == data.Q6[1])):
        grade += 1    
    if (nonExperts_df.Q7[nonExperts_index[i]] == (data.Q7[0]) or (nonExperts_df.Q7[nonExperts_index[i]] == data.Q7[1])):
        grade += 1
    if (nonExperts_df.Q8[nonExperts_index[i]] == (data.Q8[0]) or (nonExperts_df.Q8[nonExperts_index[i]] == data.Q8[1])):
        grade += 1    
    if (nonExperts_df.Q9[nonExperts_index[i]] == (data.Q9[0]) or (nonExperts_df.Q9[nonExperts_index[i]] == data.Q9[1])):
        grade += 1
    if (nonExperts_df.Q10[nonExperts_index[i]] == (data.Q10[0]) or (nonExperts_df.Q10[nonExperts_index[i]] == data.Q10[1])):
        grade += 1    
    if (nonExperts_df.Q11[nonExperts_index[i]] == (data.Q11[0]) or (nonExperts_df.Q11[nonExperts_index[i]] == data.Q11[1])):
        grade += 1
    if (nonExperts_df.Q12[nonExperts_index[i]] == (data.Q12[0]) or (nonExperts_df.Q12[nonExperts_index[i]] == data.Q12[1])):
        grade += 1      
    grades_nonexperts_down.append(grade)
mode_nonexperts_down = scistats.mode(grades_nonexperts_down)
print("Grades Non-experts:", grades_nonexperts_down)    
print("Mean:", np.mean(grades_nonexperts_down))
print("Median:", np.median(grades_nonexperts_down))
print("Most frequent result:", mode_nonexperts_down)
# Out:
# Grades Non-experts: [7, 3, 6, 6, 3, 4, 7, 3, 5, 5, 1, 9, 7, 5, 3, 8, 6, 5, 5, 10, 8, 9, 6, 8, 8, 6, 10, 5, 4, 3, 6]
# Mean: 5.838709677419355
# Median: 6.0
# Most frequent result: ModeResult(mode=array([5]), count=array([6]))

# %%
Q1nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q1[nonExperts_index2[i]] == data.Q1[0]) or (nonExperts_df.Q1[nonExperts_index2[i]] == data.Q1[1]))])
Q2nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q2[nonExperts_index2[i]] == data.Q2[0]) or (nonExperts_df.Q2[nonExperts_index2[i]] == data.Q2[1]))])
Q3nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q3[nonExperts_index2[i]] == data.Q3[0]) or (nonExperts_df.Q3[nonExperts_index2[i]] == data.Q3[1]))])
Q4nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q4[nonExperts_index2[i]] == data.Q4[0]) or (nonExperts_df.Q4[nonExperts_index2[i]] == data.Q4[1]))])
Q5nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q5[nonExperts_index2[i]] == data.Q5[0]) or (nonExperts_df.Q5[nonExperts_index2[i]] == data.Q5[1]))])
Q6nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q6[nonExperts_index2[i]] == data.Q6[0]) or (nonExperts_df.Q6[nonExperts_index2[i]] == data.Q6[1]))])
Q7nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q7[nonExperts_index2[i]] == data.Q7[0]) or (nonExperts_df.Q7[nonExperts_index2[i]] == data.Q7[1]))])
Q8nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q8[nonExperts_index2[i]] == data.Q8[0]) or (nonExperts_df.Q8[nonExperts_index2[i]] == data.Q8[1]))])
Q9nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q9[nonExperts_index2[i]] == data.Q9[0]) or (nonExperts_df.Q9[nonExperts_index2[i]] == data.Q9[1]))])
Q10nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q10[nonExperts_index2[i]] == data.Q10[0]) or (nonExperts_df.Q10[nonExperts_index2[i]] == data.Q10[1]))])
Q11nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q11[nonExperts_index2[i]] == data.Q11[0]) or (nonExperts_df.Q11[nonExperts_index2[i]] == data.Q11[1]))])
Q12nE = len([i for i in range(len(nonExperts_down)) if ((nonExperts_df.Q12[nonExperts_index2[i]] == data.Q12[0]) or (nonExperts_df.Q12[nonExperts_index2[i]] == data.Q12[1]))])

nonExperts_correct = [Q1nE,Q2nE,Q3nE,Q4nE,Q5nE,Q6nE,Q7nE,Q8nE,Q9nE,Q10nE,Q11nE,Q12nE]
nonExperts_correct = np.array(nonExperts_correct, int)
nonExperts_correct #12 Single response correct results
# Out:
# array([12, 26, 11,  9, 17, 21, 16, 19, 14,  7, 13, 14])

# %%
nonExperts_total_responses = len(nonExperts_down)
mean_nonExperts_correct = np.mean(nonExperts_correct)
print("Total responses: ", nonExperts_total_responses)
print("Non-professional astronomers success mean:", mean_nonExperts_correct/nonExperts_total_responses)

success_nonExperts_correct = np.sum(nonExperts_correct)
attempts_nonExperts_correct = 12* nonExperts_total_responses
conf_nonExperts_correct = astropy.stats.binom_conf_interval(success_nonExperts_correct, attempts_nonExperts_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nonExperts_correct) # Correct answers interval
# Out:
# Total responses:  31
# Non-professional astronomers success mean: 0.4811827956989247
# Jeffreys confidence interval:  [0.45536258 0.50710401]

# %%
nonExperts = pd.Series(nonExperts_correct/nonExperts_total_responses)
nonExperts.describe()
# Out:
# count    12.000000
# mean      0.481183
# std       0.170947
# min       0.225806
# 25%       0.379032
# 50%       0.451613
# 75%       0.564516
# max       0.838710
# dtype: float64

# %%
Q13nE = len([i for i in range(len(nonExperts_down)) if ((check_1 in nonExperts_down.Q13[nonExperts_index2[i]]) and (check_2 in nonExperts_down.Q13[nonExperts_index2[i]]) and (check_3 in nonExperts_down.Q13[nonExperts_index2[i]])) or ((check_4 in nonExperts_down.Q13[nonExperts_index2[i]]) and (check_5 in nonExperts_down.Q13[nonExperts_index2[i]]) and (check_6 in nonExperts_down.Q13[nonExperts_index2[i]]))])

Q14nE = len([i for i in range(len(nonExperts_down)) if ((check_7 in nonExperts_down.Q14[nonExperts_index2[i]]) and (check_8 in nonExperts_down.Q14[nonExperts_index2[i]]) and (check_9 in nonExperts_down.Q14[nonExperts_index2[i]])) or ((check_10 in nonExperts_down.Q14[nonExperts_index2[i]]) and (check_11 in nonExperts_down.Q14[nonExperts_index2[i]]) and (check_12 in nonExperts_down.Q14[nonExperts_index2[i]]))])

nonExperts_combined_correct = [Q13nE,Q14nE]
nonExperts_combined_correct = np.array(nonExperts_combined_correct, int)

nonExperts_combined_correct
# Out:
# array([4, 8])

# %%
mean_nonExperts_combined_correct = np.mean(nonExperts_combined_correct)
print("Non-professional astronomers success mean (Combined questions):", mean_nonExperts_combined_correct/nonExperts_total_responses)
success_nonExperts_combined_correct = np.sum(nonExperts_combined_correct)
attempts_nonExperts_combined_correct = 2* nonExperts_total_responses
conf_nonExperts_combined_correct = astropy.stats.binom_conf_interval(success_nonExperts_combined_correct, attempts_nonExperts_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nonExperts_combined_correct) # Correct answers interval
# Out:
# Non-professional astronomers success mean (Combined questions): 0.1935483870967742
# Jeffreys confidence interval:  [0.14851068 0.24838159]

# %%
nonExperts_combined = pd.Series(nonExperts_combined_correct/nonExperts_total_responses)
nonExperts_combined.describe()
# Out:
# count    2.000000
# mean     0.193548
# std      0.091240
# min      0.129032
# 25%      0.161290
# 50%      0.193548
# 75%      0.225806
# max      0.258065
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15nE_good = len([i for i in range(len(nonExperts_down)) if (("Buena" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Muy buena" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Good" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Very good" in nonExperts_down.Q15[nonExperts_index2[i]]))])
Q15nE_acc = len([i for i in range(len(nonExperts_down)) if (("Aceptable" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Acceptable" in nonExperts_down.Q15[nonExperts_index2[i]]))])
Q15nE_bad = len([i for i in range(len(nonExperts_down)) if (("Mala" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Muy mala" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Bad" in nonExperts_down.Q15[nonExperts_index2[i]]) or ("Very bad" in nonExperts_down.Q15[nonExperts_index2[i]]))])
Q15nE_xxx = len([i for i in range(len(nonExperts_down)) if ("XXX" in nonExperts_down.Q15[nonExperts_index2[i]])])
print("Interactivity 'good' or 'very good':", Q15nE_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15nE_good, len(nonExperts_down) - Q15nE_xxx))
print("Interactivity 'acceptable':", Q15nE_acc)
print("(%)", percentage_sub(Q15nE_acc, len(nonExperts_down) - Q15nE_xxx))
print("Interactivity 'bad' or 'very bad':", Q15nE_bad)
print("(%)", percentage_sub(Q15nE_bad, len(nonExperts_down) - Q15nE_xxx))
print("Participants that couldn't test the application in person:", Q15nE_xxx)
print("(%)", percentage_sub(Q15nE_xxx, len(nonExperts_down)))
# Out:
# Interactivity 'good' or 'very good': 14
# (%) 82.35294117647058
# Interactivity 'acceptable': 3
# (%) 17.647058823529413
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 14
# (%) 45.16129032258064

# %%
# Usefulness
Q16nE_good = len([i for i in range(len(nonExperts_down)) if (("Útil" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Muy útil" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Useful" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Very useful" in nonExperts_down.Q16[nonExperts_index2[i]]))])
Q16nE_bad = len([i for i in range(len(nonExperts_down)) if (("dudosa" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Doubtedly" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Doubtely" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Inútil" in nonExperts_down.Q16[nonExperts_index2[i]]) or ("Useless" in nonExperts_down.Q16[nonExperts_index2[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16nE_good)
print("(%)", percentage_sub(Q16nE_good, len(nonExperts_down)))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16nE_bad)
print("(%)", percentage_sub(Q16nE_bad, len(nonExperts_down)))
# Out:
# Participants finding it 'useful' or 'very useful': 25
# (%) 80.64516129032258
# Participants finding it 'Doubtedly useful' or 'useless': 6
# (%) 19.35483870967742

# %%
# Quality of sound
Q17nE_good = len([i for i in range(len(nonExperts_down)) if (("Buen" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Muy buen" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Good" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Nice" in nonExperts_down.Q17[nonExperts_index2[i]]))])
Q17nE_acc = len([i for i in range(len(nonExperts_down)) if (("Aceptable" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Acceptable" in nonExperts_down.Q17[nonExperts_index2[i]]))])
Q17nE_bad = len([i for i in range(len(nonExperts_down)) if (("Mal" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Insoportable" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Bad" in nonExperts_down.Q17[nonExperts_index2[i]]) or ("Intolerable" in nonExperts_down.Q17[nonExperts_index2[i]]))])
print("Sound Quality 'good' or 'very good':", Q17nE_good)
print("(%)", percentage_sub(Q17nE_good, len(nonExperts_down)))
print("Sound Quality 'acceptable':", Q17nE_acc)
print("(%)", percentage_sub(Q17nE_acc, len(nonExperts_down)))
print("Sound Quality 'bad' or 'very bad':", Q17nE_bad)
print("(%)", percentage_sub(Q17nE_bad, len(nonExperts_down)))
# Out:
# Sound Quality 'good' or 'very good': 20
# (%) 64.51612903225806
# Sound Quality 'acceptable': 9
# (%) 29.03225806451613
# Sound Quality 'bad' or 'very bad': 2
# (%) 6.451612903225806

# %% [markdown]
# ## Appending results

# %%
participants_list.append(len(nonExperts_down))
success_list.append(nonExperts.describe()["mean"])
Jeff_low_list.append(conf_nonExperts_correct[0])
Jeff_high_list.append(conf_nonExperts_correct[1])
std_list.append(nonExperts.describe()["std"])
comb_success_list.append(nonExperts_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_nonExperts_combined_correct[0])
comb_Jeff_high_list.append(conf_nonExperts_combined_correct[1])
comb_std_list.append(nonExperts_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15nE_good, len(nonExperts_down) - Q15nE_xxx))
useful_list.append(percentage_sub(Q16nE_good, len(nonExperts_down)))
sound_list.append(percentage_sub(Q17nE_good, len(nonExperts_down)))

# %% [markdown]
# ## Statistical significance

# %%
#Kruskal-Wallis test: kruskal_p_value < 0.05 => reject the null hypothesis => statistical significance
H_statistic, kruskal_p_value = scistats.kruskal(grades_experts, grades_nonexperts_down)
 
print(H_statistic, kruskal_p_value)
# Out:
# 2.180816446925985 0.13974031379377191

# %% [markdown]
# Conclusion: The diferences between subgroups have not statistical significance

# %% [markdown]
# ## SUBGROUPS. Professional astronomers - professional & amateur musicians

# %%
astromus_list = []
astromus_index = []
astromus_counter = 0
for i in range(len(data)):
    if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])) and (("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("amateur" in data.Q19[i]))):
        astromus_counter += 1
        current_row = data.iloc[i]
        astromus_list.append(current_row)
        astromus_index.append(i)
        
print("Number of Professional astronomers - professional & amateur musicians:", astromus_counter)
astromus_df = pd.DataFrame(astromus_list)
astromus_df
# Out:
# Number of Professional astronomers - professional & amateur musicians: 10
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 16          15  15.0  4/23/24 12:44:04  4/23/24 13:08:00  anonymous
# 32          31  31.0   5/2/24 18:31:56   5/2/24 18:51:31  anonymous
# 35          34  34.0   5/6/24 11:21:54   5/6/24 11:42:11  anonymous
# 39          38  38.0  5/26/24 21:53:07  5/26/24 22:10:15  anonymous
# 46          45   5.0  4/27/24 10:16:07  4/27/24 10:37:46  anonymous
# 49          48   3.0   4/26/24 4:40:27   4/26/24 5:03:39  anonymous
# 50          49   4.0   5/2/24 17:18:28   5/2/24 17:35:06  anonymous
# 53          52   7.0   6/1/24 10:16:23   6/1/24 10:29:00  anonymous
# 62          61  16.0  7/18/24 16:24:37  7/18/24 16:39:13  anonymous
# 66          66   1.0  5/13/24 11:17:19  5/13/24 11:33:10  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 16  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 32  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 35  Sonificación 2    A la derecha  Sonificación 2  Sonificación 2
# 39  Sonificación 2    A la derecha  Sonificación 1  Sonificación 2
# 46  Sonificación 1  A la izquierda  Sonificación 3  Sonificación 2
# 49  Sonification 1           Right  Sonification 2  Sonification 1
# 50  Sonification 1            Left  Sonification 2  Sonification 4
# 53  Sonification 1            Left  Sonification 2  Sonification 2
# 62  Sonification 1            Left  Sonification 3  Sonification 2
# 66  Sonification 2            Left  Sonification 2  Sonification 2
#
#             Q5  ...                              Q18  \
# 16  Espectro 1  ...  Mucha experiencia (profesional)
# 32  Espectro 2  ...  Mucha experiencia (profesional)
# 35  Espectro 2  ...  Mucha experiencia (profesional)
# 39  Espectro 1  ...  Mucha experiencia (profesional)
# 46  Espectro 2  ...  Mucha experiencia (profesional)
# 49  Spectrum 2  ...  Very experienced (professional)
# 50  Spectrum 2  ...  Very experienced (professional)
# 53  Spectrum 2  ...  Very experienced (professional)
# 62  Spectrum 3  ...  Very experienced (professional)
# 66  Spectrum 2  ...  Very experienced (professional)
#
#                                 Q19  \
# 16   Bastante experiencia (amateur)
# 32   Bastante experiencia (amateur)
# 35   Bastante experiencia (amateur)
# 39   Bastante experiencia (amateur)
# 46   Bastante experiencia (amateur)
# 49            Experienced (amateur)
# 50            Experienced (amateur)
# 53            Experienced (amateur)
# 62  Very experienced (professional)
# 66            Experienced (amateur)
#
#                                                Q20        Q21 Q22  \
# 16                      Clasica, Jazz, Cantautores      41-50  No
# 32                                            Jazz      41-50  No
# 35                                   Clásica y pop      51-60  No
# 39                                            Rock      41-50  No
# 46                                        Clásica   Más de 60  No
# 49                                Rock, folk, jazz      31-40  No
# 50                                classical, indie      41-50  No
# 53                         Classical but also rock      41-50  No
# 62  Electronic Music, Jazz, Classical, Folk, Rock       41-50  No
# 66                                      Electronic      31-40  No
#
#                 Q23       Q24                       Q25  \
# 16           España  Italiano  Sí, utilicé auriculares.
# 32           España   Español  Sí, utilicé auriculares.
# 35           España   Español  Sí, utilicé auriculares.
# 39           España   Español           No, no lo hice.
# 46          España    Español  Sí, utilicé auriculares.
# 49            Spain     Greek    Yes, I used headphones
# 50           Canada   Swedish    Yes, I used headphones
# 53          Germany   Spanish    Yes, I used headphones
# 62            Malta   English    Yes, I used headphones
# 66  United Kingdom    English    Yes, I used headphones
#
#                           Q26  \
# 16                   Estéreo;
# 32                   Estéreo;
# 35                   Estéreo;
# 39                 No lo sé.;
# 46     Intra-aurales;Estéreo;
# 49               Intra-aural;
# 50  Intra-aural;I don't know;
# 53                    Stereo;
# 62                    Stereo;
# 66                    Stereo;
#
#                                                   Q27
# 16                                                x-x
# 32  La diferencia entre zona con formación estelar...
# 35  Salvo la posición de los sonidos, las demás ca...
# 39                                                x-x
# 46                                                x-x
# 49  The localization was not very easy to distinct...
# 50  It was fairly easy in the beginning, but I had...
# 53                                                x-x
# 62                                                x-x
# 66                                                x-x
#
# [10 rows x 32 columns]

# %%
grades_astromus = []
for i in range(len(astromus_df)):
    grade = 0
    if (astromus_df.Q1[astromus_index[i]] == (data.Q1[0]) or (astromus_df.Q1[astromus_index[i]] == data.Q1[1])):
        grade += 1
    if (astromus_df.Q2[astromus_index[i]] == (data.Q2[0]) or (astromus_df.Q2[astromus_index[i]] == data.Q2[1])):
        grade += 1 
    if (astromus_df.Q3[astromus_index[i]] == (data.Q3[0]) or (astromus_df.Q3[astromus_index[i]] == data.Q3[1])):
        grade += 1
    if (astromus_df.Q4[astromus_index[i]] == (data.Q4[0]) or (astromus_df.Q4[astromus_index[i]] == data.Q4[1])):
        grade += 1    
    if (astromus_df.Q5[astromus_index[i]] == (data.Q5[0]) or (astromus_df.Q5[astromus_index[i]] == data.Q5[1])):
        grade += 1
    if (astromus_df.Q6[astromus_index[i]] == (data.Q6[0]) or (astromus_df.Q6[astromus_index[i]] == data.Q6[1])):
        grade += 1    
    if (astromus_df.Q7[astromus_index[i]] == (data.Q7[0]) or (astromus_df.Q7[astromus_index[i]] == data.Q7[1])):
        grade += 1
    if (astromus_df.Q8[astromus_index[i]] == (data.Q8[0]) or (astromus_df.Q8[astromus_index[i]] == data.Q8[1])):
        grade += 1    
    if (astromus_df.Q9[astromus_index[i]] == (data.Q9[0]) or (astromus_df.Q9[astromus_index[i]] == data.Q9[1])):
        grade += 1
    if (astromus_df.Q10[astromus_index[i]] == (data.Q10[0]) or (astromus_df.Q10[astromus_index[i]] == data.Q10[1])):
        grade += 1    
    if (astromus_df.Q11[astromus_index[i]] == (data.Q11[0]) or (astromus_df.Q11[astromus_index[i]] == data.Q11[1])):
        grade += 1
    if (astromus_df.Q12[astromus_index[i]] == (data.Q12[0]) or (astromus_df.Q12[astromus_index[i]] == data.Q12[1])):
        grade += 1      
    grades_astromus.append(grade)
mode_astromus = scistats.mode(grades_astromus)
print("Grades astromus:", grades_astromus)    
print("Mean:", np.mean(grades_astromus))
print("Median:", np.median(grades_astromus))
print("Most frequent result:", mode_astromus)
# Out:
# Grades astromus: [8, 8, 5, 6, 6, 4, 7, 8, 6, 7]
# Mean: 6.5
# Median: 6.5
# Most frequent result: ModeResult(mode=array([6]), count=array([3]))

# %%
Q1AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q1[astromus_index[i]] == data.Q1[0]) or (astromus_df.Q1[astromus_index[i]] == data.Q1[1]))])
Q2AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q2[astromus_index[i]] == data.Q2[0]) or (astromus_df.Q2[astromus_index[i]] == data.Q2[1]))])
Q3AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q3[astromus_index[i]] == data.Q3[0]) or (astromus_df.Q3[astromus_index[i]] == data.Q3[1]))])
Q4AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q4[astromus_index[i]] == data.Q4[0]) or (astromus_df.Q4[astromus_index[i]] == data.Q4[1]))])
Q5AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q5[astromus_index[i]] == data.Q5[0]) or (astromus_df.Q5[astromus_index[i]] == data.Q5[1]))])
Q6AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q6[astromus_index[i]] == data.Q6[0]) or (astromus_df.Q6[astromus_index[i]] == data.Q6[1]))])
Q7AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q7[astromus_index[i]] == data.Q7[0]) or (astromus_df.Q7[astromus_index[i]] == data.Q7[1]))])
Q8AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q8[astromus_index[i]] == data.Q8[0]) or (astromus_df.Q8[astromus_index[i]] == data.Q8[1]))])
Q9AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q9[astromus_index[i]] == data.Q9[0]) or (astromus_df.Q9[astromus_index[i]] == data.Q9[1]))])
Q10AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q10[astromus_index[i]] == data.Q10[0]) or (astromus_df.Q10[astromus_index[i]] == data.Q10[1]))])
Q11AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q11[astromus_index[i]] == data.Q11[0]) or (astromus_df.Q11[astromus_index[i]] == data.Q11[1]))])
Q12AM = len([i for i in range(len(astromus_df)) if ((astromus_df.Q12[astromus_index[i]] == data.Q12[0]) or (astromus_df.Q12[astromus_index[i]] == data.Q12[1]))])

astromus_correct = [Q1AM,Q2AM,Q3AM,Q4AM,Q5AM,Q6AM,Q7AM,Q8AM,Q9AM,Q10AM,Q11AM,Q12AM]
astromus_correct = np.array(astromus_correct, int)
astromus_correct #12 Single response correct results
# Out:
# array([7, 7, 2, 5, 7, 7, 7, 8, 5, 1, 4, 5])

# %%
astromus_total_responses = len(astromus_df)
mean_astromus_correct = np.mean(astromus_correct)
print("Total responses: ", astromus_total_responses)
print("Professional astronomers - amateur musicians success mean:", mean_astromus_correct/astromus_total_responses)

success_astromus_correct = np.sum(astromus_correct)
attempts_astromus_correct = 12* astromus_total_responses
conf_astromus_correct = astropy.stats.binom_conf_interval(success_astromus_correct, attempts_astromus_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_astromus_correct) # Correct answers interval
# Out:
# Total responses:  10
# Professional astronomers - amateur musicians success mean: 0.5416666666666667
# Jeffreys confidence interval:  [0.49602419 0.58661816]

# %%
astromus = pd.Series(astromus_correct/astromus_total_responses)
astromus.describe()
# Out:
# count    12.000000
# mean      0.541667
# std       0.219331
# min       0.100000
# 25%       0.475000
# 50%       0.600000
# 75%       0.700000
# max       0.800000
# dtype: float64

# %%
Q13AM = len([i for i in range(len(astromus_df)) if ((check_1 in astromus_df.Q13[astromus_index[i]]) and (check_2 in astromus_df.Q13[astromus_index[i]]) and (check_3 in astromus_df.Q13[astromus_index[i]])) or ((check_4 in astromus_df.Q13[astromus_index[i]]) and (check_5 in astromus_df.Q13[astromus_index[i]]) and (check_6 in astromus_df.Q13[astromus_index[i]]))])

Q14AM = len([i for i in range(len(astromus_df)) if ((check_7 in astromus_df.Q14[astromus_index[i]]) and (check_8 in astromus_df.Q14[astromus_index[i]]) and (check_9 in astromus_df.Q14[astromus_index[i]])) or ((check_10 in astromus_df.Q14[astromus_index[i]]) and (check_11 in astromus_df.Q14[astromus_index[i]]) and (check_12 in astromus_df.Q14[astromus_index[i]]))])

astromus_combined_correct = [Q13AM,Q14AM]
astromus_combined_correct = np.array(astromus_combined_correct, int)

astromus_combined_correct
# Out:
# array([2, 1])

# %%
mean_astromus_combined_correct = np.mean(astromus_combined_correct)
print("Professional astronomers - professional & amateur musicians success mean (Combined questions):", mean_astromus_combined_correct/astromus_total_responses)
success_astromus_combined_correct = np.sum(astromus_combined_correct)
attempts_astromus_combined_correct = 2* astromus_total_responses
conf_astromus_combined_correct = astropy.stats.binom_conf_interval(success_astromus_combined_correct, attempts_astromus_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_astromus_combined_correct) # Correct answers interval
# Out:
# Professional astronomers - professional & amateur musicians success mean (Combined questions): 0.15
# Jeffreys confidence interval:  [0.08785162 0.24618334]

# %%
astromus_combined = pd.Series(astromus_combined_correct/astromus_total_responses)
astromus_combined.describe()
# Out:
# count    2.000000
# mean     0.150000
# std      0.070711
# min      0.100000
# 25%      0.125000
# 50%      0.150000
# 75%      0.175000
# max      0.200000
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15AM_good = len([i for i in range(len(astromus_df)) if (("Buena" in astromus_df.Q15[astromus_index[i]]) or ("Muy buena" in astromus_df.Q15[astromus_index[i]]) or ("Good" in astromus_df.Q15[astromus_index[i]]) or ("Very good" in astromus_df.Q15[astromus_index[i]]))])
Q15AM_acc = len([i for i in range(len(astromus_df)) if (("Aceptable" in astromus_df.Q15[astromus_index[i]]) or ("Acceptable" in astromus_df.Q15[astromus_index[i]]))])
Q15AM_bad = len([i for i in range(len(astromus_df)) if (("Mala" in astromus_df.Q15[astromus_index[i]]) or ("Muy mala" in astromus_df.Q15[astromus_index[i]]) or ("Bad" in astromus_df.Q15[astromus_index[i]]) or ("Very bad" in astromus_df.Q15[astromus_index[i]]))])
Q15AM_xxx = len([i for i in range(len(astromus_df)) if ("XXX" in astromus_df.Q15[astromus_index[i]])])
print("Interactivity 'good' or 'very good':", Q15AM_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15AM_good, astromus_counter - Q15AM_xxx))
print("Interactivity 'acceptable':", Q15AM_acc)
print("(%)", percentage_sub(Q15AM_acc, astromus_counter - Q15AM_xxx))
print("Interactivity 'bad' or 'very bad':", Q15AM_bad)
print("(%)", percentage_sub(Q15AM_bad, astromus_counter - Q15AM_xxx))
print("Participants that couldn't test the application in person:", Q15AM_xxx)
print("(%)", percentage_sub(Q15AM_xxx, astromus_counter))
# Out:
# Interactivity 'good' or 'very good': 6
# (%) 75.0
# Interactivity 'acceptable': 2
# (%) 25.0
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 2
# (%) 20.0

# %%
# Usefulness
Q16AM_good = len([i for i in range(len(astromus_df)) if (("Útil" in astromus_df.Q16[astromus_index[i]]) or ("Muy útil" in astromus_df.Q16[astromus_index[i]]) or ("Useful" in astromus_df.Q16[astromus_index[i]]) or ("Very useful" in astromus_df.Q16[astromus_index[i]]))])
Q16AM_bad = len([i for i in range(len(astromus_df)) if (("dudosa" in astromus_df.Q16[astromus_index[i]]) or ("Doubtedly" in astromus_df.Q16[astromus_index[i]]) or ("Doubtely" in astromus_df.Q16[astromus_index[i]]) or ("Inútil" in astromus_df.Q16[astromus_index[i]]) or ("Useless" in astromus_df.Q16[astromus_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16AM_good)
print("(%)", percentage_sub(Q16AM_good, astromus_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16AM_bad)
print("(%)", percentage_sub(Q16AM_bad, astromus_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 6
# (%) 60.0
# Participants finding it 'Doubtedly useful' or 'useless': 4
# (%) 40.0

# %%
# Quality of sound
Q17AM_good = len([i for i in range(len(astromus_df)) if (("Buen" in astromus_df.Q17[astromus_index[i]]) or ("Muy buen" in astromus_df.Q17[astromus_index[i]]) or ("Good" in astromus_df.Q17[astromus_index[i]]) or ("Nice" in astromus_df.Q17[astromus_index[i]]))])
Q17AM_acc = len([i for i in range(len(astromus_df)) if (("Aceptable" in astromus_df.Q17[astromus_index[i]]) or ("Acceptable" in astromus_df.Q17[astromus_index[i]]))])
Q17AM_bad = len([i for i in range(len(astromus_df)) if (("Mal" in astromus_df.Q17[astromus_index[i]]) or ("Insoportable" in astromus_df.Q17[astromus_index[i]]) or ("Bad" in astromus_df.Q17[astromus_index[i]]) or ("Intolerable" in astromus_df.Q17[astromus_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17AM_good)
print("(%)", percentage_sub(Q17AM_good, astromus_counter))
print("Sound Quality 'acceptable':", Q17AM_acc)
print("(%)", percentage_sub(Q17AM_acc, astromus_counter))
print("Sound Quality 'bad' or 'very bad':", Q17AM_bad)
print("(%)", percentage_sub(Q17AM_bad, astromus_counter))
# Out:
# Sound Quality 'good' or 'very good': 4
# (%) 40.0
# Sound Quality 'acceptable': 4
# (%) 40.0
# Sound Quality 'bad' or 'very bad': 2
# (%) 20.0

# %% [markdown]
# ## Appending results

# %%
participants_list.append(astromus_counter)
success_list.append(astromus.describe()["mean"])
Jeff_low_list.append(conf_astromus_correct[0])
Jeff_high_list.append(conf_astromus_correct[1])
std_list.append(astromus.describe()["std"])
comb_success_list.append(astromus_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_astromus_combined_correct[0])
comb_Jeff_high_list.append(conf_astromus_combined_correct[1])
comb_std_list.append(astromus_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15AM_good, astromus_counter - Q15AM_xxx))
useful_list.append(percentage_sub(Q16AM_good, astromus_counter))
sound_list.append(percentage_sub(Q17AM_good, astromus_counter))

# %% [markdown]
# ## SUBGROUPS. Astronomers non-musicians

# %%
astro_nonmus_list = []
astro_nonmus_index = []
astro_nonmus_counter = 0
for i in range(len(data)):
    if ((("profesional" in data.Q18[i]) or ("professional" in data.Q18[i])) and not (("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("amateur" in data.Q19[i]) or ("entusiasta" in data.Q19[i]) or ("enthusiast" in data.Q19[i]))):
        astro_nonmus_counter += 1
        current_row = data.iloc[i]
        astro_nonmus_list.append(current_row)
        astro_nonmus_index.append(i)
        
print("Number of Professional astronomers non-musicians:", astro_nonmus_counter)
astro_nonmus_df = pd.DataFrame(astro_nonmus_list)
astro_nonmus_df
# Out:
# Number of Professional astronomers non-musicians: 12
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 2            1   1.0  4/18/24 10:01:49  4/18/24 10:26:12  anonymous
# 5            4   4.0  4/18/24 16:09:19  4/18/24 17:34:52  anonymous
# 20          19  19.0  4/25/24 11:19:03  4/25/24 11:32:28  anonymous
# 21          20  20.0  4/25/24 11:30:57  4/25/24 11:46:09  anonymous
# 40          39  39.0  6/14/24 12:39:07  6/14/24 19:32:03  anonymous
# 42          41   1.0   4/25/24 9:19:19   4/25/24 9:23:16  anonymous
# 44          43   3.0  4/25/24 11:55:21  4/25/24 12:18:21  anonymous
# 45          44   4.0  4/26/24 23:27:16   4/27/24 0:15:56  anonymous
# 48          47   2.0  4/17/24 11:32:00  4/17/24 12:09:06  anonymous
# 55          54   9.0  6/24/24 16:27:17  6/24/24 16:46:13  anonymous
# 56          55  10.0   6/25/24 9:48:12  6/25/24 10:04:54  anonymous
# 59          58  13.0   7/2/24 16:31:37   7/2/24 16:55:08  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 2   Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 5   Sonificación 2  A la izquierda  Sonificación 3  Sonificación 3
# 20  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 21  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 40  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 3
# 42  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 44  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 45  Sonificación 2  A la izquierda  Sonificación 1  Sonificación 4
# 48  Sonification 1            Left  Sonification 2  Sonification 2
# 55  Sonification 2            Left  Sonification 4  Sonification 2
# 56  Sonification 1            Left  Sonification 2  Sonification 3
# 59  Sonification 1            Left  Sonification 2  Sonification 1
#
#             Q5  ...                              Q18                    Q19  \
# 2   Espectro 1  ...  Mucha experiencia (profesional)                Ninguna
# 5   Espectro 1  ...  Mucha experiencia (profesional)             Muy básica
# 20  Espectro 2  ...  Mucha experiencia (profesional)                Ninguna
# 21  Espectro 2  ...  Mucha experiencia (profesional)             Muy básica
# 40  Espectro 2  ...  Mucha experiencia (profesional)             Muy básica
# 42  Espectro 3  ...  Mucha experiencia (profesional)             Muy básica
# 44  Espectro 2  ...  Mucha experiencia (profesional)             Muy básica
# 45  Espectro 1  ...  Mucha experiencia (profesional)                Ninguna
# 48  Spectrum 1  ...  Very experienced (professional)        Not experienced
# 55  Spectrum 2  ...  Very experienced (professional)  Very basic experience
# 56  Spectrum 2  ...  Very experienced (professional)  Very basic experience
# 59  Spectrum 2  ...  Very experienced (professional)        Not experienced
#
#                                                   Q20    Q21 Q22     Q23  \
# 2                                               Blues  31-40  No  España
# 5                                             clásica  51-60  No  España
# 20                                    Techno melódico  21-30  No  España
# 21  Pop, rock, música española/latina y francesa, ...  21-30  No  España
# 40                                               Rock  41-50  No  España
# 42                                               Toda  41-50  No  España
# 44              Rock suave, reggae, hip-hop, flamenco  21-30  No  España
# 45                                               Rock  41-50  No  España
# 48                         Rock, trash, grunge, metal  31-40  No   Spain
# 55                                               rock  21-30  No   China
# 56                              Chinese Ancient Music  21-30  No   China
# 59                                                Pop  41-50  No   Spain
#
#                     Q24                       Q25                      Q26  \
# 2               Español  Sí, utilicé auriculares.       Audio 3D / Gaming;
# 5            Castellano  Sí, utilicé auriculares.       Audio 3D / Gaming;
# 20              Español  Sí, utilicé auriculares.  Estéreo;Circum-aurales;
# 21             Francés   Sí, utilicé auriculares.       Audio 3D / Gaming;
# 40             italiano  Sí, utilicé auriculares.                 Estéreo;
# 42              Español           No, no lo hice.               No lo sé.;
# 44  Euskara, Castellano  Sí, utilicé auriculares.       Audio 3D / Gaming;
# 45              Español           No, no lo hice.               No lo sé.;
# 48              Spanish    Yes, I used headphones                      x-x
# 55              Chinese              No, I didn't            I don't know;
# 56              Chinese    Yes, I used headphones            I don't know;
# 59              Persian    Yes, I used headphones                  Stereo;
#
#                                                   Q27
# 2                                       Gran trabajo!
# 5                                                 x-x
# 20    Todo mi apoyo para este proyecto tan necesario!
# 21                                                x-x
# 40                                                x-x
# 42                                                x-x
# 44  Me hubiese ayudado una explicación más detalla...
# 45                                                x-x
# 48                                                x-x
# 55                                                x-x
# 56                                                x-x
# 59                                                x-x
#
# [12 rows x 32 columns]

# %%
grades_astro_nonmus = []
for i in range(len(astro_nonmus_df)):
    grade = 0
    if (astro_nonmus_df.Q1[astro_nonmus_index[i]] == (data.Q1[0]) or (astro_nonmus_df.Q1[astro_nonmus_index[i]] == data.Q1[1])):
        grade += 1
    if (astro_nonmus_df.Q2[astro_nonmus_index[i]] == (data.Q2[0]) or (astro_nonmus_df.Q2[astro_nonmus_index[i]] == data.Q2[1])):
        grade += 1 
    if (astro_nonmus_df.Q3[astro_nonmus_index[i]] == (data.Q3[0]) or (astro_nonmus_df.Q3[astro_nonmus_index[i]] == data.Q3[1])):
        grade += 1
    if (astro_nonmus_df.Q4[astro_nonmus_index[i]] == (data.Q4[0]) or (astro_nonmus_df.Q4[astro_nonmus_index[i]] == data.Q4[1])):
        grade += 1    
    if (astro_nonmus_df.Q5[astro_nonmus_index[i]] == (data.Q5[0]) or (astro_nonmus_df.Q5[astro_nonmus_index[i]] == data.Q5[1])):
        grade += 1
    if (astro_nonmus_df.Q6[astro_nonmus_index[i]] == (data.Q6[0]) or (astro_nonmus_df.Q6[astro_nonmus_index[i]] == data.Q6[1])):
        grade += 1    
    if (astro_nonmus_df.Q7[astro_nonmus_index[i]] == (data.Q7[0]) or (astro_nonmus_df.Q7[astro_nonmus_index[i]] == data.Q7[1])):
        grade += 1
    if (astro_nonmus_df.Q8[astro_nonmus_index[i]] == (data.Q8[0]) or (astro_nonmus_df.Q8[astro_nonmus_index[i]] == data.Q8[1])):
        grade += 1    
    if (astro_nonmus_df.Q9[astro_nonmus_index[i]] == (data.Q9[0]) or (astro_nonmus_df.Q9[astro_nonmus_index[i]] == data.Q9[1])):
        grade += 1
    if (astro_nonmus_df.Q10[astro_nonmus_index[i]] == (data.Q10[0]) or (astro_nonmus_df.Q10[astro_nonmus_index[i]] == data.Q10[1])):
        grade += 1    
    if (astro_nonmus_df.Q11[astro_nonmus_index[i]] == (data.Q11[0]) or (astro_nonmus_df.Q11[astro_nonmus_index[i]] == data.Q11[1])):
        grade += 1
    if (astro_nonmus_df.Q12[astro_nonmus_index[i]] == (data.Q12[0]) or (astro_nonmus_df.Q12[astro_nonmus_index[i]] == data.Q12[1])):
        grade += 1      
    grades_astro_nonmus.append(grade)
mode_astro_nonmus = scistats.mode(grades_astro_nonmus)
print("Grades astro_nonmus:", grades_astro_nonmus)    
print("Mean:", np.mean(grades_astro_nonmus))
print("Median:", np.median(grades_astro_nonmus))
print("Most frequent result:", mode_astro_nonmus)
# Out:
# Grades astro_nonmus: [8, 4, 7, 9, 7, 5, 11, 5, 6, 6, 10, 6]
# Mean: 7.0
# Median: 6.5
# Most frequent result: ModeResult(mode=array([6]), count=array([3]))

# %%
Q1ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q1[astro_nonmus_index[i]] == data.Q1[0]) or (astro_nonmus_df.Q1[astro_nonmus_index[i]] == data.Q1[1]))])
Q2ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q2[astro_nonmus_index[i]] == data.Q2[0]) or (astro_nonmus_df.Q2[astro_nonmus_index[i]] == data.Q2[1]))])
Q3ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q3[astro_nonmus_index[i]] == data.Q3[0]) or (astro_nonmus_df.Q3[astro_nonmus_index[i]] == data.Q3[1]))])
Q4ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q4[astro_nonmus_index[i]] == data.Q4[0]) or (astro_nonmus_df.Q4[astro_nonmus_index[i]] == data.Q4[1]))])
Q5ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q5[astro_nonmus_index[i]] == data.Q5[0]) or (astro_nonmus_df.Q5[astro_nonmus_index[i]] == data.Q5[1]))])
Q6ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q6[astro_nonmus_index[i]] == data.Q6[0]) or (astro_nonmus_df.Q6[astro_nonmus_index[i]] == data.Q6[1]))])
Q7ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q7[astro_nonmus_index[i]] == data.Q7[0]) or (astro_nonmus_df.Q7[astro_nonmus_index[i]] == data.Q7[1]))])
Q8ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q8[astro_nonmus_index[i]] == data.Q8[0]) or (astro_nonmus_df.Q8[astro_nonmus_index[i]] == data.Q8[1]))])
Q9ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q9[astro_nonmus_index[i]] == data.Q9[0]) or (astro_nonmus_df.Q9[astro_nonmus_index[i]] == data.Q9[1]))])
Q10ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q10[astro_nonmus_index[i]] == data.Q10[0]) or (astro_nonmus_df.Q10[astro_nonmus_index[i]] == data.Q10[1]))])
Q11ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q11[astro_nonmus_index[i]] == data.Q11[0]) or (astro_nonmus_df.Q11[astro_nonmus_index[i]] == data.Q11[1]))])
Q12ANM = len([i for i in range(len(astro_nonmus_df)) if ((astro_nonmus_df.Q12[astro_nonmus_index[i]] == data.Q12[0]) or (astro_nonmus_df.Q12[astro_nonmus_index[i]] == data.Q12[1]))])

astro_nonmus_correct = [Q1ANM,Q2ANM,Q3ANM,Q4ANM,Q5ANM,Q6ANM,Q7ANM,Q8ANM,Q9ANM,Q10ANM,Q11ANM,Q12ANM]
astro_nonmus_correct = np.array(astro_nonmus_correct, int)
astro_nonmus_correct #12 Single response correct results
# Out:
# array([ 6, 12,  5,  5,  7,  9,  6, 10,  5,  6,  7,  6])

# %%
astro_nonmus_total_responses = len(astro_nonmus_df)
mean_astro_nonmus_correct = np.mean(astro_nonmus_correct)
print("Total responses: ", astro_nonmus_total_responses)
print("Professional astronomers non-musicians success mean:", mean_astro_nonmus_correct/astro_nonmus_total_responses)

success_astro_nonmus_correct = np.sum(astro_nonmus_correct)
attempts_astro_nonmus_correct = 12* astro_nonmus_total_responses
conf_astro_nonmus_correct = astropy.stats.binom_conf_interval(success_astro_nonmus_correct, attempts_astro_nonmus_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_astro_nonmus_correct) # Correct answers interval
# Out:
# Total responses:  12
# Professional astronomers non-musicians success mean: 0.5833333333333334
# Jeffreys confidence interval:  [0.54181255 0.62370151]

# %%
astro_nonmus = pd.Series(astro_nonmus_correct/astro_nonmus_total_responses)
astro_nonmus.describe()
# Out:
# count    12.000000
# mean      0.583333
# std       0.184637
# min       0.416667
# 25%       0.479167
# 50%       0.500000
# 75%       0.625000
# max       1.000000
# dtype: float64

# %%
Q13ANM = len([i for i in range(len(astro_nonmus_df)) if ((check_1 in astro_nonmus_df.Q13[astro_nonmus_index[i]]) and (check_2 in astro_nonmus_df.Q13[astro_nonmus_index[i]]) and (check_3 in astro_nonmus_df.Q13[astro_nonmus_index[i]])) or ((check_4 in astro_nonmus_df.Q13[astro_nonmus_index[i]]) and (check_5 in astro_nonmus_df.Q13[astro_nonmus_index[i]]) and (check_6 in astro_nonmus_df.Q13[astro_nonmus_index[i]]))])

Q14ANM = len([i for i in range(len(astro_nonmus_df)) if ((check_7 in astro_nonmus_df.Q14[astro_nonmus_index[i]]) and (check_8 in astro_nonmus_df.Q14[astro_nonmus_index[i]]) and (check_9 in astro_nonmus_df.Q14[astro_nonmus_index[i]])) or ((check_10 in astro_nonmus_df.Q14[astro_nonmus_index[i]]) and (check_11 in astro_nonmus_df.Q14[astro_nonmus_index[i]]) and (check_12 in astro_nonmus_df.Q14[astro_nonmus_index[i]]))])

astro_nonmus_combined_correct = [Q13ANM,Q14ANM]
astro_nonmus_combined_correct = np.array(astro_nonmus_combined_correct, int)

astro_nonmus_combined_correct
# Out:
# array([2, 1])

# %%
mean_astro_nonmus_combined_correct = np.mean(astro_nonmus_combined_correct)
print("Professional astronomers non-musicians success mean (Combined questions):", mean_astro_nonmus_combined_correct/astro_nonmus_total_responses)
success_astro_nonmus_combined_correct = np.sum(astro_nonmus_combined_correct)
attempts_astro_nonmus_combined_correct = 2* astro_nonmus_total_responses
conf_astro_nonmus_combined_correct = astropy.stats.binom_conf_interval(success_astro_nonmus_combined_correct, attempts_astro_nonmus_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_astro_nonmus_combined_correct) # Correct answers interval
# Out:
# Professional astronomers non-musicians success mean (Combined questions): 0.125
# Jeffreys confidence interval:  [0.07294292 0.20760841]

# %%
astro_nonmus_combined = pd.Series(astro_nonmus_combined_correct/astro_nonmus_total_responses)
astro_nonmus_combined.describe()
# Out:
# count    2.000000
# mean     0.125000
# std      0.058926
# min      0.083333
# 25%      0.104167
# 50%      0.125000
# 75%      0.145833
# max      0.166667
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15ANM_good = len([i for i in range(len(astro_nonmus_df)) if (("Buena" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Muy buena" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Good" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Very good" in astro_nonmus_df.Q15[astro_nonmus_index[i]]))])
Q15ANM_acc = len([i for i in range(len(astro_nonmus_df)) if (("Aceptable" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Acceptable" in astro_nonmus_df.Q15[astro_nonmus_index[i]]))])
Q15ANM_bad = len([i for i in range(len(astro_nonmus_df)) if (("Mala" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Muy mala" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Bad" in astro_nonmus_df.Q15[astro_nonmus_index[i]]) or ("Very bad" in astro_nonmus_df.Q15[astro_nonmus_index[i]]))])
Q15ANM_xxx = len([i for i in range(len(astro_nonmus_df)) if ("XXX" in astro_nonmus_df.Q15[astro_nonmus_index[i]])])
print("Interactivity 'good' or 'very good':", Q15ANM_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15ANM_good, astro_nonmus_counter - Q15ANM_xxx))
print("Interactivity 'acceptable':", Q15ANM_acc)
print("(%)", percentage_sub(Q15ANM_acc, astro_nonmus_counter - Q15ANM_xxx))
print("Interactivity 'bad' or 'very bad':", Q15ANM_bad)
print("(%)", percentage_sub(Q15ANM_bad, astro_nonmus_counter - Q15ANM_xxx))
print("Participants that couldn't test the application in person:", Q15ANM_xxx)
print("(%)", percentage_sub(Q15ANM_xxx, astro_nonmus_counter))
# Out:
# Interactivity 'good' or 'very good': 6
# (%) 66.66666666666666
# Interactivity 'acceptable': 1
# (%) 11.11111111111111
# Interactivity 'bad' or 'very bad': 2
# (%) 22.22222222222222
# Participants that couldn't test the application in person: 3
# (%) 25.0

# %%
# Usefulness
Q16ANM_good = len([i for i in range(len(astro_nonmus_df)) if (("Útil" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Muy útil" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Useful" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Very useful" in astro_nonmus_df.Q16[astro_nonmus_index[i]]))])
Q16ANM_bad = len([i for i in range(len(astro_nonmus_df)) if (("dudosa" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Doubtedly" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Doubtely" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Inútil" in astro_nonmus_df.Q16[astro_nonmus_index[i]]) or ("Useless" in astro_nonmus_df.Q16[astro_nonmus_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16ANM_good)
print("(%)", percentage_sub(Q16ANM_good, astro_nonmus_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16ANM_bad)
print("(%)", percentage_sub(Q16ANM_bad, astro_nonmus_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 9
# (%) 75.0
# Participants finding it 'Doubtedly useful' or 'useless': 3
# (%) 25.0

# %%
# Quality of sound
Q17ANM_good = len([i for i in range(len(astro_nonmus_df)) if (("Buen" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Muy buen" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Good" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Nice" in astro_nonmus_df.Q17[astro_nonmus_index[i]]))])
Q17ANM_acc = len([i for i in range(len(astro_nonmus_df)) if (("Aceptable" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Acceptable" in astro_nonmus_df.Q17[astro_nonmus_index[i]]))])
Q17ANM_bad = len([i for i in range(len(astro_nonmus_df)) if (("Mal" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Insoportable" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Bad" in astro_nonmus_df.Q17[astro_nonmus_index[i]]) or ("Intolerable" in astro_nonmus_df.Q17[astro_nonmus_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17ANM_good)
print("(%)", percentage_sub(Q17ANM_good, astro_nonmus_counter))
print("Sound Quality 'acceptable':", Q17ANM_acc)
print("(%)", percentage_sub(Q17ANM_acc, astro_nonmus_counter))
print("Sound Quality 'bad' or 'very bad':", Q17ANM_bad)
print("(%)", percentage_sub(Q17ANM_bad, astro_nonmus_counter))
# Out:
# Sound Quality 'good' or 'very good': 6
# (%) 50.0
# Sound Quality 'acceptable': 5
# (%) 41.66666666666667
# Sound Quality 'bad' or 'very bad': 1
# (%) 8.333333333333332

# %% [markdown]
# ## Appending results

# %%
participants_list.append(astro_nonmus_counter)
success_list.append(astro_nonmus.describe()["mean"])
Jeff_low_list.append(conf_astro_nonmus_correct[0])
Jeff_high_list.append(conf_astro_nonmus_correct[1])
std_list.append(astro_nonmus.describe()["std"])
comb_success_list.append(astro_nonmus_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_astro_nonmus_combined_correct[0])
comb_Jeff_high_list.append(conf_astro_nonmus_combined_correct[1])
comb_std_list.append(astro_nonmus_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15ANM_good, astro_nonmus_counter - Q15ANM_xxx))
useful_list.append(percentage_sub(Q16ANM_good, astro_nonmus_counter))
sound_list.append(percentage_sub(Q17ANM_good, astro_nonmus_counter))

# %% [markdown]
# ## SUBGROUPS. Musicians non-astronomers

# %%
non_exp_mus_list = []
non_exp_mus_index = []
non_exp_mus_counter = 0
for i in range(len(data)):
    if ((("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("amateur" in data.Q19[i]) or ("entusiasta" in data.Q19[i]) or ("enthusiast" in data.Q19[i])) and not (("profesional" in data.Q18[i]) or ("professional" in data.Q18[i]) or ("entusiasta" in data.Q18[i]) or ("enthusiast" in data.Q18[i]))):
        non_exp_mus_counter += 1
        current_row = data.iloc[i]
        non_exp_mus_list.append(current_row)
        non_exp_mus_index.append(i)
        
print("Number of Non-astronomers musicians:", non_exp_mus_counter)
non_exp_mus_df = pd.DataFrame(non_exp_mus_list)
non_exp_mus_df
# Out:
# Number of Non-astronomers musicians: 11
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 14          13  13.0  4/22/24 22:03:27  4/22/24 22:09:19  anonymous
# 17          16  16.0  4/24/24 13:08:29  4/24/24 13:33:33  anonymous
# 30          29  29.0  4/30/24 11:11:36  4/30/24 11:37:53  anonymous
# 31          30  30.0   5/2/24 14:19:24   5/2/24 14:47:41  anonymous
# 34          33  33.0   5/5/24 23:19:51   5/5/24 23:38:24  anonymous
# 36          35  35.0   5/8/24 22:32:24   5/8/24 22:47:20  anonymous
# 47          46   1.0   4/17/24 9:12:01   4/17/24 9:28:15  anonymous
# 60          59  14.0  7/14/24 15:25:48  7/14/24 15:51:10  anonymous
# 61          60  15.0   7/17/24 2:20:03   7/17/24 3:10:00  anonymous
# 64          63  18.0   7/25/24 1:49:37   7/25/24 3:03:34  anonymous
# 65          64  19.0  7/29/24 10:32:28  7/29/24 10:50:09  anonymous
#
#                 Q1              Q2              Q3              Q4  \
# 14  Sonificación 2    A la derecha  Sonificación 1  Sonificación 3
# 17  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 30  Sonificación 1  A la izquierda  Sonificación 2  Sonificación 2
# 31  Sonificación 2    A la derecha  Sonificación 3  Sonificación 2
# 34  Sonificación 2  A la izquierda  Sonificación 2  Sonificación 2
# 36  Sonificación 2  A la izquierda  Sonificación 3  Sonificación 2
# 47  Sonification 2            Left  Sonification 3  Sonification 3
# 60  Sonification 2            Left  Sonification 3  Sonification 3
# 61  Sonification 2            Left  Sonification 3  Sonification 1
# 64  Sonification 1            Left  Sonification 2  Sonification 2
# 65  Sonification 2            Left  Sonification 2  Sonification 3
#
#             Q5  ...             Q18                                     Q19  \
# 14  Espectro 3  ...         Ninguna  Algo de experiencia (hobby/entusiasta)
# 17  Espectro 2  ...         Ninguna          Bastante experiencia (amateur)
# 30  Espectro 2  ...         Ninguna        Mucha experiencia (professional)
# 31  Espectro 2  ...         Ninguna  Algo de experiencia (hobby/entusiasta)
# 34  Espectro 2  ...         Ninguna          Bastante experiencia (amateur)
# 36  Espectro 1  ...         Ninguna          Bastante experiencia (amateur)
# 47  Spectrum 2  ...  No experienced         Very experienced (professional)
# 60  Spectrum 2  ...  No experienced                   Experienced (amateur)
# 61  Spectrum 1  ...  No experienced         Very experienced (professional)
# 64  Spectrum 2  ...  No experienced         Very experienced (professional)
# 65  Spectrum 2  ...  No experienced     Some experienced (hobby/enthusiast)
#
#                                                   Q20                Q21 Q22  \
# 14                                            el Fary              31-40  No
# 17  Rock, Noise, Rock-Noise, Pop-Rock, Shoegaze, E...              21-30  No
# 30        Rock psicodelico, Jazz, Reggae, Electronica              31-40  No
# 31                 R&B, jazz, indie, pop, electrónica              31-40  No
# 34                         Jazz, rock, clásica, blues              41-50  No
# 36                                           The todo              51-60  No
# 47                                       Early music               41-50  No
# 60      edm, classical music, Airs of the States, pop              21-30  No
# 61                                European art music               21-30  No
# 64  spatial electroacoustic music, music concrete,...  Prefer not to say  No
# 65                                          Pop music              21-30  No
#
#           Q23          Q24                       Q25                     Q26  \
# 14     España   Castellano           No, no lo hice.                Estéreo;
# 17     España  Castellano   Sí, utilicé auriculares.      Estéreo;No lo sé.;
# 30     España   Castellano  Sí, utilicé auriculares.  Estéreo;Intra-aurales;
# 31     España      Español  Sí, utilicé auriculares.                Estéreo;
# 34     España      Español  Sí, utilicé auriculares.         Circum-aurales;
# 36     España  Castellano   Sí, utilicé auriculares.                Estéreo;
# 47      Spain      Spanish    Yes, I used headphones                     x-x
# 60      China      Chinese    Yes, I used headphones           Circum-aural;
# 61      China      Chinese    Yes, I used headphones           I don't know;
# 64  Australia     Elnglish    Yes, I used headphones           Circum-aural;
# 65      Spain      Catalan    Yes, I used headphones                 Stereo;
#
#                                                   Q27
# 14                                                x-x
# 17                                                x-x
# 30                                                x-x
# 31                                      Buen trabajo!
# 34  La reverberación no se aprecia claramente cuan...
# 36                                                x-x
# 47                                                x-x
# 60                                          difficult
# 61                                    Fantastic work.
# 64  discriminating between constant tone and rever...
# 65                                                x-x
#
# [11 rows x 32 columns]

# %%
grades_non_exp_mus = []
for i in range(len(non_exp_mus_df)):
    grade = 0
    if (non_exp_mus_df.Q1[non_exp_mus_index[i]] == (data.Q1[0]) or (non_exp_mus_df.Q1[non_exp_mus_index[i]] == data.Q1[1])):
        grade += 1
    if (non_exp_mus_df.Q2[non_exp_mus_index[i]] == (data.Q2[0]) or (non_exp_mus_df.Q2[non_exp_mus_index[i]] == data.Q2[1])):
        grade += 1 
    if (non_exp_mus_df.Q3[non_exp_mus_index[i]] == (data.Q3[0]) or (non_exp_mus_df.Q3[non_exp_mus_index[i]] == data.Q3[1])):
        grade += 1
    if (non_exp_mus_df.Q4[non_exp_mus_index[i]] == (data.Q4[0]) or (non_exp_mus_df.Q4[non_exp_mus_index[i]] == data.Q4[1])):
        grade += 1    
    if (non_exp_mus_df.Q5[non_exp_mus_index[i]] == (data.Q5[0]) or (non_exp_mus_df.Q5[non_exp_mus_index[i]] == data.Q5[1])):
        grade += 1
    if (non_exp_mus_df.Q6[non_exp_mus_index[i]] == (data.Q6[0]) or (non_exp_mus_df.Q6[non_exp_mus_index[i]] == data.Q6[1])):
        grade += 1    
    if (non_exp_mus_df.Q7[non_exp_mus_index[i]] == (data.Q7[0]) or (non_exp_mus_df.Q7[non_exp_mus_index[i]] == data.Q7[1])):
        grade += 1
    if (non_exp_mus_df.Q8[non_exp_mus_index[i]] == (data.Q8[0]) or (non_exp_mus_df.Q8[non_exp_mus_index[i]] == data.Q8[1])):
        grade += 1    
    if (non_exp_mus_df.Q9[non_exp_mus_index[i]] == (data.Q9[0]) or (non_exp_mus_df.Q9[non_exp_mus_index[i]] == data.Q9[1])):
        grade += 1
    if (non_exp_mus_df.Q10[non_exp_mus_index[i]] == (data.Q10[0]) or (non_exp_mus_df.Q10[non_exp_mus_index[i]] == data.Q10[1])):
        grade += 1    
    if (non_exp_mus_df.Q11[non_exp_mus_index[i]] == (data.Q11[0]) or (non_exp_mus_df.Q11[non_exp_mus_index[i]] == data.Q11[1])):
        grade += 1
    if (non_exp_mus_df.Q12[non_exp_mus_index[i]] == (data.Q12[0]) or (non_exp_mus_df.Q12[non_exp_mus_index[i]] == data.Q12[1])):
        grade += 1      
    grades_non_exp_mus.append(grade)
mode_non_exp_mus = scistats.mode(grades_non_exp_mus)
print("Grades non_exp_mus:", grades_non_exp_mus)    
print("Mean:", np.mean(grades_non_exp_mus))
print("Median:", np.median(grades_non_exp_mus))
print("Most frequent result:", mode_non_exp_mus)
# Out:
# Grades non_exp_mus: [1, 7, 9, 6, 8, 6, 5, 5, 4, 8, 5]
# Mean: 5.818181818181818
# Median: 6.0
# Most frequent result: ModeResult(mode=array([5]), count=array([3]))

# %%
Q1NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q1[non_exp_mus_index[i]] == data.Q1[0]) or (non_exp_mus_df.Q1[non_exp_mus_index[i]] == data.Q1[1]))])
Q2NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q2[non_exp_mus_index[i]] == data.Q2[0]) or (non_exp_mus_df.Q2[non_exp_mus_index[i]] == data.Q2[1]))])
Q3NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q3[non_exp_mus_index[i]] == data.Q3[0]) or (non_exp_mus_df.Q3[non_exp_mus_index[i]] == data.Q3[1]))])
Q4NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q4[non_exp_mus_index[i]] == data.Q4[0]) or (non_exp_mus_df.Q4[non_exp_mus_index[i]] == data.Q4[1]))])
Q5NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q5[non_exp_mus_index[i]] == data.Q5[0]) or (non_exp_mus_df.Q5[non_exp_mus_index[i]] == data.Q5[1]))])
Q6NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q6[non_exp_mus_index[i]] == data.Q6[0]) or (non_exp_mus_df.Q6[non_exp_mus_index[i]] == data.Q6[1]))])
Q7NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q7[non_exp_mus_index[i]] == data.Q7[0]) or (non_exp_mus_df.Q7[non_exp_mus_index[i]] == data.Q7[1]))])
Q8NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q8[non_exp_mus_index[i]] == data.Q8[0]) or (non_exp_mus_df.Q8[non_exp_mus_index[i]] == data.Q8[1]))])
Q9NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q9[non_exp_mus_index[i]] == data.Q9[0]) or (non_exp_mus_df.Q9[non_exp_mus_index[i]] == data.Q9[1]))])
Q10NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q10[non_exp_mus_index[i]] == data.Q10[0]) or (non_exp_mus_df.Q10[non_exp_mus_index[i]] == data.Q10[1]))])
Q11NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q11[non_exp_mus_index[i]] == data.Q11[0]) or (non_exp_mus_df.Q11[non_exp_mus_index[i]] == data.Q11[1]))])
Q12NEM = len([i for i in range(len(non_exp_mus_df)) if ((non_exp_mus_df.Q12[non_exp_mus_index[i]] == data.Q12[0]) or (non_exp_mus_df.Q12[non_exp_mus_index[i]] == data.Q12[1]))])

non_exp_mus_correct = [Q1NEM,Q2NEM,Q3NEM,Q4NEM,Q5NEM,Q6NEM,Q7NEM,Q8NEM,Q9NEM,Q10NEM,Q11NEM,Q12NEM]
non_exp_mus_correct = np.array(non_exp_mus_correct, int)
non_exp_mus_correct #12 Single response correct results
# Out:
# array([3, 9, 3, 5, 8, 6, 6, 7, 5, 0, 6, 6])

# %%
non_exp_mus_total_responses = len(non_exp_mus_df)
mean_non_exp_mus_correct = np.mean(non_exp_mus_correct)
print("Total responses: ", non_exp_mus_total_responses)
print("Non-astronomers musicians success mean:", mean_non_exp_mus_correct/non_exp_mus_total_responses)

success_non_exp_mus_correct = np.sum(non_exp_mus_correct)
attempts_non_exp_mus_correct = 12* non_exp_mus_total_responses
conf_non_exp_mus_correct = astropy.stats.binom_conf_interval(success_non_exp_mus_correct, attempts_non_exp_mus_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_non_exp_mus_correct) # Correct answers interval
# Out:
# Total responses:  11
# Non-astronomers musicians success mean: 0.4848484848484848
# Jeffreys confidence interval:  [0.44162732 0.52829817]

# %%
non_exp_mus = pd.Series(non_exp_mus_correct/non_exp_mus_total_responses)
non_exp_mus.describe()
# Out:
# count    12.000000
# mean      0.484848
# std       0.220420
# min       0.000000
# 25%       0.409091
# 50%       0.545455
# 75%       0.568182
# max       0.818182
# dtype: float64

# %%
Q13NEM = len([i for i in range(len(non_exp_mus_df)) if ((check_1 in non_exp_mus_df.Q13[non_exp_mus_index[i]]) and (check_2 in non_exp_mus_df.Q13[non_exp_mus_index[i]]) and (check_3 in non_exp_mus_df.Q13[non_exp_mus_index[i]])) or ((check_4 in non_exp_mus_df.Q13[non_exp_mus_index[i]]) and (check_5 in non_exp_mus_df.Q13[non_exp_mus_index[i]]) and (check_6 in non_exp_mus_df.Q13[non_exp_mus_index[i]]))])

Q14NEM = len([i for i in range(len(non_exp_mus_df)) if ((check_7 in non_exp_mus_df.Q14[non_exp_mus_index[i]]) and (check_8 in non_exp_mus_df.Q14[non_exp_mus_index[i]]) and (check_9 in non_exp_mus_df.Q14[non_exp_mus_index[i]])) or ((check_10 in non_exp_mus_df.Q14[non_exp_mus_index[i]]) and (check_11 in non_exp_mus_df.Q14[non_exp_mus_index[i]]) and (check_12 in non_exp_mus_df.Q14[non_exp_mus_index[i]]))])

non_exp_mus_combined_correct = [Q13NEM,Q14NEM]
non_exp_mus_combined_correct = np.array(non_exp_mus_combined_correct, int)

non_exp_mus_combined_correct
# Out:
# array([3, 5])

# %%
mean_non_exp_mus_combined_correct = np.mean(non_exp_mus_combined_correct)
print("Non-astronomers musicians success mean (Combined questions):", mean_non_exp_mus_combined_correct/non_exp_mus_total_responses)
success_non_exp_mus_combined_correct = np.sum(non_exp_mus_combined_correct)
attempts_non_exp_mus_combined_correct = 2* non_exp_mus_total_responses
conf_non_exp_mus_combined_correct = astropy.stats.binom_conf_interval(success_non_exp_mus_combined_correct, attempts_non_exp_mus_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_non_exp_mus_combined_correct) # Correct answers interval
# Out:
# Non-astronomers musicians success mean (Combined questions): 0.36363636363636365
# Jeffreys confidence interval:  [0.26926499 0.47007223]

# %%
non_exp_mus_combined = pd.Series(non_exp_mus_combined_correct/non_exp_mus_total_responses)
non_exp_mus_combined.describe()
# Out:
# count    2.000000
# mean     0.363636
# std      0.128565
# min      0.272727
# 25%      0.318182
# 50%      0.363636
# 75%      0.409091
# max      0.454545
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15NEM_good = len([i for i in range(len(non_exp_mus_df)) if (("Buena" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Muy buena" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Good" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Very good" in non_exp_mus_df.Q15[non_exp_mus_index[i]]))])
Q15NEM_acc = len([i for i in range(len(non_exp_mus_df)) if (("Aceptable" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Acceptable" in non_exp_mus_df.Q15[non_exp_mus_index[i]]))])
Q15NEM_bad = len([i for i in range(len(non_exp_mus_df)) if (("Mala" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Muy mala" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Bad" in non_exp_mus_df.Q15[non_exp_mus_index[i]]) or ("Very bad" in non_exp_mus_df.Q15[non_exp_mus_index[i]]))])
Q15NEM_xxx = len([i for i in range(len(non_exp_mus_df)) if ("XXX" in non_exp_mus_df.Q15[non_exp_mus_index[i]])])
print("Interactivity 'good' or 'very good':", Q15NEM_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15NEM_good, non_exp_mus_counter - Q15NEM_xxx))
print("Interactivity 'acceptable':", Q15NEM_acc)
print("(%)", percentage_sub(Q15NEM_acc, non_exp_mus_counter - Q15NEM_xxx))
print("Interactivity 'bad' or 'very bad':", Q15NEM_bad)
print("(%)", percentage_sub(Q15NEM_bad, non_exp_mus_counter - Q15NEM_xxx))
print("Participants that couldn't test the application in person:", Q15NEM_xxx)
print("(%)", percentage_sub(Q15NEM_xxx, non_exp_mus_counter))
# Out:
# Interactivity 'good' or 'very good': 5
# (%) 83.33333333333334
# Interactivity 'acceptable': 1
# (%) 16.666666666666664
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 5
# (%) 45.45454545454545

# %%
# Usefulness
Q16NEM_good = len([i for i in range(len(non_exp_mus_df)) if (("Útil" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Muy útil" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Useful" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Very useful" in non_exp_mus_df.Q16[non_exp_mus_index[i]]))])
Q16NEM_bad = len([i for i in range(len(non_exp_mus_df)) if (("dudosa" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Doubtedly" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Doubtely" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Inútil" in non_exp_mus_df.Q16[non_exp_mus_index[i]]) or ("Useless" in non_exp_mus_df.Q16[non_exp_mus_index[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16NEM_good)
print("(%)", percentage_sub(Q16NEM_good, non_exp_mus_counter))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16NEM_bad)
print("(%)", percentage_sub(Q16NEM_bad, non_exp_mus_counter))
# Out:
# Participants finding it 'useful' or 'very useful': 9
# (%) 81.81818181818183
# Participants finding it 'Doubtedly useful' or 'useless': 2
# (%) 18.181818181818183

# %%
# Quality of sound
Q17NEM_good = len([i for i in range(len(non_exp_mus_df)) if (("Buen" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Muy buen" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Good" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Nice" in non_exp_mus_df.Q17[non_exp_mus_index[i]]))])
Q17NEM_acc = len([i for i in range(len(non_exp_mus_df)) if (("Aceptable" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Acceptable" in non_exp_mus_df.Q17[non_exp_mus_index[i]]))])
Q17NEM_bad = len([i for i in range(len(non_exp_mus_df)) if (("Mal" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Insoportable" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Bad" in non_exp_mus_df.Q17[non_exp_mus_index[i]]) or ("Intolerable" in non_exp_mus_df.Q17[non_exp_mus_index[i]]))])
print("Sound Quality 'good' or 'very good':", Q17NEM_good)
print("(%)", percentage_sub(Q17NEM_good, non_exp_mus_counter))
print("Sound Quality 'acceptable':", Q17NEM_acc)
print("(%)", percentage_sub(Q17NEM_acc, non_exp_mus_counter))
print("Sound Quality 'bad' or 'very bad':", Q17NEM_bad)
print("(%)", percentage_sub(Q17NEM_bad, non_exp_mus_counter))
# Out:
# Sound Quality 'good' or 'very good': 7
# (%) 63.63636363636363
# Sound Quality 'acceptable': 3
# (%) 27.27272727272727
# Sound Quality 'bad' or 'very bad': 1
# (%) 9.090909090909092

# %% [markdown]
# ## Appending results

# %%
participants_list.append(non_exp_mus_counter)
success_list.append(non_exp_mus.describe()["mean"])
Jeff_low_list.append(conf_non_exp_mus_correct[0])
Jeff_high_list.append(conf_non_exp_mus_correct[1])
std_list.append(non_exp_mus.describe()["std"])
comb_success_list.append(non_exp_mus_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_non_exp_mus_combined_correct[0])
comb_Jeff_high_list.append(conf_non_exp_mus_combined_correct[1])
comb_std_list.append(non_exp_mus_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15NEM_good, non_exp_mus_counter - Q15NEM_xxx))
useful_list.append(percentage_sub(Q16NEM_good, non_exp_mus_counter))
sound_list.append(percentage_sub(Q17NEM_good, non_exp_mus_counter))

# %% [markdown]
# ## Non-astronomers non-musicians

# %%
nothing_list = []
nothing_index = []
nothing_counter = 0
for i in range(len(data)):
    if not ((("profesional" in data.Q19[i]) or ("professional" in data.Q19[i]) or ("amateur" in data.Q19[i]) or ("entusiasta" in data.Q19[i]) or ("enthusiast" in data.Q19[i]) or ("profesional" in data.Q18[i]) or ("professional" in data.Q18[i]) or ("entusiasta" in data.Q18[i]) or ("enthusiast" in data.Q18[i]))):
        nothing_counter += 1
        current_row = data.iloc[i]
        nothing_list.append(current_row)
        nothing_index.append(i)
        
print("Number of Non-astronomers non-musicians:", nothing_counter)
nothing_df = pd.DataFrame(nothing_list)
nothing_df
# Out:
# Number of Non-astronomers non-musicians: 17
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 0            0   x-x               x-x               x-x    RES_ESP
# 1            0   x-x               x-x               x-x    RES_ENG
# 6            5   5.0  4/18/24 21:15:36  4/18/24 21:19:42  anonymous
# 7            6   6.0  4/18/24 18:10:42  4/18/24 21:23:00  anonymous
# 10           9   9.0  4/18/24 23:02:44  4/18/24 23:17:20  anonymous
# 11          10  10.0  4/18/24 23:21:02  4/18/24 23:30:11  anonymous
# 13          12  12.0  4/20/24 12:25:14  4/20/24 12:34:51  anonymous
# 15          14  14.0  4/23/24 12:13:07  4/23/24 12:56:30  anonymous
# 18          17  17.0  4/24/24 20:09:26  4/24/24 20:17:02  anonymous
# 19          18  18.0  4/24/24 21:49:28  4/24/24 22:03:07  anonymous
# 23          22  22.0  4/25/24 16:04:38  4/25/24 16:19:51  anonymous
# 24          23  23.0  4/26/24 12:04:50  4/26/24 12:17:55  anonymous
# 25          24  24.0  4/26/24 19:24:11  4/26/24 19:40:14  anonymous
# 26          25  25.0  4/26/24 21:38:11  4/26/24 21:55:22  anonymous
# 27          26  26.0  4/26/24 19:53:36   4/27/24 0:52:27  anonymous
# 28          27  27.0  4/27/24 23:28:51  4/27/24 23:58:21  anonymous
# 52          51   6.0   5/27/24 2:29:28   5/27/24 2:57:48  anonymous
#
#                 Q1              Q2               Q3               Q4  \
# 0   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 2
# 1   Sonification 1            Left  Sonification  2  Sonification  2
# 6   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 3
# 7   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 4
# 10  Sonificación 1    A la derecha   Sonificación 3   Sonificación 4
# 11  Sonificación 2  A la izquierda   Sonificación 4   Sonificación 1
# 13  Sonificación 2  A la izquierda   Sonificación 2   Sonificación 3
# 15  Sonificación 1  A la izquierda   Sonificación 3   Sonificación 2
# 18  Sonificación 2  A la izquierda   Sonificación 3   Sonificación 3
# 19  Sonificación 1  A la izquierda   Sonificación 1   Sonificación 4
# 23  Sonificación 1  A la izquierda   Sonificación 2   Sonificación 3
# 24  Sonificación 1    A la derecha   Sonificación 1   Sonificación 3
# 25  Sonificación 2  A la izquierda   Sonificación 3   Sonificación 2
# 26  Sonificación 1  A la izquierda   Sonificación 3   Sonificación 3
# 27  Sonificación 2  A la izquierda   Sonificación 2   Sonificación 2
# 28  Sonificación 2  A la izquierda   Sonificación 3   Sonificación 2
# 52  Sonification 2            Left   Sonification 3   Sonification 2
#
#             Q5  ...             Q18              Q19  \
# 0   Espectro 2  ...             x-x              x-x
# 1   Spectrum 2  ...             x-x              x-x
# 6   Espectro 2  ...         Ninguna       Muy básica
# 7   Espectro 1  ...         Ninguna       Muy básica
# 10  Espectro 2  ...         Ninguna          Ninguna
# 11  Espectro 1  ...         Ninguna          Ninguna
# 13  Espectro 2  ...         Ninguna       Muy básica
# 15  Espectro 3  ...         Ninguna       Muy básica
# 18  Espectro 1  ...         Ninguna       Muy básica
# 19  Espectro 3  ...         Ninguna       Muy básica
# 23  Espectro 1  ...         Ninguna          Ninguna
# 24  Espectro 2  ...         Ninguna          Ninguna
# 25  Espectro 2  ...         Ninguna          Ninguna
# 26  Espectro 1  ...         Ninguna          Ninguna
# 27  Espectro 2  ...         Ninguna       Muy básica
# 28  Espectro 2  ...         Ninguna          Ninguna
# 52  Spectrum 1  ...  No experienced  Not experienced
#
#                                              Q20          Q21  Q22      Q23  \
# 0                                            x-x          x-x  x-x      x-x
# 1                                            x-x          x-x  x-x      x-x
# 6                               Música del mundo    Más de 60   No   Canada
# 7                                        Clásica    Más de 60   No   España
# 10                                           Pop        51-60   No  España
# 11                                           pop  Menos de 21   No   España
# 13                                       clasica    Más de 60   No   España
# 15                     Variada (un poco de todo)        21-30   No   España
# 18                                     Todo tipo        41-50   No   España
# 19                            Sobre todo clasica    Más de 60   No   España
# 23                                      Clásica     Más de 60   No   ESPAÑA
# 24                                       Clasica        51-60   No  España
# 25                                   Electrónica        21-30   No   España
# 26                                 Rock and roll    Más de 60   No  España
# 27                                          Jazz        41-50   No   España
# 28  Jazz, Rock, Blues, Alternativo, Lofi, Metal.        21-30   No   México
# 52                                 Jazz and Pops        41-50   No    Japan
#
#             Q24                       Q25                      Q26  \
# 0           x-x                       x-x                      x-x
# 1           x-x                       x-x                      x-x
# 6       español  Sí, utilicé auriculares.                 Estéreo;
# 7       Español  Sí, utilicé auriculares.                 Estéreo;
# 10     Español   Sí, utilicé auriculares.          Circum-aurales;
# 11      español           No, no lo hice.                 Estéreo;
# 13      Español  Sí, utilicé auriculares.          Circum-aurales;
# 15   Castellano  Sí, utilicé auriculares.               No lo sé.;
# 18      Español  Sí, utilicé auriculares.  Estéreo;Circum-aurales;
# 19      Español           No, no lo hice.               No lo sé.;
# 23    ESPAÑOLA   Sí, utilicé auriculares.               No lo sé.;
# 24  Castellano   Sí, utilicé auriculares.                 Estéreo;
# 25      Español  Sí, utilicé auriculares.                 Estéreo;
# 26      Español  Sí, utilicé auriculares.               No lo sé.;
# 27   Mallorquín  Sí, utilicé auriculares.                 Estéreo;
# 28      Español  Sí, utilicé auriculares.       Audio 3D / Gaming;
# 52     Japanese    Yes, I used headphones                  Stereo;
#
#                                                   Q27
# 0                                                 x-x
# 1                                                 x-x
# 6                                     muy interesante
# 7                                     Muy interesante
# 10                                                x-x
# 11                                                x-x
# 13                                                x-x
# 15                                                x-x
# 18                                                x-x
# 19                                                x-x
# 23               Me parece un trabajo extraordinario
# 24                                                x-x
# 25                                                x-x
# 26                                                x-x
# 27                                                x-x
# 28                                                x-x
# 52  The age of the stellar was rather difficult fo...
#
# [17 rows x 32 columns]

# %% [markdown]
# ## Downsamplig

# %%
nothing_df = nothing_df.sample(frac=0.70, replace=False, random_state=123)
nothing_df
# Out:
#     Unnamed: 0    ID        Start time   Completion time        REF  \
# 10           9   9.0  4/18/24 23:02:44  4/18/24 23:17:20  anonymous
# 19          18  18.0  4/24/24 21:49:28  4/24/24 22:03:07  anonymous
# 52          51   6.0   5/27/24 2:29:28   5/27/24 2:57:48  anonymous
# 18          17  17.0  4/24/24 20:09:26  4/24/24 20:17:02  anonymous
# 11          10  10.0  4/18/24 23:21:02  4/18/24 23:30:11  anonymous
# 15          14  14.0  4/23/24 12:13:07  4/23/24 12:56:30  anonymous
# 0            0   x-x               x-x               x-x    RES_ESP
# 23          22  22.0  4/25/24 16:04:38  4/25/24 16:19:51  anonymous
# 24          23  23.0  4/26/24 12:04:50  4/26/24 12:17:55  anonymous
# 7            6   6.0  4/18/24 18:10:42  4/18/24 21:23:00  anonymous
# 1            0   x-x               x-x               x-x    RES_ENG
# 13          12  12.0  4/20/24 12:25:14  4/20/24 12:34:51  anonymous
#
#                 Q1              Q2               Q3               Q4  \
# 10  Sonificación 1    A la derecha   Sonificación 3   Sonificación 4
# 19  Sonificación 1  A la izquierda   Sonificación 1   Sonificación 4
# 52  Sonification 2            Left   Sonification 3   Sonification 2
# 18  Sonificación 2  A la izquierda   Sonificación 3   Sonificación 3
# 11  Sonificación 2  A la izquierda   Sonificación 4   Sonificación 1
# 15  Sonificación 1  A la izquierda   Sonificación 3   Sonificación 2
# 0   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 2
# 23  Sonificación 1  A la izquierda   Sonificación 2   Sonificación 3
# 24  Sonificación 1    A la derecha   Sonificación 1   Sonificación 3
# 7   Sonificación 1  A la izquierda   Sonificación 2   Sonificación 4
# 1   Sonification 1            Left  Sonification  2  Sonification  2
# 13  Sonificación 2  A la izquierda   Sonificación 2   Sonificación 3
#
#             Q5  ...             Q18              Q19  \
# 10  Espectro 2  ...         Ninguna          Ninguna
# 19  Espectro 3  ...         Ninguna       Muy básica
# 52  Spectrum 1  ...  No experienced  Not experienced
# 18  Espectro 1  ...         Ninguna       Muy básica
# 11  Espectro 1  ...         Ninguna          Ninguna
# 15  Espectro 3  ...         Ninguna       Muy básica
# 0   Espectro 2  ...             x-x              x-x
# 23  Espectro 1  ...         Ninguna          Ninguna
# 24  Espectro 2  ...         Ninguna          Ninguna
# 7   Espectro 1  ...         Ninguna       Muy básica
# 1   Spectrum 2  ...             x-x              x-x
# 13  Espectro 2  ...         Ninguna       Muy básica
#
#                           Q20          Q21  Q22      Q23          Q24  \
# 10                        Pop        51-60   No  España      Español
# 19         Sobre todo clasica    Más de 60   No   España      Español
# 52              Jazz and Pops        41-50   No    Japan     Japanese
# 18                  Todo tipo        41-50   No   España      Español
# 11                        pop  Menos de 21   No   España      español
# 15  Variada (un poco de todo)        21-30   No   España   Castellano
# 0                         x-x          x-x  x-x      x-x          x-x
# 23                   Clásica     Más de 60   No   ESPAÑA    ESPAÑOLA
# 24                    Clasica        51-60   No  España   Castellano
# 7                     Clásica    Más de 60   No   España      Español
# 1                         x-x          x-x  x-x      x-x          x-x
# 13                    clasica    Más de 60   No   España      Español
#
#                          Q25                      Q26  \
# 10  Sí, utilicé auriculares.          Circum-aurales;
# 19           No, no lo hice.               No lo sé.;
# 52    Yes, I used headphones                  Stereo;
# 18  Sí, utilicé auriculares.  Estéreo;Circum-aurales;
# 11           No, no lo hice.                 Estéreo;
# 15  Sí, utilicé auriculares.               No lo sé.;
# 0                        x-x                      x-x
# 23  Sí, utilicé auriculares.               No lo sé.;
# 24  Sí, utilicé auriculares.                 Estéreo;
# 7   Sí, utilicé auriculares.                 Estéreo;
# 1                        x-x                      x-x
# 13  Sí, utilicé auriculares.          Circum-aurales;
#
#                                                   Q27
# 10                                                x-x
# 19                                                x-x
# 52  The age of the stellar was rather difficult fo...
# 18                                                x-x
# 11                                                x-x
# 15                                                x-x
# 0                                                 x-x
# 23               Me parece un trabajo extraordinario
# 24                                                x-x
# 7                                     Muy interesante
# 1                                                 x-x
# 13                                                x-x
#
# [12 rows x 32 columns]

# %%
nothing_index2 = []
for i in range(len(nothing_df)):
    nothing_index2.append(nothing_df.index[i])
nothing_index2
# Out:
# [10, 19, 52, 18, 11, 15, 0, 23, 24, 7, 1, 13]

# %%
grades_nothing = []
for i in range(len(nothing_df)):
    grade = 0
    if (nothing_df.Q1[nothing_index2[i]] == (data.Q1[0]) or (nothing_df.Q1[nothing_index2[i]] == data.Q1[1])):
        grade += 1
    if (nothing_df.Q2[nothing_index2[i]] == (data.Q2[0]) or (nothing_df.Q2[nothing_index2[i]] == data.Q2[1])):
        grade += 1 
    if (nothing_df.Q3[nothing_index2[i]] == (data.Q3[0]) or (nothing_df.Q3[nothing_index2[i]] == data.Q3[1])):
        grade += 1
    if (nothing_df.Q4[nothing_index2[i]] == (data.Q4[0]) or (nothing_df.Q4[nothing_index2[i]] == data.Q4[1])):
        grade += 1    
    if (nothing_df.Q5[nothing_index2[i]] == (data.Q5[0]) or (nothing_df.Q5[nothing_index2[i]] == data.Q5[1])):
        grade += 1
    if (nothing_df.Q6[nothing_index2[i]] == (data.Q6[0]) or (nothing_df.Q6[nothing_index2[i]] == data.Q6[1])):
        grade += 1    
    if (nothing_df.Q7[nothing_index2[i]] == (data.Q7[0]) or (nothing_df.Q7[nothing_index2[i]] == data.Q7[1])):
        grade += 1
    if (nothing_df.Q8[nothing_index2[i]] == (data.Q8[0]) or (nothing_df.Q8[nothing_index2[i]] == data.Q8[1])):
        grade += 1    
    if (nothing_df.Q9[nothing_index2[i]] == (data.Q9[0]) or (nothing_df.Q9[nothing_index2[i]] == data.Q9[1])):
        grade += 1
    if (nothing_df.Q10[nothing_index2[i]] == (data.Q10[0]) or (nothing_df.Q10[nothing_index2[i]] == data.Q10[1])):
        grade += 1    
    if (nothing_df.Q11[nothing_index2[i]] == (data.Q11[0]) or (nothing_df.Q11[nothing_index2[i]] == data.Q11[1])):
        grade += 1
    if (nothing_df.Q12[nothing_index2[i]] == (data.Q12[0]) or (nothing_df.Q12[nothing_index2[i]] == data.Q12[1])):
        grade += 1      
    grades_nothing.append(grade)
mode_nothing = scistats.mode(grades_nothing)
print("Grades nothing:", grades_nothing)    
print("Mean:", np.mean(grades_nothing))
print("Median:", np.median(grades_nothing))
print("Most frequent result:", mode_nothing)
# Out:
# Grades nothing: [7, 3, 4, 5, 3, 9, 12, 8, 6, 6, 12, 5]
# Mean: 6.666666666666667
# Median: 6.0
# Most frequent result: ModeResult(mode=array([3]), count=array([2]))

# %%
Q1NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q1[nothing_index2[i]] == data.Q1[0]) or (nothing_df.Q1[nothing_index2[i]] == data.Q1[1]))])
Q2NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q2[nothing_index2[i]] == data.Q2[0]) or (nothing_df.Q2[nothing_index2[i]] == data.Q2[1]))])
Q3NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q3[nothing_index2[i]] == data.Q3[0]) or (nothing_df.Q3[nothing_index2[i]] == data.Q3[1]))])
Q4NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q4[nothing_index2[i]] == data.Q4[0]) or (nothing_df.Q4[nothing_index2[i]] == data.Q4[1]))])
Q5NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q5[nothing_index2[i]] == data.Q5[0]) or (nothing_df.Q5[nothing_index2[i]] == data.Q5[1]))])
Q6NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q6[nothing_index2[i]] == data.Q6[0]) or (nothing_df.Q6[nothing_index2[i]] == data.Q6[1]))])
Q7NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q7[nothing_index2[i]] == data.Q7[0]) or (nothing_df.Q7[nothing_index2[i]] == data.Q7[1]))])
Q8NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q8[nothing_index2[i]] == data.Q8[0]) or (nothing_df.Q8[nothing_index2[i]] == data.Q8[1]))])
Q9NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q9[nothing_index2[i]] == data.Q9[0]) or (nothing_df.Q9[nothing_index2[i]] == data.Q9[1]))])
Q10NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q10[nothing_index2[i]] == data.Q10[0]) or (nothing_df.Q10[nothing_index2[i]] == data.Q10[1]))])
Q11NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q11[nothing_index2[i]] == data.Q11[0]) or (nothing_df.Q11[nothing_index2[i]] == data.Q11[1]))])
Q12NO = len([i for i in range(len(nothing_df)) if ((nothing_df.Q12[nothing_index2[i]] == data.Q12[0]) or (nothing_df.Q12[nothing_index2[i]] == data.Q12[1]))])

nothing_correct = [Q1NO,Q2NO,Q3NO,Q4NO,Q5NO,Q6NO,Q7NO,Q8NO,Q9NO,Q10NO,Q11NO,Q12NO]
nothing_correct = np.array(nothing_correct, int)
nothing_correct #12 Single response correct results
# Out:
# array([ 8, 10,  5,  3,  5,  9,  4,  7,  7,  8,  5,  9])

# %%
nothing_total_responses = len(nothing_df)
mean_nothing_correct = np.mean(nothing_correct)
print("Total responses: ", nothing_total_responses)
print("Non-astronomers non-musicians success mean:", mean_nothing_correct/(nothing_total_responses))

success_nothing_correct = np.sum(nothing_correct)
attempts_nothing_correct = 12* nothing_total_responses
conf_nothing_correct = astropy.stats.binom_conf_interval(success_nothing_correct, attempts_nothing_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nothing_correct) # Correct answers interval
# Out:
# Total responses:  12
# Non-astronomers non-musicians success mean: 0.5555555555555556
# Jeffreys confidence interval:  [0.51390473 0.59643798]

# %%
nothing = pd.Series(nothing_correct/nothing_total_responses)
nothing.describe()
# Out:
# count    12.000000
# mean      0.555556
# std       0.185773
# min       0.250000
# 25%       0.416667
# 50%       0.583333
# 75%       0.687500
# max       0.833333
# dtype: float64

# %%
Q13NO = len([i for i in range(len(nothing_df)) if ((check_1 in nothing_df.Q13[nothing_index2[i]]) and (check_2 in nothing_df.Q13[nothing_index2[i]]) and (check_3 in nothing_df.Q13[nothing_index2[i]])) or ((check_4 in nothing_df.Q13[nothing_index2[i]]) and (check_5 in nothing_df.Q13[nothing_index2[i]]) and (check_6 in nothing_df.Q13[nothing_index2[i]]))])
Q14NO = len([i for i in range(len(nothing_df)) if ((check_7 in nothing_df.Q14[nothing_index2[i]]) and (check_8 in nothing_df.Q14[nothing_index2[i]]) and (check_9 in nothing_df.Q14[nothing_index2[i]])) or ((check_10 in nothing_df.Q14[nothing_index2[i]]) and (check_11 in nothing_df.Q14[nothing_index2[i]]) and (check_12 in nothing_df.Q14[nothing_index2[i]]))])

nothing_combined_correct = [Q13NO,Q14NO]
nothing_combined_correct = np.array(nothing_combined_correct, int)

nothing_combined_correct
# Out:
# array([2, 3])

# %%
mean_nothing_combined_correct = np.mean(nothing_combined_correct)
print("Non-astronomers non-musicians success mean (Combined questions):", mean_nothing_combined_correct/nothing_total_responses)
success_nothing_combined_correct = np.sum(nothing_combined_correct)
attempts_nothing_combined_correct = 2* nothing_total_responses
conf_nothing_combined_correct = astropy.stats.binom_conf_interval(success_nothing_combined_correct, attempts_nothing_combined_correct, confidence_level=0.68269, interval='jeffreys')
print("Jeffreys confidence interval: ", conf_nothing_combined_correct) # Correct answers interval
# Out:
# Non-astronomers non-musicians success mean (Combined questions): 0.20833333333333334
# Jeffreys confidence interval:  [0.13840338 0.30199198]

# %%
nothing_combined = pd.Series(nothing_combined_correct/nothing_total_responses)
nothing_combined.describe()
# Out:
# count    2.000000
# mean     0.208333
# std      0.058926
# min      0.166667
# 25%      0.187500
# 50%      0.208333
# 75%      0.229167
# max      0.250000
# dtype: float64

# %% [markdown]
# ## Qualitative

# %%
# Interactivity
Q15NO_good = len([i for i in range(len(nothing_df)) if (("Buena" in nothing_df.Q15[nothing_index2[i]]) or ("Muy buena" in nothing_df.Q15[nothing_index2[i]]) or ("Good" in nothing_df.Q15[nothing_index2[i]]) or ("Very good" in nothing_df.Q15[nothing_index2[i]]))])
Q15NO_acc = len([i for i in range(len(nothing_df)) if (("Aceptable" in nothing_df.Q15[nothing_index2[i]]) or ("Acceptable" in nothing_df.Q15[nothing_index2[i]]))])
Q15NO_bad = len([i for i in range(len(nothing_df)) if (("Mala" in nothing_df.Q15[nothing_index2[i]]) or ("Muy mala" in nothing_df.Q15[nothing_index2[i]]) or ("Bad" in nothing_df.Q15[nothing_index2[i]]) or ("Very bad" in nothing_df.Q15[nothing_index2[i]]))])
Q15NO_xxx = len([i for i in range(len(nothing_df)) if ("XXX" in nothing_df.Q15[nothing_index2[i]])])
print("Interactivity 'good' or 'very good':", Q15NO_good) #Lack of this question in the first version of the survey (1 participant)
print("(%)", percentage_sub(Q15NO_good, (len(nothing_df)-Q15NO_xxx)))
print("Interactivity 'acceptable':", Q15NO_acc)
print("(%)", percentage_sub(Q15NO_acc, (len(nothing_df)-Q15NO_xxx)))
print("Interactivity 'bad' or 'very bad':", Q15NO_bad)
print("(%)", percentage_sub(Q15NO_bad, (len(nothing_df)-Q15NO_xxx)))
print("Participants that couldn't test the application in person:", Q15NO_xxx)
print("(%)", percentage_sub(Q15NO_xxx, len(nothing_df)))
# Out:
# Interactivity 'good' or 'very good': 5
# (%) 55.55555555555556
# Interactivity 'acceptable': 2
# (%) 22.22222222222222
# Interactivity 'bad' or 'very bad': 0
# (%) 0.0
# Participants that couldn't test the application in person: 3
# (%) 25.0

# %%
# Usefulness
Q16NO_good = len([i for i in range(len(nothing_df)) if (("Útil" in nothing_df.Q16[nothing_index2[i]]) or ("Muy útil" in nothing_df.Q16[nothing_index2[i]]) or ("Useful" in nothing_df.Q16[nothing_index2[i]]) or ("Very useful" in nothing_df.Q16[nothing_index2[i]]))])
Q16NO_bad = len([i for i in range(len(nothing_df)) if (("dudosa" in nothing_df.Q16[nothing_index2[i]]) or ("Doubtedly" in nothing_df.Q16[nothing_index2[i]]) or ("Doubtely" in nothing_df.Q16[nothing_index2[i]]) or ("Inútil" in nothing_df.Q16[nothing_index2[i]]) or ("Useless" in nothing_df.Q16[nothing_index2[i]]))])
print("Participants finding it 'useful' or 'very useful':", Q16NO_good)
print("(%)", percentage_sub(Q16NO_good, len(nothing_df)))
print("Participants finding it 'Doubtedly useful' or 'useless':", Q16NO_bad)
print("(%)", percentage_sub(Q16NO_bad, len(nothing_df)))
# Out:
# Participants finding it 'useful' or 'very useful': 10
# (%) 83.33333333333334
# Participants finding it 'Doubtedly useful' or 'useless': 0
# (%) 0.0

# %%
# Quality of sound
Q17NO_good = len([i for i in range(len(nothing_df)) if (("Buen" in nothing_df.Q17[nothing_index2[i]]) or ("Muy buen" in nothing_df.Q17[nothing_index2[i]]) or ("Good" in nothing_df.Q17[nothing_index2[i]]) or ("Nice" in nothing_df.Q17[nothing_index2[i]]))])
Q17NO_acc = len([i for i in range(len(nothing_df)) if (("Aceptable" in nothing_df.Q17[nothing_index2[i]]) or ("Acceptable" in nothing_df.Q17[nothing_index2[i]]))])
Q17NO_bad = len([i for i in range(len(nothing_df)) if (("Mal" in nothing_df.Q17[nothing_index2[i]]) or ("Insoportable" in nothing_df.Q17[nothing_index2[i]]) or ("Bad" in nothing_df.Q17[nothing_index2[i]]) or ("Intolerable" in nothing_df.Q17[nothing_index2[i]]))])
print("Sound Quality 'good' or 'very good':", Q17NO_good)
print("(%)", percentage_sub(Q17NO_good, len(nothing_df)))
print("Sound Quality 'acceptable':", Q17NO_acc)
print("(%)", percentage_sub(Q17NO_acc, len(nothing_df)))
print("Sound Quality 'bad' or 'very bad':", Q17NO_bad)
print("(%)", percentage_sub(Q17NO_bad, len(nothing_df)))
# Out:
# Sound Quality 'good' or 'very good': 7
# (%) 58.333333333333336
# Sound Quality 'acceptable': 3
# (%) 25.0
# Sound Quality 'bad' or 'very bad': 0
# (%) 0.0

# %% [markdown]
# ## Appending results

# %%
participants_list.append(len(nothing_df))
success_list.append(nothing.describe()["mean"])
Jeff_low_list.append(conf_nothing_correct[0])
Jeff_high_list.append(conf_nothing_correct[1])
std_list.append(nothing.describe()["std"])
comb_success_list.append(nothing_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_nothing_combined_correct[0])
comb_Jeff_high_list.append(conf_nothing_combined_correct[1])
comb_std_list.append(nothing_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15NO_good, (len(nothing_df)-Q15NO_xxx)))
useful_list.append(percentage_sub(Q16NO_good, len(nothing_df)))
sound_list.append(percentage_sub(Q17NO_good, len(nothing_df)))

# %% [markdown]
# # Statistical significance

# %%
#Kruskal-Wallis test: kruskal_p_value < 0.05 => reject the null hypothesis => statistical significance
H_statistic, kruskal_p_value = scistats.kruskal(grades_astro_nonmus, grades_non_exp_mus, grades_astromus, grades_nothing)
 
print(H_statistic, kruskal_p_value)
# Out:
# 1.1509399172512935 0.7647933540893164

# %%
scistats.f_oneway(grades_astro_nonmus, grades_non_exp_mus, grades_astromus, grades_nothing)
# Out:
# F_onewayResult(statistic=0.5224837408601903, pvalue=0.6692372501578652)

# %% [markdown]
# Conclusion: The diferences between subgroups have not statistical significance

# %%
def test_mean_vs_random(data, random_choice_value, alpha=0.05):
    
    data = np.array(data)
    sample_mean = np.mean(data)
    n = len(data)

    # Perform a one-sample t-test
    if n < 2:
        raise ValueError("Data must contain at least two observations for a t-test.")
    sample_std = np.std(data, ddof=1)  # Use sample standard deviation (ddof=1 for unbiased estimate)
    standard_error = sample_std / np.sqrt(n)
    test_statistic = (sample_mean - random_choice_value) / standard_error
    degrees_freedom = n - 1
    p_value = scistats.t.sf(np.abs(test_statistic), df=degrees_freedom) * 2  # Two-tailed p-value

    if p_value <= alpha:
        result = "Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value."
    else:
        result = "Fail to reject the null hypothesis. There is not enough statistically significant evidence that the mean is different from the random choice value."

    return test_statistic, p_value, result, sample_mean

# %%
grades_astro_nonmus
# Out:
# [8, 4, 7, 9, 7, 5, 11, 5, 6, 6, 10, 6]

# %%
random_choice_value = 4.14 #average random choice grade = average random choice rate(%) * (number of questions) = 0.345 * 12
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_experts, random_choice_value, alpha=0.05)
print(f"--- Experts ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Experts ---
# Sample Mean Proportion: 6.66
# Random Choice Proportion: 4.14
# Test Statistic (t): 8.192
# P-value: 0.000000006
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
random_choice_value = 4.14
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_nonexperts_down, random_choice_value, alpha=0.05)
print(f"--- Non experts ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Non experts ---
# Sample Mean Proportion: 5.84
# Random Choice Proportion: 4.14
# Test Statistic (t): 4.199
# P-value: 0.000220301
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
random_choice_value = 4.14
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_astro_nonmus, random_choice_value, alpha=0.05)
print(f"--- Astro ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Astro ---
# Sample Mean Proportion: 7.00
# Random Choice Proportion: 4.14
# Test Statistic (t): 4.647
# P-value: 0.000708588
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
random_choice_value = 4.14
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_non_exp_mus, random_choice_value, alpha=0.05)
print(f"--- Mus ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Mus ---
# Sample Mean Proportion: 5.82
# Random Choice Proportion: 4.14
# Test Statistic (t): 2.498
# P-value: 0.031541431
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
random_choice_value = 4.14
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_astromus, random_choice_value, alpha=0.05)
print(f"--- Astromus ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Astromus ---
# Sample Mean Proportion: 6.50
# Random Choice Proportion: 4.14
# Test Statistic (t): 5.512
# P-value: 0.000374442
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
random_choice_value = 4.14
test_statistic_prop, p_value_prop, result_prop, sample_mean = test_mean_vs_random(grades_nothing, random_choice_value, alpha=0.05)
print(f"--- Nothing ---")
print(f"Sample Mean Proportion: {sample_mean:.2f}")
print(f"Random Choice Proportion: {random_choice_value:.2f}")
print(f"Test Statistic (t): {test_statistic_prop:.3f}")
print(f"P-value: {p_value_prop:.9f}")
print(f"Result: {result_prop}")
print("-" * 20)
# Out:
# --- Nothing ---
# Sample Mean Proportion: 6.67
# Random Choice Proportion: 4.14
# Test Statistic (t): 2.837
# P-value: 0.016154929
# Result: Reject the null hypothesis. There is statistically significant evidence that the mean is different from the random choice value.
# --------------------

# %%
participants_list.append(blv_counter)
success_list.append(blv.describe()["mean"])
Jeff_low_list.append(conf_blv_correct[0])
Jeff_high_list.append(conf_blv_correct[1])
std_list.append(blv.describe()["std"])
comb_success_list.append(blv_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_blv_combined_correct[0])
comb_Jeff_high_list.append(conf_blv_combined_correct[1])
comb_std_list.append(blv_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15blv_good, blv_counter))
useful_list.append(percentage_sub(Q16blv_good, blv_counter))
sound_list.append(percentage_sub(Q17blv_good, blv_counter))

# %%
participants_list.append(nonblv_counter)
success_list.append(nonblv.describe()["mean"])
Jeff_low_list.append(conf_nonblv_correct[0])
Jeff_high_list.append(conf_nonblv_correct[1])
std_list.append(nonblv.describe()["std"])
comb_success_list.append(nonblv_combined.describe()["mean"])
comb_Jeff_low_list.append(conf_nonblv_combined_correct[0])
comb_Jeff_high_list.append(conf_nonblv_combined_correct[1])
comb_std_list.append(nonblv_combined.describe()["std"])
interactivity_list.append(percentage_sub(Q15nonblv_good, nonblv_counter - Q15nonblv_xxx))
useful_list.append(percentage_sub(Q16nonblv_good, nonblv_counter))
sound_list.append(percentage_sub(Q17nonblv_good, nonblv_counter))

# %% [markdown]
# # Normality

# %%
from scipy.stats import shapiro

# Test normality for each group. p-value<0.05 =>not normally distributed
stat1, p0 = shapiro(data_correct)
stat1, p1 = shapiro(experts_correct)
stat2, p2 = shapiro(nonExperts_correct)
stat3, p3 = shapiro(astromus_correct)
stat4, p4 = shapiro(non_exp_mus_correct)
stat4, p5 = shapiro(astro_nonmus_correct)
stat4, p6 = shapiro(nothing_correct)
stat4, p7 = shapiro(blv_correct)
stat4, p8 = shapiro(nonblv_correct)

print(f"global normality: p={p0}")
print(f"experts normality: p={p1}")
print(f"nonexperts normality: p={p2}")
print(f"astromus normality: p={p3}")
print(f"mus normality: p={p4}")
print(f"astro normality: p={p5}")
print(f"nonexperts-4 normality: p={p6}")
print(f"blv normality: p={p7}")
print(f"nonblv normality: p={p8}")
# Out:
# global normality: p=0.794381856918335
# experts normality: p=0.9231464862823486
# nonexperts normality: p=0.9423493146896362
# astromus normality: p=0.05495025962591171
# mus normality: p=0.4459173083305359
# astro normality: p=0.019538642838597298
# nonexperts-4 normality: p=0.5632864832878113
# blv normality: p=0.018008066341280937
# nonblv normality: p=0.015256590209901333

# %% [markdown]
# ## Generating a CSV file

# %%
with open("ViewCube_Stats-2-Thesis.csv", "w") as csvfile:
    write = csv.writer(csvfile)
    write.writerow(["Group", "Participants", "Success", "Jeff_low", "Jeff_high", "std", "comb_Success", "comb_Jeff_low", "comb_Jeff_high", "comb_std", "interactivity", "useful", "sound"])
    for i in range(len(column_list)):
        write.writerow([column_list[i], participants_list[i], success_list[i], Jeff_low_list[i], Jeff_high_list[i], std_list[i], comb_success_list[i], comb_Jeff_low_list[i], comb_Jeff_high_list[i], comb_std_list[i], interactivity_list[i], useful_list[i], sound_list[i]])

# %% [markdown]
# ## Ploting

# %%
data = pd.read_csv("ViewCube_Stats-2-Thesis.csv", delimiter=',')
data
# Out:
#              Group  Participants   Success  Jeff_low  Jeff_high       std  \
# 0           Global            65  0.515385  0.497482   0.533248  0.165372
# 1       Astrónomos            29  0.554598  0.527836   0.581046  0.179153
# 2    No astrónomos            31  0.481183  0.455363   0.507104  0.170947
# 3      Astro y Mus            10  0.541667  0.496024   0.586618  0.219331
# 4     Astro no Mus            12  0.583333  0.541813   0.623702  0.184637
# 5     Mus no Astro            11  0.484848  0.441627   0.528298  0.220420
# 6  Sin experiencia            12  0.555556  0.513905   0.596438  0.185773
# 7              BLV             2  0.541667  0.440332   0.639615  0.396481
# 8           No BLV             2  0.583333  0.481326   0.678567  0.358870
#
#    comb_Success  comb_Jeff_low  comb_Jeff_high  comb_std  interactivity  \
# 0      0.161538       0.131907        0.196355  0.010879      80.952381
# 1      0.155172       0.113679        0.208444  0.121915      76.190476
# 2      0.193548       0.148511        0.248382  0.091240      82.352941
# 3      0.150000       0.087852        0.246183  0.070711      75.000000
# 4      0.125000       0.072943        0.207608  0.058926      66.666667
# 5      0.363636       0.269265        0.470072  0.128565      83.333333
# 6      0.208333       0.138403        0.301992  0.058926      55.555556
# 7      0.000000       0.000000        0.207926  0.000000       0.000000
# 8      0.000000       0.000000        0.207926  0.000000     100.000000
#
#        useful       sound
# 0   78.461538   56.923077
# 1   72.413793   48.275862
# 2   80.645161   64.516129
# 3   60.000000   40.000000
# 4   75.000000   50.000000
# 5   81.818182   63.636364
# 6   83.333333   58.333333
# 7  100.000000  100.000000
# 8  100.000000   50.000000

# %%
means = data['Success']
means
# Out:
# 0    0.515385
# 1    0.554598
# 2    0.481183
# 3    0.541667
# 4    0.583333
# 5    0.484848
# 6    0.555556
# 7    0.541667
# 8    0.583333
# Name: Success, dtype: float64

# %%
labels = data['Group']
labels
# Out:
# 0             Global
# 1         Astrónomos
# 2      No astrónomos
# 3        Astro y Mus
# 4       Astro no Mus
# 5       Mus no Astro
# 6    Sin experiencia
# 7                BLV
# 8             No BLV
# Name: Group, dtype: object

# %%
participants = data['Participants']
participants
# Out:
# 0    65
# 1    29
# 2    31
# 3    10
# 4    12
# 5    11
# 6    12
# 7     2
# 8     2
# Name: Participants, dtype: int64

# %% [markdown]
# ## Success rate: Global | Experts (Astronomers) | Nonexperts (Non astronomers)

# %%
fig, ax = plt.subplots(figsize=(14,6),dpi=200)
x = np.arange(len(labels))
bar_width = .9
rects1 = ax.bar(1 - bar_width/2, means[0] , bar_width, yerr=data['std'][0], 
                label=labels[0] + " (" + str(participants[0]) + " participantes)",color='hotpink', align='center',ecolor='black',capsize=10)
rects2 = ax.bar(2 - bar_width/2, means[1] , bar_width, yerr=data['std'][1], 
                label=labels[1] + " (" + str(participants[1]) + " participantes)", color='steelblue', align='center',ecolor='black',capsize=10)
rects3 = ax.bar(3 - bar_width/2, means[2] , bar_width, yerr=data['std'][2], 
                label=labels[2] + " (" + str(participants[2]) + " participantes)", color = 'forestgreen', align='center',ecolor='black',capsize=10)

ax.set_ylabel('Tasa de acierto promedio',size=20)
ax.set_xlabel('Subgrupos',size=20)

ax.tick_params(which='major', width=1.0, labelsize=14)
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.add_patch(Rectangle((0.46, data['Jeff_low'][0]), 
                       0.18, data['Jeff_high'][0]-data['Jeff_low'][0],
                       alpha=0.5,color='black'))
ax.add_patch(Rectangle((1.46, data['Jeff_low'][1]), 
                       0.18, data['Jeff_high'][1]-data['Jeff_low'][1],
                       alpha=0.5,color='black'))
ax.add_patch(Rectangle((2.46, data['Jeff_low'][2]), 
                       0.18, data['Jeff_high'][2]-data['Jeff_low'][2],
                       alpha=0.5,color='black'))
ax.set_xticks([])
ax.set_xticklabels([])
ax.legend(fontsize=14,loc='lower right', framealpha=1)
ax.set_ylim(0, 0.82)

plt.axhline(y=0.345, color='black', linestyle='--')


plt.savefig('ViewCube_plot1-Thesis.png')
plt.show()

# %% [markdown]
# ## Combined questions

# %%
comb_means = data['comb_Success']
comb_means
# Out:
# 0    0.161538
# 1    0.155172
# 2    0.193548
# 3    0.150000
# 4    0.125000
# 5    0.363636
# 6    0.208333
# 7    0.000000
# 8    0.000000
# Name: comb_Success, dtype: float64

# %% [markdown]
# ## Subgroups: Astronomers musicians | Astronomers non musicians | Musicians non astronomers | Non musicians non astronomers

# %%
fig, ax = plt.subplots(figsize=(14,6),dpi=200)
x = np.arange(len(labels))
bar_width = .9
rects1 = ax.bar(1 - bar_width/2, means[3] , bar_width, yerr=data['std'][3], 
                label=labels[3] + " (" + str(participants[3]) + " participants)",color='dodgerblue', align='center',ecolor='black',capsize=10)
rects2 = ax.bar(2 - bar_width/2, means[4] , bar_width, yerr=data['std'][4], 
                label=labels[4] + " (" + str(participants[4]) + " participants)", color='deepskyblue', align='center',ecolor='black',capsize=10)
rects3 = ax.bar(3 - bar_width/2, means[5] , bar_width, yerr=data['std'][5], 
                label=labels[5] + " (" + str(participants[5]) + " participants)", color = 'olivedrab', align='center',ecolor='black',capsize=10)
rects4 = ax.bar(4 - bar_width/2, means[6] , bar_width, yerr=data['std'][6], 
                label=labels[6] + " (" + str(participants[6]) + " participants)", color = 'lightgreen', align='center',ecolor='black',capsize=10)


ax.set_ylabel('Tasa de acierto promedio',size=20)
ax.set_xlabel('Subgrupos',size=20)

ax.tick_params(which='major', width=1.0, labelsize=14)
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.add_patch(Rectangle((0.46, data['Jeff_low'][3]), 
                       0.18, data['Jeff_high'][3]-data['Jeff_low'][3],
                       alpha=0.5,color='black'))#,label="Jeffreys' confidence intervals"))
ax.add_patch(Rectangle((1.46, data['Jeff_low'][4]), 
                       0.18, data['Jeff_high'][4]-data['Jeff_low'][4],
                       alpha=0.5,color='black'))
ax.add_patch(Rectangle((2.46, data['Jeff_low'][5]), 
                       0.18, data['Jeff_high'][5]-data['Jeff_low'][5],
                       alpha=0.5,color='black'))
ax.add_patch(Rectangle((3.46, data['Jeff_low'][6]), 
                       0.18, data['Jeff_high'][6]-data['Jeff_low'][6],
                       alpha=0.5,color='black'))

plt.axhline(y=0.345, color='black', linestyle='--')

ax.set_xticks([])
ax.set_xticklabels([])
ax.legend(fontsize=14,loc='lower right', framealpha=1)
plt.savefig('ViewCube_plot3-Thesis.png')
plt.show()

# %% [markdown]
# ## Subgroups - Combined questions (Not used)

# %% [markdown]
# ## Results summary

# %%
graph1 = [glob.describe(), experts.describe(), nonExperts.describe()]
graph2 = [glob_comb.describe(), experts_combined.describe(), nonExperts_combined.describe()]

# %%
medianprops = dict(linestyle='-', linewidth=3.5, color='black')

labels_1 = ["Global", "Astrónomos", "No astrónomos"]
fig, ax = plt.subplots(1, 1, figsize=(8,6), dpi=100)


ax.boxplot(graph2, '', medianprops=medianprops)
ax.set_xticklabels(labels_1, fontsize=20)
ax.tick_params(which='major', width=1.0, labelsize=18)
ax.set_title("Preguntas combinadas", size=20, weight="bold")
ax.set_ylim(-0.009, 0.31)
ax.set_ylabel('Tasa de acierto promedio',size=20)


plt.axhline(y=0.2, color='black', linestyle='--')


plt.savefig('ViewCube_boxplot1-Thesis.png')

plt.show()

# %%
graph3 = [astromus.describe(), astro_nonmus.describe(), non_exp_mus.describe(), nothing.describe()]
graph4 = [astromus_combined.describe(), astro_nonmus_combined.describe(), non_exp_mus.describe(), nothing_combined.describe()]

# %%
labels_2 = ["AstroMus", "Astro", "Mus", "Sin experiencia"]
fig, ax = plt.subplots(1, 1, figsize=(8,6), dpi=100)

ax.boxplot(graph4, '', medianprops=medianprops)
ax.set_xticklabels(labels_2, fontsize=12)
ax.tick_params(which='major', width=1.0, labelsize=18)
ax.set_title("Preguntas combinadas según experiencia", size=20, weight="bold")
ax.set_ylim(-0.03, 1.03)
ax.set_ylabel('Tasa de acierto promedio',size=20)

plt.axhline(y=0.2, color='black', linestyle='--')

plt.savefig('ViewCube_boxplot2-Thesis.png')

plt.show()

# %%
data['useful'][0]
# Out:
# 78.46153846153847

# %% [markdown]
# ## Global qualitative answers

# %%
qualitative_labels = 'Yes', 'No'
interactivity = [data['interactivity'][0], 100-data['interactivity'][0]]
usefulness = [data['useful'][0], 100-data['useful'][0]]
sound = [data['sound'][0], 100-data['sound'][0]]


explode = (0.15, 0)
explode2 = (0.1, 0.05)
explode3 = (0.12, 0)


fig, ax = plt.subplots(1, 3, figsize=(12, 8), dpi=200)
ax[0].pie(interactivity, explode=explode2, shadow= True, autopct='%1.1f%%', startangle=70, textprops=dict(color="w", size=16, weight="bold"), colors=['yellowgreen', 'slategrey'])
ax[0].set_title("Buena interactividad", size=18, weight="bold")

ax[1].pie(usefulness, explode=explode, shadow= True, autopct='%1.1f%%', startangle=70, textprops=dict(color="w", size=16, weight="bold"), colors=['yellowgreen', 'slategrey'])
ax[1].set_title("Útil", size=18, weight="bold")
ax[2].pie(sound, explode=explode3, shadow= True, autopct='%1.1f%%', startangle=85, textprops=dict(color="w", size=16, weight="bold"), colors=['yellowgreen', 'slategrey'])
ax[2].set_title("Buen sonido", size=18, weight="bold")

ax[0].text(-.65,.25, 'Sí', color='w', size=30, weight="bold")
ax[1].text(-.65,.25, 'Sí', color='w', size=30, weight="bold")
ax[2].text(-.7,.25, 'Sí', color='w', size=30, weight="bold")



plt.savefig('ViewCube_qualitative-Thesis.png')
plt.show()

# %%
test = np.concatenate((data_correct, combined_correct))
test
# Out:
# array([30, 57, 25, 25, 39, 42, 34, 43, 31, 16, 26, 34, 11, 10])

# %%
data_correct
# Out:
# array([30, 57, 25, 25, 39, 42, 34, 43, 31, 16, 26, 34])

# %%
combined_correct
# Out:
# array([11, 10])

# %% [markdown]
# ## Analysis by question

# %%
colors = plt.colormaps['Set2'].colors

fig, ax = plt.subplots(layout='constrained')

for i, color in enumerate(colors):
    ax.plot([0, i], color=color)

plt.show()

# %%
plt.rc('ytick', labelsize=15) 

questions = ("Loc-1", "Loc-2", "Loc-3", "Loc-4", "Dist-5", "Dist-6", "Dist-7", "Dist-8", "Tipo-9", "Tipo-10","Tipo-11", "Tipo-12", "Comb-13", "Comb-14")
success = {
    'Astrónomos (31 participantes)': np.concatenate((np.round(100*experts_correct/31), np.round(100*experts_combined_correct/31))),
    'No astrónomos (31 participantes)': np.concatenate((np.round(100*nonExperts_correct/31), np.round(100*nonExperts_combined_correct/31))),
#    'Astromus (11 participants)': np.concatenate((np.round(100*astromus_correct/11), np.round(100*astromus_combined_correct/11))),
 #   'AstroNonMus (13 participants)': np.concatenate((np.round(100*astro_nonmus_correct/13), np.round(100*astro_nonmus_combined_correct/13))),
  #  'MusNonAstro (11 participants)': np.concatenate((np.round(100*non_exp_mus_correct/11), np.round(100*non_exp_mus_combined_correct/11))),
   # 'Nothing (12 participants)': np.concatenate((np.round(100*nothing_correct/12), np.round(100*nothing_combined_correct/12))),

}

x = np.arange(len(questions))  # the label locations
width = 0.45  # the width of the bars
multiplier = 1.05
fig, ax = plt.subplots(figsize=(20,6),dpi=200, layout='constrained')

i=0
for attribute, measurement in success.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[i])
    ax.bar_label(rects, padding=-2, fontsize=16)
    multiplier += 1
    i += 1
    
line_offset = 0.33    
ax.hlines(y=50, color='black', linestyle=':', linewidth=2, xmin=-.07+line_offset, xmax=.82+line_offset)
ax.hlines(y=50, color='black', linestyle=':', linewidth=2, xmin=0.93+line_offset, xmax=1.82+line_offset)
ax.hlines(y=25, color='black', linestyle=':', linewidth=2, xmin=1.93+line_offset, xmax=2.82+line_offset)
ax.hlines(y=25, color='black', linestyle=':', linewidth=2, xmin=2.93+line_offset, xmax=3.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=3.93+line_offset, xmax=4.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=4.93+line_offset, xmax=5.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=5.93+line_offset, xmax=6.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=6.93+line_offset, xmax=7.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=7.93+line_offset, xmax=8.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=8.93+line_offset, xmax=9.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=9.93+line_offset, xmax=10.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=10.93+line_offset, xmax=11.82+line_offset)
ax.hlines(y=17, color='black', linestyle=':', linewidth=2, xmin=11.93+line_offset, xmax=12.82+line_offset)
ax.hlines(y=17, color='black', linestyle=':', linewidth=2, xmin=12.93+line_offset, xmax=13.82+line_offset)

    
ax.set_xlabel('Preguntas', fontsize=22)
ax.set_ylabel('Acierto (% redondeado)', fontsize=22)

ax.set_xticks(.25 + x + width, questions, fontsize=17)
ax.legend(loc='upper right', ncols=1, fontsize=17)
ax.set_ylim(0, 100)



plt.savefig('ViewCube_questions_subgroups1-Thesis.png')
plt.show()

# %%
plt.style.use('fast')

questions = ("Loc-1", "Loc-2", "Loc-3", "Loc-4", "Dist-5", "Dist-6", "Dist-7", "Dist-8", "Tipo-9", "Tipo-10","Tipo-11", "Tipo-12", "Comb-13", "Comb-14")
success2 = {
#    'Astronomers (31 participants)': np.concatenate((np.round(100*experts_correct/31), np.round(100*experts_combined_correct/31))),
 #   'Non-astronomers (31 participants)': np.concatenate((np.round(100*nonExperts_correct/31), np.round(100*nonExperts_combined_correct/31))),
    'Astro y Mus (11 participantes)': np.concatenate((np.round(100*astromus_correct/11), np.round(100*astromus_combined_correct/11))),
    'Astro no Mus (13 participantes)': np.concatenate((np.round(100*astro_nonmus_correct/13), np.round(100*astro_nonmus_combined_correct/13))),
    'Mus no Astro (11 participantes)': np.concatenate((np.round(100*non_exp_mus_correct/11), np.round(100*non_exp_mus_combined_correct/11))),
    'Sin experiencia (12 participantes)': np.concatenate((np.round(100*nothing_correct/12), np.round(100*nothing_combined_correct/12))),

}

x = np.arange(len(questions))  # the label locations
width = 0.22  # the width of the bars
multiplier = 0.55
fig, ax = plt.subplots(figsize=(20,6),dpi=200, layout='constrained')
i=0
for attribute, measurement in success2.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[i+2])
    ax.bar_label(rects, padding= 5, fontsize=16)
    multiplier += 1
    i += 1

line_offset = 0.07    
ax.hlines(y=50, color='black', linestyle=':', linewidth=2, xmin=-.07+line_offset, xmax=.82+line_offset)
ax.hlines(y=50, color='black', linestyle=':', linewidth=2, xmin=0.93+line_offset, xmax=1.82+line_offset)
ax.hlines(y=25, color='black', linestyle=':', linewidth=2, xmin=1.93+line_offset, xmax=2.82+line_offset)
ax.hlines(y=25, color='black', linestyle=':', linewidth=2, xmin=2.93+line_offset, xmax=3.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=3.93+line_offset, xmax=4.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=4.93+line_offset, xmax=5.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=5.93+line_offset, xmax=6.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=6.93+line_offset, xmax=7.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=7.93+line_offset, xmax=8.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=8.93+line_offset, xmax=9.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=9.93+line_offset, xmax=10.82+line_offset)
ax.hlines(y=33, color='black', linestyle=':', linewidth=2, xmin=10.93+line_offset, xmax=11.82+line_offset)
ax.hlines(y=17, color='black', linestyle=':', linewidth=2, xmin=11.93+line_offset, xmax=12.82+line_offset)
ax.hlines(y=17, color='black', linestyle=':', linewidth=2, xmin=12.93+line_offset, xmax=13.82+line_offset)

    
ax.set_ylabel('Acierto (% redondeado)', fontsize=22)
ax.set_xlabel('Preguntas', fontsize=22)

ax.set_xticks(.25 + x + width, questions, fontsize=17)
ax.legend(loc='upper right', ncols=2, fontsize=17)
ax.set_ylim(0, 110)



plt.savefig('ViewCube_questions-subgroups2-Thesis.png')
plt.show()

# %%
np.save('correct.npy', data_correct)
np.save('experts_correct.npy', experts_correct)
np.save('nonexperts_correct.npy', nonExperts_correct)
np.save('astromus_correct.npy', astromus_correct)
np.save('mus_correct.npy', non_exp_mus_correct)
np.save('astro_correct.npy', astro_nonmus_correct)
np.save('nonexperts_4_correct.npy', nothing_correct)
np.save('blv_correct.npy', blv_correct)
np.save('nonblv_correct.npy', nonblv_correct)

np.save('grades.npy', grades)
np.save('grades_experts.npy', grades_experts)
np.save('grades_nonexperts.npy', grades_nonexperts_down)
np.save('grades_astromus.npy', grades_astromus)
np.save('grades_mus.npy', grades_non_exp_mus)
np.save('grades_astro.npy', grades_astro_nonmus)
np.save('grades_nonexperts_4.npy', nothing)
np.save('grades_blv.npy', grades_blv)
np.save('grades_nonblv.npy', grades_nonblv)

np.save('participants.npy', data['Participants'])
